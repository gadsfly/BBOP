# %%
import os
import re
from scipy.io import loadmat, savemat
import numpy as np
from pprint import pp
import shutil
import tempfile
import uuid
from pathlib import Path
import csv
import datetime

# %%
# GLOBAL CONSTANTS - DO NOT CHANGE THIS SECTION -

LASTCHANGE_STRING = "2024-08-27_mir_morecams_calibonly" #"2024-08-20_mir_flip_zaxes" # 240827 noticed, same name in ssh and bryan ws

# Matrix tranform to flip x,y axes and negate z axis
# this is multiplied by each 3d point and by each rotation matrix
transform = np.array([[0, 1, 0], [ 1, 0, 0] , [ 0, 0, -1]])
# transform = np.array([[1, 0, 0], [ 0, 1, 0] , [ 0, 0, -1]])

# %%
def save_backup_samedir(src_filepath):
    """For each file, create a copy of it with a .old postfix in the same directory"""
    assert Path(src_filepath).exists(), "src_filepath must exist"
    src_filepath_str = str(Path(src_filepath).resolve())

    candidate_path = src_filepath
    
    # try 1000 times to make a unique filename then throw an error if it failed
    tries = 0
    while True:
        candidate_path = Path(f"{candidate_path}.old")
        if candidate_path.exists():
            tries += 1
        else:
            break

        if tries > 1000: 
            raise Exception("Unable to generate unique file name. Tried 1000 times already.")

    dest_filepath = candidate_path
    
    shutil.copy2(src_filepath, dest_filepath)
    print(f"BACKUP src={src_filepath} dest={dest_filepath}")


def update_hires_file(filepath, saveto=None):    
    print(f"update_hires_file: {filepath}")    
    
    mat1 = loadmat(filepath)
    
    if 'lastchange' in mat1 and mat1['lastchange'] == LASTCHANGE_STRING:
        raise Exception("SKIPPING BECAUSE UPDATE WAS ALREADY APPLIED")

    save_backup_samedir(filepath)

    
    mat1['lastchange'] = LASTCHANGE_STRING
    mat1['r'] =transform @ mat1['r']

    if saveto is not None:
        print(f"Saving update mat file as: {saveto}")
        savemat(saveto, mat1)
    else:
        print("Not saving file because saveto not specified")


def update_label3d_working_file(filepath, saveto=None):
    """Fix label3d save files (these can be loaded in label3d). This is NOT 
    the label3d exported files used to train dannce (those are *dannce.mat)"""
    
    mat3 = loadmat(filepath)
    
    if 'lastchange' in mat3 and mat3['lastchange'] == LASTCHANGE_STRING:
        raise Exception("SKIPPING BECAUSE UPDATE WAS ALREADY APPLIED")


    save_backup_samedir(filepath)

    
    n_cams = mat3['camParams'].shape[0]
    n_samples = mat3['data_3D'].shape[0]
    n_joints =  mat3['data_3D'].shape[1]//3
    
    
    # update 3d points (labeld 3d-space)
    # format is [x y z x2 y2 z2 ... xN yN zN] for each row
    # mat3d['data_3D'].shape = (75,69)
    dat = mat3['data_3D'] # old shape: (75, 69)
    dat = dat.reshape(n_samples, n_joints, 3) # new shape: (75, 23, 3)
    print("fixing all 3d points for #samples={n_samples}")
    for joint_idx in range(n_joints):
        print(f"updating on joint_idx={joint_idx}")
        joint_dat = dat[:,joint_idx,:] #shape: (75,3)
        joint_dat = (transform @ joint_dat.T).T
        dat[:,joint_idx,:] = joint_dat
    mat3['data_3D'] = dat.reshape(n_samples, 3*n_joints)
    
    # update camera parameters (rotation mtx) for each camera
    # mat3['camParams'].shape = (6,1)
    for cam_idx in range(n_cams):
        print(f"updating rot mtx for cam_idx={cam_idx}")
        
        this_rot_mtx = mat3['camParams'][cam_idx,0]['r'][0,0]
        this_rot_mtx = transform @ this_rot_mtx
        mat3['camParams'][cam_idx,0]['r'][0,0] = this_rot_mtx
    
    mat3['lastchange'] = LASTCHANGE_STRING

    if saveto is not None:
        print(f"Saving update mat file as: {saveto}")
        savemat(saveto, mat3)
    else:
        print("Not saving file because saveto not specified")


def update_calib_for_dannce(filepath,saveto=None):
    print(f"update_dannce_mat_file: {filepath}")

    mat4 = loadmat(filepath)
    
    if 'lastchange' in mat4 and mat4['lastchange'] == LASTCHANGE_STRING:
        raise Exception("SKIPPING BECAUSE UPDATE WAS ALREADY APPLIED")

    save_backup_samedir(filepath)
    
    mat4['lastchange'] = LASTCHANGE_STRING

    n_cams = mat4['camnames'].shape[1] # I've made a mistake by having shape[0] i am so stupid...

    # import pdb
    # pdb.set_trace()


    # n_cams = mat4['labelData'].shape[0]
    # n_samples = mat4['labelData'][0,0][0,0]['data_3d'].shape[0]
    # n_joints =  mat4['labelData'][0,0][0,0]['data_3d'].shape[1]//3
    
    # print(f"n_cams={n_cams}, n_samples={n_samples}, n_joints={n_joints}")
    
    # update camera parameters (rotation mtx) for each camera
    # mat4['camParams'].shape = (6,1)
    for cam_idx in range(n_cams):
        print(f"updating rot mtx for cam_idx={cam_idx}")
        
        this_rot_mtx = mat4['params'][cam_idx,0]['r'][0,0]
        this_rot_mtx = transform @ this_rot_mtx
        mat4['params'][cam_idx,0]['r'][0,0] = this_rot_mtx
    
    
    # for cam_idx in range(n_cams):
    #     print(f"updating all 3d pts in labelData[cam_idx] -> data_3d for cam_idx={cam_idx}")
        
    #     dat = mat4['labelData'][cam_idx,0][0,0]['data_3d']  # old shape: (35, 69)
    #     dat = dat.reshape(n_samples, n_joints, 3) # new shape: (35, 23, 3)
    #     for joint_idx in range(n_joints):
    #         # print(f"updating on joint_idx={joint_idx}")
    #         joint_dat = dat[:,joint_idx,:] #shape: (75,3)
    #         joint_dat = (transform @ joint_dat.T).T
    #         dat[:,joint_idx,:] = joint_dat
    #     mat4['labelData'][cam_idx,0][0,0]['data_3d'] = dat.reshape(n_samples, 3*n_joints)
    
    if saveto is not None:
        print(f"Saving update mat file as: {saveto}")
        savemat(saveto, mat4)
    else:
        print("Not saving file because saveto not specified")

def update_dannce_mat_file(filepath,saveto=None):
    print(f"update_dannce_mat_file: {filepath}")

    mat4 = loadmat(filepath)
    
    if 'lastchange' in mat4 and mat4['lastchange'] == LASTCHANGE_STRING:
        raise Exception("SKIPPING BECAUSE UPDATE WAS ALREADY APPLIED")

    save_backup_samedir(filepath)
    
    mat4['lastchange'] = LASTCHANGE_STRING
    
    n_cams = mat4['labelData'].shape[0]
    n_samples = mat4['labelData'][0,0][0,0]['data_3d'].shape[0]
    n_joints =  mat4['labelData'][0,0][0,0]['data_3d'].shape[1]//3
    
    print(f"n_cams={n_cams}, n_samples={n_samples}, n_joints={n_joints}")
    
    # update camera parameters (rotation mtx) for each camera
    # mat4['camParams'].shape = (6,1)
    for cam_idx in range(n_cams):
        print(f"updating rot mtx for cam_idx={cam_idx}")
        
        this_rot_mtx = mat4['params'][cam_idx,0]['r'][0,0]
        this_rot_mtx = transform @ this_rot_mtx
        mat4['params'][cam_idx,0]['r'][0,0] = this_rot_mtx
    
    
    for cam_idx in range(n_cams):
        print(f"updating all 3d pts in labelData[cam_idx] -> data_3d for cam_idx={cam_idx}")
        
        dat = mat4['labelData'][cam_idx,0][0,0]['data_3d']  # old shape: (35, 69)
        dat = dat.reshape(n_samples, n_joints, 3) # new shape: (35, 23, 3)
        for joint_idx in range(n_joints):
            # print(f"updating on joint_idx={joint_idx}")
            joint_dat = dat[:,joint_idx,:] #shape: (75,3)
            joint_dat = (transform @ joint_dat.T).T
            dat[:,joint_idx,:] = joint_dat
        mat4['labelData'][cam_idx,0][0,0]['data_3d'] = dat.reshape(n_samples, 3*n_joints)
    
    if saveto is not None:
        print(f"Saving update mat file as: {saveto}")
        savemat(saveto, mat4)
    else:
        print("Not saving file because saveto not specified")


def update_com3d_file(filepath, saveto=None):
    print(f"update_com3d_file: {filepath}")
    mat5 = loadmat(filepath)

    if 'lastchange' in mat5 and mat5['lastchange'] == LASTCHANGE_STRING:
        raise Exception("SKIPPING BECAUSE UPDATE WAS ALREADY APPLIED")

    save_backup_samedir(filepath)

    n_samples = mat5['com'].shape[0]
    n_joints =  1 # always 1 for COMs
    
    
    # update 3d points (labeld 3d-space)
    # format is [x y z x2 y2 z2 ... xN yN zN] for each row
    dat = mat5['com'] # old shape: (90000, 3)
    dat = dat.reshape(n_samples, n_joints, 3) # new shape: (90000, 1, 3)
    print("fixing all 3d points for #samples={n_samples}")
    for joint_idx in range(n_joints):
        print(f"updating on joint_idx={joint_idx}")
        joint_dat = dat[:,joint_idx,:] #shape: (75,3)
        joint_dat = (transform @ joint_dat.T).T
        dat[:,joint_idx,:] = joint_dat
    mat5['com'] = dat.reshape(n_samples, 3*n_joints)
    mat5['lastchange'] = LASTCHANGE_STRING

    if saveto is not None:
        print(f"Saving update mat file as: {saveto}")
        savemat(saveto, mat5)
    else:
        print("Not saving file because saveto not specified")

# %%
import shutil
from pathlib import Path

def revert_backup_samedir(src_filepath):
    """Revert to the latest .old backup and remove all .old backups in the same directory."""
    original_file = Path(src_filepath)
    assert original_file.exists(), f"{src_filepath} does not exist."

    # Find all backup files for the original file
    backup_files = sorted(Path(f"{src_filepath}.old").parent.glob(f"{original_file.name}.old"), #old*, but i want only .old just in case
                          key=lambda x: x.stat().st_mtime, reverse=True)
    
    if not backup_files:
        raise FileNotFoundError("No backup files found.")
    
    # Use the most recent backup
    latest_backup = backup_files[0]
    print(f"Reverting {src_filepath} to {latest_backup}")

    # Copy the latest backup to the original file
    shutil.copy2(latest_backup, src_filepath)
    print(f"Reverted {src_filepath} to {latest_backup}")

    # Remove all .old backups
    for backup in backup_files:
        try:
            backup.unlink()
            print(f"Removed backup: {backup}")
        except Exception as e:
            print(f"Failed to remove backup: {backup}. Reason: {e}")

# Example usage
# revert_backup_samedir('/home/lq53/mir_data/text_orig.txt')

# %%
# have to input origion file path though hh
# revert_backup_samedir('/home/lq53/mir_data/24summ/2024_07_03/1691486_left_right_habituation/df_converted_pos_synced_1691486_left_right_habituation_calib_before_label3d_dannce.mat')
# Out:
# Reverting /home/lq53/mir_data/24summ/2024_07_03/1691486_left_right_habituation/df_converted_pos_synced_1691486_left_right_habituation_calib_before_label3d_dannce.mat to /home/lq53/mir_data/24summ/2024_07_03/1691486_left_right_habituation/df_converted_pos_synced_1691486_left_right_habituation_calib_before_label3d_dannce.mat.old
# Reverted /home/lq53/mir_data/24summ/2024_07_03/1691486_left_right_habituation/df_converted_pos_synced_1691486_left_right_habituation_calib_before_label3d_dannce.mat to /home/lq53/mir_data/24summ/2024_07_03/1691486_left_right_habituation/df_converted_pos_synced_1691486_left_right_habituation_calib_before_label3d_dannce.mat.old
# Removed backup: /home/lq53/mir_data/24summ/2024_07_03/1691486_left_right_habituation/df_converted_pos_synced_1691486_left_right_habituation_calib_before_label3d_dannce.mat.old

# %% [markdown]
# **Note: label3d working files are commented out**

# %%
# find the following:
#   1. dannce.mat
#   2. label3d working files (_Label3D.mat)
#   3. calibration (hires_camX_params.mat) files
#   4. com3d.mat files

# specify foldes to do the glob search on:
base_paths = [ 
    '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ'
]
# base_paths = [ 
#     # below 3 need to process from strach.
#     '/home/lq53/mir_data/24summ/2024_06_26/1686940_left', #validation set
#     '/home/lq53/mir_data/24summ/2024_06_28/1686941_left_right_2', 
#     '/home/lq53/mir_data/24summ/2024_07_12/240605PMC1_right_hole_11_27',


#     # # labels
#     "/home/lq53/mir_data/24summ/2024_07_10/1691485_no_hole_habituation_13_59",
#     "/home/lq53/mir_data/24summ/2024_07_11/1691485BMCFF1505",
#     "/home/lq53/mir_data/24summ/2024_07_10/1691485_left_hole_saline_10_35",
#     "/home/lq53/mir_data/24summ/2024_07_03/1691486_left_right_habituation",
#     "/home/lq53/mir_data/24summ/2024_07_19/240605PMC_window2_right2holes_12_14",
#     # #below are my labels.
#     # "/home/lq53/mir_data/24summ/2024_07_03/1691486_left_right_habituation",
#     # "/home/lq53/mir_data/24summ/2024_07_12/240605PMC1_right_hole_11_27" #this one did not work
#     "/home/lq53/mir_data/24summ/2024_07_16/1691485RMHBN1405",
#     "/home/lq53/mir_data/24summ/2024_07_15/1691485RMPBS1659",
#     "/home/lq53/mir_data/24summ/2024_07_19/240605PMC_window2_right2holes_11_30",
#     "/home/lq53/mir_data/24summ/2024_07_15/1691485RMHBN1425",
#     "/home/lq53/mir_data/24summ/2024_07_15/1691485RMPBF1531"


#     # 'G:\\Videos\\6cam\\lq53\\Mir_intrinsics\\pyxy3d_noT'
#     # '/n/olveczky_lab_tier1/Lab/dannce_rig2/data/M1-M7_photometry/Alone', SYNTAX_ERROR_UPDATE_THIS_WITH_YOUR_OWN_FILES
#     # '/n/holylabs/LABS/olveczky_lab/Lab/dannce-dev/hannah-data/COM_DANNCE_TRAINING'
# ]

dannce_mat_files = []
calibration_files = []
com3d_files = []

for base_path in base_paths:
    # for p in Path(base_path).glob("label*/df_*_dannce.mat"): #**/ 
    #     if p.name.startswith("._"): 
    #         continue
    #     dannce_mat_files.append(str(p))

    for p in Path(base_path).glob("2024_*/[0-9]*/df_converted_pos_synced_*label3d_dannce.mat"): #**/calibration/
        if p.name.startswith("._"):
            continue
        calibration_files.append(str(p))    

    # for p in Path(base_path).glob("hires_cam*_params.mat"): #**/calibration/
    #     if p.name.startswith("._"):
    #         continue
    #     calibration_files.append(str(p))

    for p in Path(base_path).glob("2024_*/[0-9]*/COM_df_final/predict_results/com3d.mat"):
        if p.name.startswith("._"):
            continue
        com3d_files.append(str(p))


dannce_mat_files = sorted(dannce_mat_files)
calibration_files = sorted(calibration_files)
com3d_files = sorted(com3d_files)

print("\nDANNCE Mat files")
pp(dannce_mat_files)

print("\nCalibration Files")
pp(calibration_files)

print("\nCom3D Files")
pp(com3d_files)

allfiles = []
allfiles.extend(dannce_mat_files)
allfiles.extend(calibration_files)
allfiles.extend(com3d_files)
# Out:
# DANNCE Mat files
# []
#
# Calibration Files
# ['/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_26/1686940_left/df_converted_pos_synced_1686940_left_2024_06_26_1686940_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_26/1686940_left2/df_converted_pos_synced_1686940_left2_2024_06_26_1686940_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_26/1686940_no_holes/df_converted_pos_synced_1686940_no_holes_2024_06_26_1686940_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_27/1686940_left_right_2/df_converted_pos_synced_2024_06_27_1686940_1686941_lefts_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_27/1686941_left/df_converted_pos_synced_1686941_left_lefts_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_27/1686941_left_right/df_converted_pos_synced_2024_06_27_1686940_1686941_lefts_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_28/1686941_left_right_2/df_converted_pos_synced_1686941_left_right_2_2024_06_28_1686941_left_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_28/1686941_no_hole/df_converted_pos_synced_1686941_no_hole_2024_06_28_1686941_left_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_28/1686941_no_hole_2/df_converted_pos_synced_1686941_no_hole_2_2024_06_28_1686941_left_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_01/230815PMC_left_hole_baseline_14_32/df_converted_pos_synced_230815PMC_left_hole_baseline_14_32_calib_noon_1_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_01/230815PMC_left_hole_caffeine_15_32/df_converted_pos_synced_230815PMC_left_hole_caffeine_15_32_calib_noon_1_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_01/230815PMC_no_hole_caffine_13_56/df_converted_pos_synced_230815PMC_no_hole_caffine_13_56_calib_noon_1_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_02/1691486_left_habituation/df_converted_pos_synced_1691486_left_habituation_calib_before_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_02/1691486_left_right_habituation/df_converted_pos_synced_1691486_left_right_habituation_calib_before_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_02/1691486_left_right_saline_1430/df_converted_pos_synced_1691486_left_right_saline_1430_calib_before_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_02/1691486_left_right_saline_1505/df_converted_pos_synced_1691486_left_right_saline_1505_calib_before_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_02/1691486_left_saline_1016/df_converted_pos_synced_1691486_left_saline_1016_calib_before_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_02/1691486_left_saline_1051/df_converted_pos_synced_1691486_left_saline_1051_calib_before_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_03/1691486_left_caffeine_1051/df_converted_pos_synced_1691486_left_caffeine_1051_calib_before_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_03/1691486_left_caffeine_1128/df_converted_pos_synced_1691486_left_caffeine_1128_calib_before_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_03/1691486_left_right_caffeine_1448/df_converted_pos_synced_1691486_left_right_caffeine_1448_calib_before_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_03/1691486_left_right_caffeine_1546/df_converted_pos_synced_1691486_left_right_caffeine_1546_calib_before_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_03/1691486_left_right_habituation/df_converted_pos_synced_1691486_left_right_habituation_calib_before_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_08/1691486_no_hole_habituation_938/df_converted_pos_synced_1691486_no_hole_habituation_938_calib_before_no_hole_935_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_08/1691486_no_hole_saline_1029/df_converted_pos_synced_1691486_no_hole_saline_1029_calib_before_no_hole_935_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_08/1691486_no_hole_saline_1054_test/df_converted_pos_synced_1691486_no_hole_saline_1054_test_calib_before_no_hole_935_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_08/1691486_no_hole_saline_2_1123_test/df_converted_pos_synced_1691486_no_hole_saline_2_1123_test_calib_before_no_hole_935_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_08/1691486_right_baseline_1353/df_converted_pos_synced_1691486_right_baseline_1353_calib_before_no_hole_935_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_08/1691486_right_baseline_1500/df_converted_pos_synced_1691486_right_baseline_1500_calib_before_no_hole_935_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_08/1691486_right_baseline_1533/df_converted_pos_synced_1691486_right_baseline_1533_calib_before_no_hole_935_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_09/1691485_left_hole_habituation/df_converted_pos_synced_1691485_left_hole_habituation_calib_before_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_09/1691485_no_hole_caffeine_1041/df_converted_pos_synced_1691485_no_hole_caffeine_1041_calib_before_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_09/1691485_no_hole_caffeine_1118/df_converted_pos_synced_1691485_no_hole_caffeine_1118_calib_before_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_09/1691485_no_hole_habituation/df_converted_pos_synced_1691485_no_hole_habituation_calib_before_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_09/1691486_right_hole_caffine_15_31/df_converted_pos_synced_1691486_right_hole_caffine_15_31_calib_before_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_09/1691486_right_hole_caffine_16_18/df_converted_pos_synced_1691486_right_hole_caffine_16_18_calib_before_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_09/1691486_right_hole_habituation_14_39/df_converted_pos_synced_1691486_right_hole_habituation_14_39_calib_before_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_10/1691485_left_hole_habituation/df_converted_pos_synced_1691485_left_hole_habituation_calib_before_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_10/1691485_left_hole_saline_10_35/df_converted_pos_synced_1691485_left_hole_saline_10_35_calib_before_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_10/1691485_left_hole_saline_11_10/df_converted_pos_synced_1691485_left_hole_saline_11_10_calib_before_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_10/1691485_left_right_habituation_14_46/df_converted_pos_synced_1691485_left_right_habituation_14_46_calib_before_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_10/1691485_left_right_saline_15_34/df_converted_pos_synced_1691485_left_right_saline_15_34_calib_before_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_10/1691485_no_hole_habituation_13_59/df_converted_pos_synced_1691485_no_hole_habituation_13_59_calib_before_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_11/1691485BMCFF1505/df_converted_pos_synced_1691485BMCFF1505_calib_before_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_11/1691485BMCFS1547/df_converted_pos_synced_1691485BMCFS1547_calib_before_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_11/1691485BMHBN1359/df_converted_pos_synced_1691485BMHBN1359_calib_before_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_11/1691485LMCFS1129/df_converted_pos_synced_1691485LMCFS1129_calib_before_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_12/240605PMC1_right_hole_11_27/df_converted_pos_synced_240605PMC1_right_hole_11_27_calib_test_offset_3_38_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_12/240626V1_right_hole_10_31/df_converted_pos_synced_240626V1_right_hole_10_31_calib_test_offset_3_38_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_15/1691485RMHBN1425/df_converted_pos_synced_1691485RMHBN1425_calib_before_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_15/1691485RMPBF1531/df_converted_pos_synced_1691485RMPBF1531_calib_before_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_15/1691485RMPBS1659/df_converted_pos_synced_1691485RMPBS1659_calib_before_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_16/1691485RMCFF1500/df_converted_pos_synced_1691485RMCFF1500_calib_test_offset_3_38_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_16/1691485RMCFS1535/df_converted_pos_synced_1691485RMCFS1535_calib_test_offset_3_38_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_16/1691485RMHBN1405/df_converted_pos_synced_1691485RMHBN1405_calib_test_offset_3_38_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_16/1691486NMCFF1033/df_converted_pos_synced_1691486NMCFF1033_calib_test_offset_3_38_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_16/1691486NMCFS1123/df_converted_pos_synced_1691486NMCFS1123_calib_test_offset_3_38_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_16/1691486NMHBN0927/df_converted_pos_synced_1691486NMHBN0927_calib_test_offset_3_38_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_19/240605PMC_window2_right2holes_11_30/df_converted_pos_synced_240605PMC_window2_right2holes_11_30_calib_test_offset_3_38_label3d_dannce.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_19/240605PMC_window2_right2holes_12_14/df_converted_pos_synced_240605PMC_window2_right2holes_12_14_calib_test_offset_3_38_label3d_dannce.mat']
#
# Com3D Files
# ['/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_03/1691486_left_right_habituation/COM_df_final/predict_results/com3d.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_10/1691485_left_hole_saline_10_35/COM_df_final/predict_results/com3d.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_10/1691485_no_hole_habituation_13_59/COM_df_final/predict_results/com3d.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_11/1691485BMCFF1505/COM_df_final/predict_results/com3d.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_15/1691485RMHBN1425/COM_df_final/predict_results/com3d.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_15/1691485RMPBF1531/COM_df_final/predict_results/com3d.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_15/1691485RMPBS1659/COM_df_final/predict_results/com3d.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_16/1691485RMHBN1405/COM_df_final/predict_results/com3d.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_19/240605PMC_window2_right2holes_11_30/COM_df_final/predict_results/com3d.mat',
#  '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_19/240605PMC_window2_right2holes_12_14/COM_df_final/predict_results/com3d.mat']

# %%
# UPDATE THIS TO MAKE PATHS RELATIVE TO SOME BASE PATH
# e.g. /n/holylabs/LABS/olveckzy/Alone/M1/dannce.mat -> ./Alone/M1/dannce.mat
# allfiles = list(map(lambda x: x.replace(r"/net/holy-nfsisilon/ifs/rc_labs/olveczky_lab_tier1/Lab/dannce_rig2/data/M1-M7_photometry", "."), allfiles))
allfiles = list(map(lambda x: x.replace(r"/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ", "."), allfiles)) #2024_06_28/1686941_left_right_2

# create rsync file list
with open("file-list_3", "wt") as f:
    for p in allfiles:
        f.write(f"{p}\n")

####
# You can use RSYNC to create a clone of files listed in allfiles
### HOWEVER YOU NEED TO DO THIS 1x BASEPATH AT A TIME ###
### e.g. comment out other so that base_paths list len is 1
### and re-run above code and rsync command for each

### EXAMPLE RSYNC COMMAND
# rsync -avR --files-from=./file-list /n/olveczky_lab_tier1/Lab/dannce_rig2/data/M1-M7_photometry ./backup-files-rot-fix
# !rsync -avR --files-from=./file-list G:\\Videos\\6cam\\lq53\\Mir_intrinsics\\pyxy3d_noT ./backup-files-rot-fix
# !rsync -avR --files-from=./file-list /home/lq53/mir_data/24summ/2024_06_28/1686941_left_right_2 /home/lq53/mir_data/24summ/2024_06_28/1686941_left_right_2/backup-files-rot-fix
### NOTE ON RSYNC ARGS:
### rsync -avR --files-from=FILE_LIST RSYNC_SRC RSYNC_DEST
### --avR : use archive mode, print extra output (verbose), and build relative tree (relative to dot "." in file list)
### --files-from=FILE_LIST : FILE_LIST is a text file with where each line is a file to copy, relative to RSYNC_SRC
### RSYNC_SRC : directory to look for files-from within. This is also where the dest file paths are relative to.
### RSYNC_DEST : directory where the file copies will be stored.

# %%
# !rsync -avR --files-from=./file-list_3 /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/backup-files-rot-fix_240830
# Out:
# building file list ... done
# created directory /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/backup-files-rot-fix_240830
# ./
# 2024_06_26/
# 2024_06_26/1686940_left/
# 2024_06_26/1686940_left/df_converted_pos_synced_1686940_left_2024_06_26_1686940_label3d_dannce.mat
# 2024_06_26/1686940_left2/
# 2024_06_26/1686940_left2/df_converted_pos_synced_1686940_left2_2024_06_26_1686940_label3d_dannce.mat
# 2024_06_26/1686940_no_holes/
# 2024_06_26/1686940_no_holes/df_converted_pos_synced_1686940_no_holes_2024_06_26_1686940_label3d_dannce.mat
# 2024_06_27/
# 2024_06_27/1686940_left_right_2/
# 2024_06_27/1686940_left_right_2/df_converted_pos_synced_2024_06_27_1686940_1686941_lefts_label3d_dannce.mat
# 2024_06_27/1686941_left/
# 2024_06_27/1686941_left/df_converted_pos_synced_1686941_left_lefts_label3d_dannce.mat
# 2024_06_27/1686941_left_right/
# 2024_06_27/1686941_left_right/df_converted_pos_synced_2024_06_27_1686940_1686941_lefts_label3d_dannce.mat
# 2024_06_28/
# 2024_06_28/1686941_left_right_2/
# 2024_06_28/1686941_left_right_2/df_converted_pos_synced_1686941_left_right_2_2024_06_28_1686941_left_label3d_dannce.mat
# 2024_06_28/1686941_no_hole/
# 2024_06_28/1686941_no_hole/df_converted_pos_synced_1686941_no_hole_2024_06_28_1686941_left_label3d_dannce.mat
# 2024_06_28/1686941_no_hole_2/
# 2024_06_28/1686941_no_hole_2/df_converted_pos_synced_1686941_no_hole_2_2024_06_28_1686941_left_label3d_dannce.mat
# 2024_07_01/
# 2024_07_01/230815PMC_left_hole_baseline_14_32/
# 2024_07_01/230815PMC_left_hole_baseline_14_32/df_converted_pos_synced_230815PMC_left_hole_baseline_14_32_calib_noon_1_label3d_dannce.mat
# 2024_07_01/230815PMC_left_hole_caffeine_15_32/
# 2024_07_01/230815PMC_left_hole_caffeine_15_32/df_converted_pos_synced_230815PMC_left_hole_caffeine_15_32_calib_noon_1_label3d_dannce.mat
# 2024_07_01/230815PMC_no_hole_caffine_13_56/
# 2024_07_01/230815PMC_no_hole_caffine_13_56/df_converted_pos_synced_230815PMC_no_hole_caffine_13_56_calib_noon_1_label3d_dannce.mat
# 2024_07_02/
# 2024_07_02/1691486_left_habituation/
# 2024_07_02/1691486_left_habituation/df_converted_pos_synced_1691486_left_habituation_calib_before_label3d_dannce.mat
# 2024_07_02/1691486_left_right_habituation/
# 2024_07_02/1691486_left_right_habituation/df_converted_pos_synced_1691486_left_right_habituation_calib_before_label3d_dannce.mat
# 2024_07_02/1691486_left_right_saline_1430/
# 2024_07_02/1691486_left_right_saline_1430/df_converted_pos_synced_1691486_left_right_saline_1430_calib_before_label3d_dannce.mat
# 2024_07_02/1691486_left_right_saline_1505/
# 2024_07_02/1691486_left_right_saline_1505/df_converted_pos_synced_1691486_left_right_saline_1505_calib_before_label3d_dannce.mat
# 2024_07_02/1691486_left_saline_1016/
# 2024_07_02/1691486_left_saline_1016/df_converted_pos_synced_1691486_left_saline_1016_calib_before_label3d_dannce.mat
# 2024_07_02/1691486_left_saline_1051/
# 2024_07_02/1691486_left_saline_1051/df_converted_pos_synced_1691486_left_saline_1051_calib_before_label3d_dannce.mat
# 2024_07_03/
# 2024_07_03/1691486_left_caffeine_1051/
# 2024_07_03/1691486_left_caffeine_1051/df_converted_pos_synced_1691486_left_caffeine_1051_calib_before_label3d_dannce.mat
# 2024_07_03/1691486_left_caffeine_1128/
# 2024_07_03/1691486_left_caffeine_1128/df_converted_pos_synced_1691486_left_caffeine_1128_calib_before_label3d_dannce.mat
# 2024_07_03/1691486_left_right_caffeine_1448/
# 2024_07_03/1691486_left_right_caffeine_1448/df_converted_pos_synced_1691486_left_right_caffeine_1448_calib_before_label3d_dannce.mat
# 2024_07_03/1691486_left_right_caffeine_1546/
# 2024_07_03/1691486_left_right_caffeine_1546/df_converted_pos_synced_1691486_left_right_caffeine_1546_calib_before_label3d_dannce.mat
# 2024_07_03/1691486_left_right_habituation/
# 2024_07_03/1691486_left_right_habituation/df_converted_pos_synced_1691486_left_right_habituation_calib_before_label3d_dannce.mat
# 2024_07_03/1691486_left_right_habituation/COM_df_final/
# 2024_07_03/1691486_left_right_habituation/COM_df_final/predict_results/
# 2024_07_03/1691486_left_right_habituation/COM_df_final/predict_results/com3d.mat
# 2024_07_08/
# 2024_07_08/1691486_no_hole_habituation_938/
# 2024_07_08/1691486_no_hole_habituation_938/df_converted_pos_synced_1691486_no_hole_habituation_938_calib_before_no_hole_935_label3d_dannce.mat
# 2024_07_08/1691486_no_hole_saline_1029/
# 2024_07_08/1691486_no_hole_saline_1029/df_converted_pos_synced_1691486_no_hole_saline_1029_calib_before_no_hole_935_label3d_dannce.mat
# 2024_07_08/1691486_no_hole_saline_1054_test/
# 2024_07_08/1691486_no_hole_saline_1054_test/df_converted_pos_synced_1691486_no_hole_saline_1054_test_calib_before_no_hole_935_label3d_dannce.mat
# 2024_07_08/1691486_no_hole_saline_2_1123_test/
# 2024_07_08/1691486_no_hole_saline_2_1123_test/df_converted_pos_synced_1691486_no_hole_saline_2_1123_test_calib_before_no_hole_935_label3d_dannce.mat
# 2024_07_08/1691486_right_baseline_1353/
# 2024_07_08/1691486_right_baseline_1353/df_converted_pos_synced_1691486_right_baseline_1353_calib_before_no_hole_935_label3d_dannce.mat
# 2024_07_08/1691486_right_baseline_1500/
# 2024_07_08/1691486_right_baseline_1500/df_converted_pos_synced_1691486_right_baseline_1500_calib_before_no_hole_935_label3d_dannce.mat
# 2024_07_08/1691486_right_baseline_1533/
# 2024_07_08/1691486_right_baseline_1533/df_converted_pos_synced_1691486_right_baseline_1533_calib_before_no_hole_935_label3d_dannce.mat
# 2024_07_09/
# 2024_07_09/1691485_left_hole_habituation/
# 2024_07_09/1691485_left_hole_habituation/df_converted_pos_synced_1691485_left_hole_habituation_calib_before_label3d_dannce.mat
# 2024_07_09/1691485_no_hole_caffeine_1041/
# 2024_07_09/1691485_no_hole_caffeine_1041/df_converted_pos_synced_1691485_no_hole_caffeine_1041_calib_before_label3d_dannce.mat
# 2024_07_09/1691485_no_hole_caffeine_1118/
# 2024_07_09/1691485_no_hole_caffeine_1118/df_converted_pos_synced_1691485_no_hole_caffeine_1118_calib_before_label3d_dannce.mat
# 2024_07_09/1691485_no_hole_habituation/
# 2024_07_09/1691485_no_hole_habituation/df_converted_pos_synced_1691485_no_hole_habituation_calib_before_label3d_dannce.mat
# 2024_07_09/1691486_right_hole_caffine_15_31/
# 2024_07_09/1691486_right_hole_caffine_15_31/df_converted_pos_synced_1691486_right_hole_caffine_15_31_calib_before_label3d_dannce.mat
# 2024_07_09/1691486_right_hole_caffine_16_18/
# 2024_07_09/1691486_right_hole_caffine_16_18/df_converted_pos_synced_1691486_right_hole_caffine_16_18_calib_before_label3d_dannce.mat
# 2024_07_09/1691486_right_hole_habituation_14_39/
# 2024_07_09/1691486_right_hole_habituation_14_39/df_converted_pos_synced_1691486_right_hole_habituation_14_39_calib_before_label3d_dannce.mat
# 2024_07_10/
# 2024_07_10/1691485_left_hole_habituation/
# 2024_07_10/1691485_left_hole_habituation/df_converted_pos_synced_1691485_left_hole_habituation_calib_before_label3d_dannce.mat
# 2024_07_10/1691485_left_hole_saline_10_35/
# 2024_07_10/1691485_left_hole_saline_10_35/df_converted_pos_synced_1691485_left_hole_saline_10_35_calib_before_label3d_dannce.mat
# 2024_07_10/1691485_left_hole_saline_10_35/COM_df_final/
# 2024_07_10/1691485_left_hole_saline_10_35/COM_df_final/predict_results/
# 2024_07_10/1691485_left_hole_saline_10_35/COM_df_final/predict_results/com3d.mat
# 2024_07_10/1691485_left_hole_saline_11_10/
# 2024_07_10/1691485_left_hole_saline_11_10/df_converted_pos_synced_1691485_left_hole_saline_11_10_calib_before_label3d_dannce.mat
# 2024_07_10/1691485_left_right_habituation_14_46/
# 2024_07_10/1691485_left_right_habituation_14_46/df_converted_pos_synced_1691485_left_right_habituation_14_46_calib_before_label3d_dannce.mat
# 2024_07_10/1691485_left_right_saline_15_34/
# 2024_07_10/1691485_left_right_saline_15_34/df_converted_pos_synced_1691485_left_right_saline_15_34_calib_before_label3d_dannce.mat
# 2024_07_10/1691485_no_hole_habituation_13_59/
# 2024_07_10/1691485_no_hole_habituation_13_59/df_converted_pos_synced_1691485_no_hole_habituation_13_59_calib_before_label3d_dannce.mat
# 2024_07_10/1691485_no_hole_habituation_13_59/COM_df_final/
# 2024_07_10/1691485_no_hole_habituation_13_59/COM_df_final/predict_results/
# 2024_07_10/1691485_no_hole_habituation_13_59/COM_df_final/predict_results/com3d.mat
# 2024_07_11/
# 2024_07_11/1691485BMCFF1505/
# 2024_07_11/1691485BMCFF1505/df_converted_pos_synced_1691485BMCFF1505_calib_before_label3d_dannce.mat
# 2024_07_11/1691485BMCFF1505/COM_df_final/
# 2024_07_11/1691485BMCFF1505/COM_df_final/predict_results/
# 2024_07_11/1691485BMCFF1505/COM_df_final/predict_results/com3d.mat
# 2024_07_11/1691485BMCFS1547/
# 2024_07_11/1691485BMCFS1547/df_converted_pos_synced_1691485BMCFS1547_calib_before_label3d_dannce.mat
# 2024_07_11/1691485BMHBN1359/
# 2024_07_11/1691485BMHBN1359/df_converted_pos_synced_1691485BMHBN1359_calib_before_label3d_dannce.mat
# 2024_07_11/1691485LMCFS1129/
# 2024_07_11/1691485LMCFS1129/df_converted_pos_synced_1691485LMCFS1129_calib_before_label3d_dannce.mat
# 2024_07_12/
# 2024_07_12/240605PMC1_right_hole_11_27/
# 2024_07_12/240605PMC1_right_hole_11_27/df_converted_pos_synced_240605PMC1_right_hole_11_27_calib_test_offset_3_38_label3d_dannce.mat
# 2024_07_12/240626V1_right_hole_10_31/
# 2024_07_12/240626V1_right_hole_10_31/df_converted_pos_synced_240626V1_right_hole_10_31_calib_test_offset_3_38_label3d_dannce.mat
# 2024_07_15/
# 2024_07_15/1691485RMHBN1425/
# 2024_07_15/1691485RMHBN1425/df_converted_pos_synced_1691485RMHBN1425_calib_before_label3d_dannce.mat
# 2024_07_15/1691485RMHBN1425/COM_df_final/
# 2024_07_15/1691485RMHBN1425/COM_df_final/predict_results/
# 2024_07_15/1691485RMHBN1425/COM_df_final/predict_results/com3d.mat
# 2024_07_15/1691485RMPBF1531/
# 2024_07_15/1691485RMPBF1531/df_converted_pos_synced_1691485RMPBF1531_calib_before_label3d_dannce.mat
# 2024_07_15/1691485RMPBF1531/COM_df_final/
# 2024_07_15/1691485RMPBF1531/COM_df_final/predict_results/
# 2024_07_15/1691485RMPBF1531/COM_df_final/predict_results/com3d.mat
# 2024_07_15/1691485RMPBS1659/
# 2024_07_15/1691485RMPBS1659/df_converted_pos_synced_1691485RMPBS1659_calib_before_label3d_dannce.mat
# 2024_07_15/1691485RMPBS1659/COM_df_final/
# 2024_07_15/1691485RMPBS1659/COM_df_final/predict_results/
# 2024_07_15/1691485RMPBS1659/COM_df_final/predict_results/com3d.mat
# 2024_07_16/
# 2024_07_16/1691485RMCFF1500/
# 2024_07_16/1691485RMCFF1500/df_converted_pos_synced_1691485RMCFF1500_calib_test_offset_3_38_label3d_dannce.mat
# 2024_07_16/1691485RMCFS1535/
# 2024_07_16/1691485RMCFS1535/df_converted_pos_synced_1691485RMCFS1535_calib_test_offset_3_38_label3d_dannce.mat
# 2024_07_16/1691485RMHBN1405/
# 2024_07_16/1691485RMHBN1405/df_converted_pos_synced_1691485RMHBN1405_calib_test_offset_3_38_label3d_dannce.mat
# 2024_07_16/1691485RMHBN1405/COM_df_final/
# 2024_07_16/1691485RMHBN1405/COM_df_final/predict_results/
# 2024_07_16/1691485RMHBN1405/COM_df_final/predict_results/com3d.mat
# 2024_07_16/1691486NMCFF1033/
# 2024_07_16/1691486NMCFF1033/df_converted_pos_synced_1691486NMCFF1033_calib_test_offset_3_38_label3d_dannce.mat
# 2024_07_16/1691486NMCFS1123/
# 2024_07_16/1691486NMCFS1123/df_converted_pos_synced_1691486NMCFS1123_calib_test_offset_3_38_label3d_dannce.mat
# 2024_07_16/1691486NMHBN0927/
# 2024_07_16/1691486NMHBN0927/df_converted_pos_synced_1691486NMHBN0927_calib_test_offset_3_38_label3d_dannce.mat
# 2024_07_19/
# 2024_07_19/240605PMC_window2_right2holes_11_30/
# 2024_07_19/240605PMC_window2_right2holes_11_30/df_converted_pos_synced_240605PMC_window2_right2holes_11_30_calib_test_offset_3_38_label3d_dannce.mat
# 2024_07_19/240605PMC_window2_right2holes_11_30/COM_df_final/
# 2024_07_19/240605PMC_window2_right2holes_11_30/COM_df_final/predict_results/
# 2024_07_19/240605PMC_window2_right2holes_11_30/COM_df_final/predict_results/com3d.mat
# 2024_07_19/240605PMC_window2_right2holes_12_14/
# 2024_07_19/240605PMC_window2_right2holes_12_14/df_converted_pos_synced_240605PMC_window2_right2holes_12_14_calib_test_offset_3_38_label3d_dannce.mat
# 2024_07_19/240605PMC_window2_right2holes_12_14/COM_df_final/
# 2024_07_19/240605PMC_window2_right2holes_12_14/COM_df_final/predict_results/
# 2024_07_19/240605PMC_window2_right2holes_12_14/COM_df_final/predict_results/com3d.mat
#
# sent 11,980,412,685 bytes  received 1,729 bytes  80,136,551.26 bytes/sec
# total size is 11,977,475,400  speedup is 1.00

# %%
### RUN FIX ON EACH LIST OF FILES ###
######################################################################
### I WOULD UN-COMMENT AND RUN ONE GROUP AT A TIME 
### IF THERE IS AN ERROR WITH ONE OF THE FILES, YOU CAN CONTINUE AFTER
###    A CERTAIN INDEX. E.G. 5
###
### for i,f in enumerate(calibration_files[5:]): ...
#######################################################################

for i,f in enumerate(calibration_files):
    print (f"calib_file: [{i}]:" ,f)
    # update_hires_file(f, f)
    try:
        # revert_backup_samedir(f)
        update_calib_for_dannce(f, f)  # for calibs
    except Exception as e:
        print(f"Skipping file {f} due to: {e}")
        continue    
    # update_calib_for_dannce(f,f) #for calibs
        
# for i,f in enumerate(dannce_mat_files):
#     print (f"dannce.mat: [{i}]:" ,f)
#     #in case still some calib files are taken in as label files...
#     # if "pos" in f:
#     #     try:
#     #         update_calib_for_dannce(f, f)  # for calibs
#     #     except Exception as e:
#     #         print(f"Skipping file {f} due to: {e}")
#     #         continue
#         # update_calib_for_dannce(f,f) #for calibs
#     # else:
#     try:
#         # revert_backup_samedir(f)
#         update_dannce_mat_file(f, f)  # for calibs
#     except Exception as e:
#         print(f"Skipping file {f} due to: {e}")
#         continue
        
        # update_dannce_mat_file(f,f) # for labels

for i,f in enumerate(com3d_files):
    print (f"c3d: [{i}]:" ,f)
    try:
        update_com3d_file(f, f)  # for calibs
    except Exception as e:
        print(f"Skipping file {f} due to: {e}")
        continue
    # update_com3d_file(f,f)
# Out:
# calib_file: [0]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_26/1686940_left/df_converted_pos_synced_1686940_left_2024_06_26_1686940_label3d_dannce.mat
# update_dannce_mat_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_26/1686940_left/df_converted_pos_synced_1686940_left_2024_06_26_1686940_label3d_dannce.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_26/1686940_left/df_converted_pos_synced_1686940_left_2024_06_26_1686940_label3d_dannce.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_26/1686940_left/df_converted_pos_synced_1686940_left_2024_06_26_1686940_label3d_dannce.mat.old
# updating rot mtx for cam_idx=0
# updating rot mtx for cam_idx=1
# updating rot mtx for cam_idx=2
# updating rot mtx for cam_idx=3
# updating rot mtx for cam_idx=4
# updating rot mtx for cam_idx=5
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_26/1686940_left/df_converted_pos_synced_1686940_left_2024_06_26_1686940_label3d_dannce.mat
# calib_file: [1]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_26/1686940_left2/df_converted_pos_synced_1686940_left2_2024_06_26_1686940_label3d_dannce.mat
# update_dannce_mat_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_26/1686940_left2/df_converted_pos_synced_1686940_left2_2024_06_26_1686940_label3d_dannce.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_26/1686940_left2/df_converted_pos_synced_1686940_left2_2024_06_26_1686940_label3d_dannce.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_26/1686940_left2/df_converted_pos_synced_1686940_left2_2024_06_26_1686940_label3d_dannce.mat.old
# updating rot mtx for cam_idx=0
# updating rot mtx for cam_idx=1
# updating rot mtx for cam_idx=2
# updating rot mtx for cam_idx=3
# updating rot mtx for cam_idx=4
# updating rot mtx for cam_idx=5
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_26/1686940_left2/df_converted_pos_synced_1686940_left2_2024_06_26_1686940_label3d_dannce.mat
# calib_file: [2]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_26/1686940_no_holes/df_converted_pos_synced_1686940_no_holes_2024_06_26_1686940_label3d_dannce.mat
# update_dannce_mat_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_26/1686940_no_holes/df_converted_pos_synced_1686940_no_holes_2024_06_26_1686940_label3d_dannce.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_26/1686940_no_holes/df_converted_pos_synced_1686940_no_holes_2024_06_26_1686940_label3d_dannce.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_26/1686940_no_holes/df_converted_pos_synced_1686940_no_holes_2024_06_26_1686940_label3d_dannce.mat.old
# updating rot mtx for cam_idx=0
# updating rot mtx for cam_idx=1
# updating rot mtx for cam_idx=2
# updating rot mtx for cam_idx=3
# updating rot mtx for cam_idx=4
# updating rot mtx for cam_idx=5
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_26/1686940_no_holes/df_converted_pos_synced_1686940_no_holes_2024_06_26_1686940_label3d_dannce.mat
# calib_file: [3]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_27/1686940_left_right_2/df_converted_pos_synced_2024_06_27_1686940_1686941_lefts_label3d_dannce.mat
# update_dannce_mat_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_27/1686940_left_right_2/df_converted_pos_synced_2024_06_27_1686940_1686941_lefts_label3d_dannce.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_27/1686940_left_right_2/df_converted_pos_synced_2024_06_27_1686940_1686941_lefts_label3d_dannce.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_27/1686940_left_right_2/df_converted_pos_synced_2024_06_27_1686940_1686941_lefts_label3d_dannce.mat.old
# updating rot mtx for cam_idx=0
# updating rot mtx for cam_idx=1
# updating rot mtx for cam_idx=2
# updating rot mtx for cam_idx=3
# updating rot mtx for cam_idx=4
# updating rot mtx for cam_idx=5
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_27/1686940_left_right_2/df_converted_pos_synced_2024_06_27_1686940_1686941_lefts_label3d_dannce.mat
# calib_file: [4]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_27/1686941_left/df_converted_pos_synced_1686941_left_lefts_label3d_dannce.mat
# update_dannce_mat_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_27/1686941_left/df_converted_pos_synced_1686941_left_lefts_label3d_dannce.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_27/1686941_left/df_converted_pos_synced_1686941_left_lefts_label3d_dannce.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_27/1686941_left/df_converted_pos_synced_1686941_left_lefts_label3d_dannce.mat.old
# updating rot mtx for cam_idx=0
# updating rot mtx for cam_idx=1
# updating rot mtx for cam_idx=2
# updating rot mtx for cam_idx=3
# updating rot mtx for cam_idx=4
# updating rot mtx for cam_idx=5
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_27/1686941_left/df_converted_pos_synced_1686941_left_lefts_label3d_dannce.mat
# calib_file: [5]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_27/1686941_left_right/df_converted_pos_synced_2024_06_27_1686940_1686941_lefts_label3d_dannce.mat
# update_dannce_mat_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_27/1686941_left_right/df_converted_pos_synced_2024_06_27_1686940_1686941_lefts_label3d_dannce.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_27/1686941_left_right/df_converted_pos_synced_2024_06_27_1686940_1686941_lefts_label3d_dannce.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_27/1686941_left_right/df_converted_pos_synced_2024_06_27_1686940_1686941_lefts_label3d_dannce.mat.old
# updating rot mtx for cam_idx=0
# updating rot mtx for cam_idx=1
# updating rot mtx for cam_idx=2
# updating rot mtx for cam_idx=3
# updating rot mtx for cam_idx=4
# updating rot mtx for cam_idx=5
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_27/1686941_left_right/df_converted_pos_synced_2024_06_27_1686940_1686941_lefts_label3d_dannce.mat
# calib_file: [6]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_28/1686941_left_right_2/df_converted_pos_synced_1686941_left_right_2_2024_06_28_1686941_left_label3d_dannce.mat
# update_dannce_mat_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_28/1686941_left_right_2/df_converted_pos_synced_1686941_left_right_2_2024_06_28_1686941_left_label3d_dannce.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_28/1686941_left_right_2/df_converted_pos_synced_1686941_left_right_2_2024_06_28_1686941_left_label3d_dannce.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_28/1686941_left_right_2/df_converted_pos_synced_1686941_left_right_2_2024_06_28_1686941_left_label3d_dannce.mat.old
# updating rot mtx for cam_idx=0
# updating rot mtx for cam_idx=1
# updating rot mtx for cam_idx=2
# updating rot mtx for cam_idx=3
# updating rot mtx for cam_idx=4
# updating rot mtx for cam_idx=5
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_28/1686941_left_right_2/df_converted_pos_synced_1686941_left_right_2_2024_06_28_1686941_left_label3d_dannce.mat
# calib_file: [7]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_28/1686941_no_hole/df_converted_pos_synced_1686941_no_hole_2024_06_28_1686941_left_label3d_dannce.mat
# update_dannce_mat_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_28/1686941_no_hole/df_converted_pos_synced_1686941_no_hole_2024_06_28_1686941_left_label3d_dannce.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_28/1686941_no_hole/df_converted_pos_synced_1686941_no_hole_2024_06_28_1686941_left_label3d_dannce.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_28/1686941_no_hole/df_converted_pos_synced_1686941_no_hole_2024_06_28_1686941_left_label3d_dannce.mat.old
# updating rot mtx for cam_idx=0
# updating rot mtx for cam_idx=1
# updating rot mtx for cam_idx=2
# updating rot mtx for cam_idx=3
# updating rot mtx for cam_idx=4
# updating rot mtx for cam_idx=5
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_28/1686941_no_hole/df_converted_pos_synced_1686941_no_hole_2024_06_28_1686941_left_label3d_dannce.mat
# calib_file: [8]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_28/1686941_no_hole_2/df_converted_pos_synced_1686941_no_hole_2_2024_06_28_1686941_left_label3d_dannce.mat
# update_dannce_mat_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_28/1686941_no_hole_2/df_converted_pos_synced_1686941_no_hole_2_2024_06_28_1686941_left_label3d_dannce.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_28/1686941_no_hole_2/df_converted_pos_synced_1686941_no_hole_2_2024_06_28_1686941_left_label3d_dannce.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_28/1686941_no_hole_2/df_converted_pos_synced_1686941_no_hole_2_2024_06_28_1686941_left_label3d_dannce.mat.old
# updating rot mtx for cam_idx=0
# updating rot mtx for cam_idx=1
# updating rot mtx for cam_idx=2
# updating rot mtx for cam_idx=3
# updating rot mtx for cam_idx=4
# updating rot mtx for cam_idx=5
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_06_28/1686941_no_hole_2/df_converted_pos_synced_1686941_no_hole_2_2024_06_28_1686941_left_label3d_dannce.mat
# calib_file: [9]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_01/230815PMC_left_hole_baseline_14_32/df_converted_pos_synced_230815PMC_left_hole_baseline_14_32_calib_noon_1_label3d_dannce.mat
# update_dannce_mat_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_01/230815PMC_left_hole_baseline_14_32/df_converted_pos_synced_230815PMC_left_hole_baseline_14_32_calib_noon_1_label3d_dannce.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_01/230815PMC_left_hole_baseline_14_32/df_converted_pos_synced_230815PMC_left_hole_baseline_14_32_calib_noon_1_label3d_dannce.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_01/230815PMC_left_hole_baseline_14_32/df_converted_pos_synced_230815PMC_left_hole_baseline_14_32_calib_noon_1_label3d_dannce.mat.old
# updating rot mtx for cam_idx=0
# updating rot mtx for cam_idx=1
# updating rot mtx for cam_idx=2
# updating rot mtx for cam_idx=3
# updating rot mtx for cam_idx=4
# updating rot mtx for cam_idx=5
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_01/230815PMC_left_hole_baseline_14_32/df_converted_pos_synced_230815PMC_left_hole_baseline_14_32_calib_noon_1_label3d_dannce.mat
# calib_file: [10]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_01/230815PMC_left_hole_caffeine_15_32/df_converted_pos_synced_230815PMC_left_hole_caffeine_15_32_calib_noon_1_label3d_dannce.mat
# update_dannce_mat_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_01/230815PMC_left_hole_caffeine_15_32/df_converted_pos_synced_230815PMC_left_hole_caffeine_15_32_calib_noon_1_label3d_dannce.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_01/230815PMC_left_hole_caffeine_15_32/df_converted_pos_synced_230815PMC_left_hole_caffeine_15_32_calib_noon_1_label3d_dannce.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_01/230815PMC_left_hole_caffeine_15_32/df_converted_pos_synced_230815PMC_left_hole_caffeine_15_32_calib_noon_1_label3d_dannce.mat.old
# updating rot mtx for cam_idx=0
# updating rot mtx for cam_idx=1
# updating rot mtx for cam_idx=2
# updating rot mtx for cam_idx=3
# updating rot mtx for cam_idx=4
# updating rot mtx for cam_idx=5
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_01/230815PMC_left_hole_caffeine_15_32/df_converted_pos_synced_230815PMC_left_hole_caffeine_15_32_calib_noon_1_label3d_dannce.mat
# calib_file: [11]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_01/230815PMC_no_hole_caffine_13_56/df_converted_pos_synced_230815PMC_no_hole_caffine_13_56_calib_noon_1_label3d_dannce.mat
# update_dannce_mat_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_01/230815PMC_no_hole_caffine_13_56/df_converted_pos_synced_230815PMC_no_hole_caffine_13_56_calib_noon_1_label3d_dannce.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_01/230815PMC_no_hole_caffine_13_56/df_converted_pos_synced_230815PMC_no_hole_caffine_13_56_calib_noon_1_label3d_dannce.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_01/230815PMC_no_hole_caffine_13_56/df_converted_pos_synced_230815PMC_no_hole_caffine_13_56_calib_noon_1_label3d_dannce.mat.old
# updating rot mtx for cam_idx=0
# updating rot mtx for cam_idx=1
# updating rot mtx for cam_idx=2
# updating rot mtx for cam_idx=3
# updating rot mtx for cam_idx=4
# updating rot mtx for cam_idx=5
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_01/230815PMC_no_hole_caffine_13_56/df_converted_pos_synced_230815PMC_no_hole_caffine_13_56_calib_noon_1_label3d_dannce.mat
# calib_file: [12]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_02/1691486_left_habituation/df_converted_pos_synced_1691486_left_habituation_calib_before_label3d_dannce.mat
# update_dannce_mat_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_02/1691486_left_habituation/df_converted_pos_synced_1691486_left_habituation_calib_before_label3d_dannce.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_02/1691486_left_habituation/df_converted_pos_synced_1691486_left_habituation_calib_before_label3d_dannce.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_02/1691486_left_habituation/df_converted_pos_synced_1691486_left_habituation_calib_before_label3d_dannce.mat.old
# updating rot mtx for cam_idx=0
# updating rot mtx for cam_idx=1
# updating rot mtx for cam_idx=2
# updating rot mtx for cam_idx=3
# updating rot mtx for cam_idx=4
# updating rot mtx for cam_idx=5
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_02/1691486_left_habituation/df_converted_pos_synced_1691486_left_habituation_calib_before_label3d_dannce.mat
# calib_file: [13]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_02/1691486_left_right_habituation/df_converted_pos_synced_1691486_left_right_habituation_calib_before_label3d_dannce.mat
# update_dannce_mat_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_02/1691486_left_right_habituation/df_converted_pos_synced_1691486_left_right_habituation_calib_before_label3d_dannce.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_02/1691486_left_right_habituation/df_converted_pos_synced_1691486_left_right_habituation_calib_before_label3d_dannce.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_02/1691486_left_right_habituation/df_converted_pos_synced_1691486_left_right_habituation_calib_before_label3d_dannce.mat.old
# updating rot mtx for cam_idx=0
# updating rot mtx for cam_idx=1
# updating rot mtx for cam_idx=2
# updating rot mtx for cam_idx=3
# updating rot mtx for cam_idx=4
# updating rot mtx for cam_idx=5
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_02/1691486_left_right_habituation/df_converted_pos_synced_1691486_left_right_habituation_calib_before_label3d_dannce.mat
# calib_file: [14]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_02/1691486_left_right_saline_1430/df_converted_pos_synced_1691486_left_right_saline_1430_calib_before_label3d_dannce.mat
# update_dannce_mat_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_02/1691486_left_right_saline_1430/df_converted_pos_synced_1691486_left_right_saline_1430_calib_before_label3d_dannce.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_02/1691486_left_right_saline_1430/df_converted_pos_synced_1691486_left_right_saline_1430_calib_before_label3d_dannce.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_02/1691486_left_right_saline_1430/df_converted_pos_synced_1691486_left_right_saline_1430_calib_before_label3d_dannce.mat.old
# updating rot mtx for cam_idx=0
# updating rot mtx for cam_idx=1
# updating rot mtx for cam_idx=2
# updating rot mtx for cam_idx=3
# updating rot mtx for cam_idx=4
# updating rot mtx for cam_idx=5
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_02/1691486_left_right_saline_1430/df_converted_pos_synced_1691486_left_right_saline_1430_calib_before_label3d_dannce.mat
# calib_file: [15]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_02/1691486_left_right_saline_1505/df_converted_pos_synced_1691486_left_right_saline_1505_calib_before_label3d_dannce.mat
# update_dannce_mat_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_02/1691486_left_right_saline_1505/df_converted_pos_synced_1691486_left_right_saline_1505_calib_before_label3d_dannce.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_02/1691486_left_right_saline_1505/df_converted_pos_synced_1691486_left_right_saline_1505_calib_before_label3d_dannce.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_02/1691486_left_right_saline_1505/df_converted_pos_synced_1691486_left_right_saline_1505_calib_before_label3d_dannce.mat.old
# updating rot mtx for cam_idx=0
# updating rot mtx for cam_idx=1
# updating rot mtx for cam_idx=2
# updating rot mtx for cam_idx=3
# updating rot mtx for cam_idx=4
# updating rot mtx for cam_idx=5
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_02/1691486_left_right_saline_1505/df_converted_pos_synced_1691486_left_right_saline_1505_calib_before_label3d_dannce.mat
# calib_file: [16]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_02/1691486_left_saline_1016/df_converted_pos_synced_1691486_left_saline_1016_calib_before_label3d_dannce.mat
# update_dannce_mat_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_02/1691486_left_saline_1016/df_converted_pos_synced_1691486_left_saline_1016_calib_before_label3d_dannce.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_02/1691486_left_saline_1016/df_converted_pos_synced_1691486_left_saline_1016_calib_before_label3d_dannce.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_02/1691486_left_saline_1016/df_converted_pos_synced_1691486_left_saline_1016_calib_before_label3d_dannce.mat.old
# updating rot mtx for cam_idx=0
# updating rot mtx for cam_idx=1
# updating rot mtx for cam_idx=2
# updating rot mtx for cam_idx=3
# updating rot mtx for cam_idx=4
# updating rot mtx for cam_idx=5
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_02/1691486_left_saline_1016/df_converted_pos_synced_1691486_left_saline_1016_calib_before_label3d_dannce.mat
# calib_file: [17]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_02/1691486_left_saline_1051/df_converted_pos_synced_1691486_left_saline_1051_calib_before_label3d_dannce.mat
# update_dannce_mat_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_02/1691486_left_saline_1051/df_converted_pos_synced_1691486_left_saline_1051_calib_before_label3d_dannce.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_02/1691486_left_saline_1051/df_converted_pos_synced_1691486_left_saline_1051_calib_before_label3d_dannce.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_02/1691486_left_saline_1051/df_converted_pos_synced_1691486_left_saline_1051_calib_before_label3d_dannce.mat.old
# updating rot mtx for cam_idx=0
# updating rot mtx for cam_idx=1
# updating rot mtx for cam_idx=2
# updating rot mtx for cam_idx=3
# updating rot mtx for cam_idx=4
# updating rot mtx for cam_idx=5
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_02/1691486_left_saline_1051/df_converted_pos_synced_1691486_left_saline_1051_calib_before_label3d_dannce.mat
# calib_file: [18]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_03/1691486_left_caffeine_1051/df_converted_pos_synced_1691486_left_caffeine_1051_calib_before_label3d_dannce.mat
# update_dannce_mat_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_03/1691486_left_caffeine_1051/df_converted_pos_synced_1691486_left_caffeine_1051_calib_before_label3d_dannce.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_03/1691486_left_caffeine_1051/df_converted_pos_synced_1691486_left_caffeine_1051_calib_before_label3d_dannce.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_03/1691486_left_caffeine_1051/df_converted_pos_synced_1691486_left_caffeine_1051_calib_before_label3d_dannce.mat.old
# updating rot mtx for cam_idx=0
# updating rot mtx for cam_idx=1
# updating rot mtx for cam_idx=2
# updating rot mtx for cam_idx=3
# updating rot mtx for cam_idx=4
# updating rot mtx for cam_idx=5
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_03/1691486_left_caffeine_1051/df_converted_pos_synced_1691486_left_caffeine_1051_calib_before_label3d_dannce.mat
# calib_file: [19]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_03/1691486_left_caffeine_1128/df_converted_pos_synced_1691486_left_caffeine_1128_calib_before_label3d_dannce.mat
# update_dannce_mat_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_03/1691486_left_caffeine_1128/df_converted_pos_synced_1691486_left_caffeine_1128_calib_before_label3d_dannce.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_03/1691486_left_caffeine_1128/df_converted_pos_synced_1691486_left_caffeine_1128_calib_before_label3d_dannce.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_03/1691486_left_caffeine_1128/df_converted_pos_synced_1691486_left_caffeine_1128_calib_before_label3d_dannce.mat.old
# updating rot mtx for cam_idx=0
# updating rot mtx for cam_idx=1
# updating rot mtx for cam_idx=2
# updating rot mtx for cam_idx=3
# updating rot mtx for cam_idx=4
# updating rot mtx for cam_idx=5
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_03/1691486_left_caffeine_1128/df_converted_pos_synced_1691486_left_caffeine_1128_calib_before_label3d_dannce.mat
# calib_file: [20]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_03/1691486_left_right_caffeine_1448/df_converted_pos_synced_1691486_left_right_caffeine_1448_calib_before_label3d_dannce.mat
# update_dannce_mat_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_03/1691486_left_right_caffeine_1448/df_converted_pos_synced_1691486_left_right_caffeine_1448_calib_before_label3d_dannce.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_03/1691486_left_right_caffeine_1448/df_converted_pos_synced_1691486_left_right_caffeine_1448_calib_before_label3d_dannce.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_03/1691486_left_right_caffeine_1448/df_converted_pos_synced_1691486_left_right_caffeine_1448_calib_before_label3d_dannce.mat.old
# updating rot mtx for cam_idx=0
# updating rot mtx for cam_idx=1
# updating rot mtx for cam_idx=2
# updating rot mtx for cam_idx=3
# updating rot mtx for cam_idx=4
# updating rot mtx for cam_idx=5
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_03/1691486_left_right_caffeine_1448/df_converted_pos_synced_1691486_left_right_caffeine_1448_calib_before_label3d_dannce.mat
# calib_file: [21]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_03/1691486_left_right_caffeine_1546/df_converted_pos_synced_1691486_left_right_caffeine_1546_calib_before_label3d_dannce.mat
# update_dannce_mat_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_03/1691486_left_right_caffeine_1546/df_converted_pos_synced_1691486_left_right_caffeine_1546_calib_before_label3d_dannce.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_03/1691486_left_right_caffeine_1546/df_converted_pos_synced_1691486_left_right_caffeine_1546_calib_before_label3d_dannce.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_03/1691486_left_right_caffeine_1546/df_converted_pos_synced_1691486_left_right_caffeine_1546_calib_before_label3d_dannce.mat.old
# updating rot mtx for cam_idx=0
# updating rot mtx for cam_idx=1
# updating rot mtx for cam_idx=2
# updating rot mtx for cam_idx=3
# updating rot mtx for cam_idx=4
# updating rot mtx for cam_idx=5
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_03/1691486_left_right_caffeine_1546/df_converted_pos_synced_1691486_left_right_caffeine_1546_calib_before_label3d_dannce.mat
# calib_file: [22]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_03/1691486_left_right_habituation/df_converted_pos_synced_1691486_left_right_habituation_calib_before_label3d_dannce.mat
# update_dannce_mat_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_03/1691486_left_right_habituation/df_converted_pos_synced_1691486_left_right_habituation_calib_before_label3d_dannce.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_03/1691486_left_right_habituation/df_converted_pos_synced_1691486_left_right_habituation_calib_before_label3d_dannce.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_03/1691486_left_right_habituation/df_converted_pos_synced_1691486_left_right_habituation_calib_before_label3d_dannce.mat.old
# updating rot mtx for cam_idx=0
# updating rot mtx for cam_idx=1
# updating rot mtx for cam_idx=2
# updating rot mtx for cam_idx=3
# updating rot mtx for cam_idx=4
# updating rot mtx for cam_idx=5
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_03/1691486_left_right_habituation/df_converted_pos_synced_1691486_left_right_habituation_calib_before_label3d_dannce.mat
# calib_file: [23]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_08/1691486_no_hole_habituation_938/df_converted_pos_synced_1691486_no_hole_habituation_938_calib_before_no_hole_935_label3d_dannce.mat
# update_dannce_mat_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_08/1691486_no_hole_habituation_938/df_converted_pos_synced_1691486_no_hole_habituation_938_calib_before_no_hole_935_label3d_dannce.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_08/1691486_no_hole_habituation_938/df_converted_pos_synced_1691486_no_hole_habituation_938_calib_before_no_hole_935_label3d_dannce.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_08/1691486_no_hole_habituation_938/df_converted_pos_synced_1691486_no_hole_habituation_938_calib_before_no_hole_935_label3d_dannce.mat.old
# updating rot mtx for cam_idx=0
# updating rot mtx for cam_idx=1
# updating rot mtx for cam_idx=2
# updating rot mtx for cam_idx=3
# updating rot mtx for cam_idx=4
# updating rot mtx for cam_idx=5
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_08/1691486_no_hole_habituation_938/df_converted_pos_synced_1691486_no_hole_habituation_938_calib_before_no_hole_935_label3d_dannce.mat
# calib_file: [24]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_08/1691486_no_hole_saline_1029/df_converted_pos_synced_1691486_no_hole_saline_1029_calib_before_no_hole_935_label3d_dannce.mat
# update_dannce_mat_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_08/1691486_no_hole_saline_1029/df_converted_pos_synced_1691486_no_hole_saline_1029_calib_before_no_hole_935_label3d_dannce.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_08/1691486_no_hole_saline_1029/df_converted_pos_synced_1691486_no_hole_saline_1029_calib_before_no_hole_935_label3d_dannce.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_08/1691486_no_hole_saline_1029/df_converted_pos_synced_1691486_no_hole_saline_1029_calib_before_no_hole_935_label3d_dannce.mat.old
# updating rot mtx for cam_idx=0
# updating rot mtx for cam_idx=1
# updating rot mtx for cam_idx=2
# updating rot mtx for cam_idx=3
# updating rot mtx for cam_idx=4
# updating rot mtx for cam_idx=5
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_08/1691486_no_hole_saline_1029/df_converted_pos_synced_1691486_no_hole_saline_1029_calib_before_no_hole_935_label3d_dannce.mat
# calib_file: [25]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_08/1691486_no_hole_saline_1054_test/df_converted_pos_synced_1691486_no_hole_saline_1054_test_calib_before_no_hole_935_label3d_dannce.mat
# update_dannce_mat_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_08/1691486_no_hole_saline_1054_test/df_converted_pos_synced_1691486_no_hole_saline_1054_test_calib_before_no_hole_935_label3d_dannce.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_08/1691486_no_hole_saline_1054_test/df_converted_pos_synced_1691486_no_hole_saline_1054_test_calib_before_no_hole_935_label3d_dannce.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_08/1691486_no_hole_saline_1054_test/df_converted_pos_synced_1691486_no_hole_saline_1054_test_calib_before_no_hole_935_label3d_dannce.mat.old
# updating rot mtx for cam_idx=0
# updating rot mtx for cam_idx=1
# updating rot mtx for cam_idx=2
# updating rot mtx for cam_idx=3
# updating rot mtx for cam_idx=4
# updating rot mtx for cam_idx=5
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_08/1691486_no_hole_saline_1054_test/df_converted_pos_synced_1691486_no_hole_saline_1054_test_calib_before_no_hole_935_label3d_dannce.mat
# calib_file: [26]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_08/1691486_no_hole_saline_2_1123_test/df_converted_pos_synced_1691486_no_hole_saline_2_1123_test_calib_before_no_hole_935_label3d_dannce.mat
# update_dannce_mat_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_08/1691486_no_hole_saline_2_1123_test/df_converted_pos_synced_1691486_no_hole_saline_2_1123_test_calib_before_no_hole_935_label3d_dannce.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_08/1691486_no_hole_saline_2_1123_test/df_converted_pos_synced_1691486_no_hole_saline_2_1123_test_calib_before_no_hole_935_label3d_dannce.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_08/1691486_no_hole_saline_2_1123_test/df_converted_pos_synced_1691486_no_hole_saline_2_1123_test_calib_before_no_hole_935_label3d_dannce.mat.old
# updating rot mtx for cam_idx=0
# updating rot mtx for cam_idx=1
# updating rot mtx for cam_idx=2
# updating rot mtx for cam_idx=3
# updating rot mtx for cam_idx=4
# updating rot mtx for cam_idx=5
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_08/1691486_no_hole_saline_2_1123_test/df_converted_pos_synced_1691486_no_hole_saline_2_1123_test_calib_before_no_hole_935_label3d_dannce.mat
# calib_file: [27]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_08/1691486_right_baseline_1353/df_converted_pos_synced_1691486_right_baseline_1353_calib_before_no_hole_935_label3d_dannce.mat
# update_dannce_mat_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_08/1691486_right_baseline_1353/df_converted_pos_synced_1691486_right_baseline_1353_calib_before_no_hole_935_label3d_dannce.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_08/1691486_right_baseline_1353/df_converted_pos_synced_1691486_right_baseline_1353_calib_before_no_hole_935_label3d_dannce.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_08/1691486_right_baseline_1353/df_converted_pos_synced_1691486_right_baseline_1353_calib_before_no_hole_935_label3d_dannce.mat.old
# updating rot mtx for cam_idx=0
# updating rot mtx for cam_idx=1
# updating rot mtx for cam_idx=2
# updating rot mtx for cam_idx=3
# updating rot mtx for cam_idx=4
# updating rot mtx for cam_idx=5
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_08/1691486_right_baseline_1353/df_converted_pos_synced_1691486_right_baseline_1353_calib_before_no_hole_935_label3d_dannce.mat
# calib_file: [28]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_08/1691486_right_baseline_1500/df_converted_pos_synced_1691486_right_baseline_1500_calib_before_no_hole_935_label3d_dannce.mat
# update_dannce_mat_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_08/1691486_right_baseline_1500/df_converted_pos_synced_1691486_right_baseline_1500_calib_before_no_hole_935_label3d_dannce.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_08/1691486_right_baseline_1500/df_converted_pos_synced_1691486_right_baseline_1500_calib_before_no_hole_935_label3d_dannce.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_08/1691486_right_baseline_1500/df_converted_pos_synced_1691486_right_baseline_1500_calib_before_no_hole_935_label3d_dannce.mat.old
# updating rot mtx for cam_idx=0
# updating rot mtx for cam_idx=1
# updating rot mtx for cam_idx=2
# updating rot mtx for cam_idx=3
# updating rot mtx for cam_idx=4
# updating rot mtx for cam_idx=5
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_08/1691486_right_baseline_1500/df_converted_pos_synced_1691486_right_baseline_1500_calib_before_no_hole_935_label3d_dannce.mat
# calib_file: [29]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_08/1691486_right_baseline_1533/df_converted_pos_synced_1691486_right_baseline_1533_calib_before_no_hole_935_label3d_dannce.mat
# update_dannce_mat_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_08/1691486_right_baseline_1533/df_converted_pos_synced_1691486_right_baseline_1533_calib_before_no_hole_935_label3d_dannce.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_08/1691486_right_baseline_1533/df_converted_pos_synced_1691486_right_baseline_1533_calib_before_no_hole_935_label3d_dannce.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_08/1691486_right_baseline_1533/df_converted_pos_synced_1691486_right_baseline_1533_calib_before_no_hole_935_label3d_dannce.mat.old
# updating rot mtx for cam_idx=0
# updating rot mtx for cam_idx=1
# updating rot mtx for cam_idx=2
# updating rot mtx for cam_idx=3
# updating rot mtx for cam_idx=4
# updating rot mtx for cam_idx=5
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_08/1691486_right_baseline_1533/df_converted_pos_synced_1691486_right_baseline_1533_calib_before_no_hole_935_label3d_dannce.mat
# calib_file: [30]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_09/1691485_left_hole_habituation/df_converted_pos_synced_1691485_left_hole_habituation_calib_before_label3d_dannce.mat
# update_dannce_mat_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_09/1691485_left_hole_habituation/df_converted_pos_synced_1691485_left_hole_habituation_calib_before_label3d_dannce.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_09/1691485_left_hole_habituation/df_converted_pos_synced_1691485_left_hole_habituation_calib_before_label3d_dannce.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_09/1691485_left_hole_habituation/df_converted_pos_synced_1691485_left_hole_habituation_calib_before_label3d_dannce.mat.old
# updating rot mtx for cam_idx=0
# updating rot mtx for cam_idx=1
# updating rot mtx for cam_idx=2
# updating rot mtx for cam_idx=3
# updating rot mtx for cam_idx=4
# updating rot mtx for cam_idx=5
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_09/1691485_left_hole_habituation/df_converted_pos_synced_1691485_left_hole_habituation_calib_before_label3d_dannce.mat
# calib_file: [31]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_09/1691485_no_hole_caffeine_1041/df_converted_pos_synced_1691485_no_hole_caffeine_1041_calib_before_label3d_dannce.mat
# update_dannce_mat_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_09/1691485_no_hole_caffeine_1041/df_converted_pos_synced_1691485_no_hole_caffeine_1041_calib_before_label3d_dannce.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_09/1691485_no_hole_caffeine_1041/df_converted_pos_synced_1691485_no_hole_caffeine_1041_calib_before_label3d_dannce.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_09/1691485_no_hole_caffeine_1041/df_converted_pos_synced_1691485_no_hole_caffeine_1041_calib_before_label3d_dannce.mat.old
# updating rot mtx for cam_idx=0
# updating rot mtx for cam_idx=1
# updating rot mtx for cam_idx=2
# updating rot mtx for cam_idx=3
# updating rot mtx for cam_idx=4
# updating rot mtx for cam_idx=5
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_09/1691485_no_hole_caffeine_1041/df_converted_pos_synced_1691485_no_hole_caffeine_1041_calib_before_label3d_dannce.mat
# calib_file: [32]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_09/1691485_no_hole_caffeine_1118/df_converted_pos_synced_1691485_no_hole_caffeine_1118_calib_before_label3d_dannce.mat
# update_dannce_mat_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_09/1691485_no_hole_caffeine_1118/df_converted_pos_synced_1691485_no_hole_caffeine_1118_calib_before_label3d_dannce.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_09/1691485_no_hole_caffeine_1118/df_converted_pos_synced_1691485_no_hole_caffeine_1118_calib_before_label3d_dannce.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_09/1691485_no_hole_caffeine_1118/df_converted_pos_synced_1691485_no_hole_caffeine_1118_calib_before_label3d_dannce.mat.old
# updating rot mtx for cam_idx=0
# updating rot mtx for cam_idx=1
# updating rot mtx for cam_idx=2
# updating rot mtx for cam_idx=3
# updating rot mtx for cam_idx=4
# updating rot mtx for cam_idx=5
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_09/1691485_no_hole_caffeine_1118/df_converted_pos_synced_1691485_no_hole_caffeine_1118_calib_before_label3d_dannce.mat
# calib_file: [33]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_09/1691485_no_hole_habituation/df_converted_pos_synced_1691485_no_hole_habituation_calib_before_label3d_dannce.mat
# update_dannce_mat_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_09/1691485_no_hole_habituation/df_converted_pos_synced_1691485_no_hole_habituation_calib_before_label3d_dannce.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_09/1691485_no_hole_habituation/df_converted_pos_synced_1691485_no_hole_habituation_calib_before_label3d_dannce.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_09/1691485_no_hole_habituation/df_converted_pos_synced_1691485_no_hole_habituation_calib_before_label3d_dannce.mat.old
# updating rot mtx for cam_idx=0
# updating rot mtx for cam_idx=1
# updating rot mtx for cam_idx=2
# updating rot mtx for cam_idx=3
# updating rot mtx for cam_idx=4
# updating rot mtx for cam_idx=5
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_09/1691485_no_hole_habituation/df_converted_pos_synced_1691485_no_hole_habituation_calib_before_label3d_dannce.mat
# calib_file: [34]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_09/1691486_right_hole_caffine_15_31/df_converted_pos_synced_1691486_right_hole_caffine_15_31_calib_before_label3d_dannce.mat
# update_dannce_mat_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_09/1691486_right_hole_caffine_15_31/df_converted_pos_synced_1691486_right_hole_caffine_15_31_calib_before_label3d_dannce.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_09/1691486_right_hole_caffine_15_31/df_converted_pos_synced_1691486_right_hole_caffine_15_31_calib_before_label3d_dannce.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_09/1691486_right_hole_caffine_15_31/df_converted_pos_synced_1691486_right_hole_caffine_15_31_calib_before_label3d_dannce.mat.old
# updating rot mtx for cam_idx=0
# updating rot mtx for cam_idx=1
# updating rot mtx for cam_idx=2
# updating rot mtx for cam_idx=3
# updating rot mtx for cam_idx=4
# updating rot mtx for cam_idx=5
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_09/1691486_right_hole_caffine_15_31/df_converted_pos_synced_1691486_right_hole_caffine_15_31_calib_before_label3d_dannce.mat
# calib_file: [35]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_09/1691486_right_hole_caffine_16_18/df_converted_pos_synced_1691486_right_hole_caffine_16_18_calib_before_label3d_dannce.mat
# update_dannce_mat_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_09/1691486_right_hole_caffine_16_18/df_converted_pos_synced_1691486_right_hole_caffine_16_18_calib_before_label3d_dannce.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_09/1691486_right_hole_caffine_16_18/df_converted_pos_synced_1691486_right_hole_caffine_16_18_calib_before_label3d_dannce.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_09/1691486_right_hole_caffine_16_18/df_converted_pos_synced_1691486_right_hole_caffine_16_18_calib_before_label3d_dannce.mat.old
# updating rot mtx for cam_idx=0
# updating rot mtx for cam_idx=1
# updating rot mtx for cam_idx=2
# updating rot mtx for cam_idx=3
# updating rot mtx for cam_idx=4
# updating rot mtx for cam_idx=5
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_09/1691486_right_hole_caffine_16_18/df_converted_pos_synced_1691486_right_hole_caffine_16_18_calib_before_label3d_dannce.mat
# calib_file: [36]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_09/1691486_right_hole_habituation_14_39/df_converted_pos_synced_1691486_right_hole_habituation_14_39_calib_before_label3d_dannce.mat
# update_dannce_mat_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_09/1691486_right_hole_habituation_14_39/df_converted_pos_synced_1691486_right_hole_habituation_14_39_calib_before_label3d_dannce.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_09/1691486_right_hole_habituation_14_39/df_converted_pos_synced_1691486_right_hole_habituation_14_39_calib_before_label3d_dannce.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_09/1691486_right_hole_habituation_14_39/df_converted_pos_synced_1691486_right_hole_habituation_14_39_calib_before_label3d_dannce.mat.old
# updating rot mtx for cam_idx=0
# updating rot mtx for cam_idx=1
# updating rot mtx for cam_idx=2
# updating rot mtx for cam_idx=3
# updating rot mtx for cam_idx=4
# updating rot mtx for cam_idx=5
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_09/1691486_right_hole_habituation_14_39/df_converted_pos_synced_1691486_right_hole_habituation_14_39_calib_before_label3d_dannce.mat
# calib_file: [37]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_10/1691485_left_hole_habituation/df_converted_pos_synced_1691485_left_hole_habituation_calib_before_label3d_dannce.mat
# update_dannce_mat_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_10/1691485_left_hole_habituation/df_converted_pos_synced_1691485_left_hole_habituation_calib_before_label3d_dannce.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_10/1691485_left_hole_habituation/df_converted_pos_synced_1691485_left_hole_habituation_calib_before_label3d_dannce.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_10/1691485_left_hole_habituation/df_converted_pos_synced_1691485_left_hole_habituation_calib_before_label3d_dannce.mat.old
# updating rot mtx for cam_idx=0
# updating rot mtx for cam_idx=1
# updating rot mtx for cam_idx=2
# updating rot mtx for cam_idx=3
# updating rot mtx for cam_idx=4
# updating rot mtx for cam_idx=5
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_10/1691485_left_hole_habituation/df_converted_pos_synced_1691485_left_hole_habituation_calib_before_label3d_dannce.mat
# calib_file: [38]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_10/1691485_left_hole_saline_10_35/df_converted_pos_synced_1691485_left_hole_saline_10_35_calib_before_label3d_dannce.mat
# update_dannce_mat_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_10/1691485_left_hole_saline_10_35/df_converted_pos_synced_1691485_left_hole_saline_10_35_calib_before_label3d_dannce.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_10/1691485_left_hole_saline_10_35/df_converted_pos_synced_1691485_left_hole_saline_10_35_calib_before_label3d_dannce.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_10/1691485_left_hole_saline_10_35/df_converted_pos_synced_1691485_left_hole_saline_10_35_calib_before_label3d_dannce.mat.old
# updating rot mtx for cam_idx=0
# updating rot mtx for cam_idx=1
# updating rot mtx for cam_idx=2
# updating rot mtx for cam_idx=3
# updating rot mtx for cam_idx=4
# updating rot mtx for cam_idx=5
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_10/1691485_left_hole_saline_10_35/df_converted_pos_synced_1691485_left_hole_saline_10_35_calib_before_label3d_dannce.mat
# calib_file: [39]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_10/1691485_left_hole_saline_11_10/df_converted_pos_synced_1691485_left_hole_saline_11_10_calib_before_label3d_dannce.mat
# update_dannce_mat_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_10/1691485_left_hole_saline_11_10/df_converted_pos_synced_1691485_left_hole_saline_11_10_calib_before_label3d_dannce.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_10/1691485_left_hole_saline_11_10/df_converted_pos_synced_1691485_left_hole_saline_11_10_calib_before_label3d_dannce.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_10/1691485_left_hole_saline_11_10/df_converted_pos_synced_1691485_left_hole_saline_11_10_calib_before_label3d_dannce.mat.old
# updating rot mtx for cam_idx=0
# updating rot mtx for cam_idx=1
# updating rot mtx for cam_idx=2
# updating rot mtx for cam_idx=3
# updating rot mtx for cam_idx=4
# updating rot mtx for cam_idx=5
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_10/1691485_left_hole_saline_11_10/df_converted_pos_synced_1691485_left_hole_saline_11_10_calib_before_label3d_dannce.mat
# calib_file: [40]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_10/1691485_left_right_habituation_14_46/df_converted_pos_synced_1691485_left_right_habituation_14_46_calib_before_label3d_dannce.mat
# update_dannce_mat_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_10/1691485_left_right_habituation_14_46/df_converted_pos_synced_1691485_left_right_habituation_14_46_calib_before_label3d_dannce.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_10/1691485_left_right_habituation_14_46/df_converted_pos_synced_1691485_left_right_habituation_14_46_calib_before_label3d_dannce.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_10/1691485_left_right_habituation_14_46/df_converted_pos_synced_1691485_left_right_habituation_14_46_calib_before_label3d_dannce.mat.old
# updating rot mtx for cam_idx=0
# updating rot mtx for cam_idx=1
# updating rot mtx for cam_idx=2
# updating rot mtx for cam_idx=3
# updating rot mtx for cam_idx=4
# updating rot mtx for cam_idx=5
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_10/1691485_left_right_habituation_14_46/df_converted_pos_synced_1691485_left_right_habituation_14_46_calib_before_label3d_dannce.mat
# calib_file: [41]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_10/1691485_left_right_saline_15_34/df_converted_pos_synced_1691485_left_right_saline_15_34_calib_before_label3d_dannce.mat
# update_dannce_mat_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_10/1691485_left_right_saline_15_34/df_converted_pos_synced_1691485_left_right_saline_15_34_calib_before_label3d_dannce.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_10/1691485_left_right_saline_15_34/df_converted_pos_synced_1691485_left_right_saline_15_34_calib_before_label3d_dannce.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_10/1691485_left_right_saline_15_34/df_converted_pos_synced_1691485_left_right_saline_15_34_calib_before_label3d_dannce.mat.old
# updating rot mtx for cam_idx=0
# updating rot mtx for cam_idx=1
# updating rot mtx for cam_idx=2
# updating rot mtx for cam_idx=3
# updating rot mtx for cam_idx=4
# updating rot mtx for cam_idx=5
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_10/1691485_left_right_saline_15_34/df_converted_pos_synced_1691485_left_right_saline_15_34_calib_before_label3d_dannce.mat
# ...
# updating rot mtx for cam_idx=0
# updating rot mtx for cam_idx=1
# updating rot mtx for cam_idx=2
# updating rot mtx for cam_idx=3
# updating rot mtx for cam_idx=4
# updating rot mtx for cam_idx=5
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_16/1691485RMCFF1500/df_converted_pos_synced_1691485RMCFF1500_calib_test_offset_3_38_label3d_dannce.mat
# calib_file: [53]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_16/1691485RMCFS1535/df_converted_pos_synced_1691485RMCFS1535_calib_test_offset_3_38_label3d_dannce.mat
# update_dannce_mat_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_16/1691485RMCFS1535/df_converted_pos_synced_1691485RMCFS1535_calib_test_offset_3_38_label3d_dannce.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_16/1691485RMCFS1535/df_converted_pos_synced_1691485RMCFS1535_calib_test_offset_3_38_label3d_dannce.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_16/1691485RMCFS1535/df_converted_pos_synced_1691485RMCFS1535_calib_test_offset_3_38_label3d_dannce.mat.old
# updating rot mtx for cam_idx=0
# updating rot mtx for cam_idx=1
# updating rot mtx for cam_idx=2
# updating rot mtx for cam_idx=3
# updating rot mtx for cam_idx=4
# updating rot mtx for cam_idx=5
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_16/1691485RMCFS1535/df_converted_pos_synced_1691485RMCFS1535_calib_test_offset_3_38_label3d_dannce.mat
# calib_file: [54]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_16/1691485RMHBN1405/df_converted_pos_synced_1691485RMHBN1405_calib_test_offset_3_38_label3d_dannce.mat
# update_dannce_mat_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_16/1691485RMHBN1405/df_converted_pos_synced_1691485RMHBN1405_calib_test_offset_3_38_label3d_dannce.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_16/1691485RMHBN1405/df_converted_pos_synced_1691485RMHBN1405_calib_test_offset_3_38_label3d_dannce.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_16/1691485RMHBN1405/df_converted_pos_synced_1691485RMHBN1405_calib_test_offset_3_38_label3d_dannce.mat.old
# updating rot mtx for cam_idx=0
# updating rot mtx for cam_idx=1
# updating rot mtx for cam_idx=2
# updating rot mtx for cam_idx=3
# updating rot mtx for cam_idx=4
# updating rot mtx for cam_idx=5
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_16/1691485RMHBN1405/df_converted_pos_synced_1691485RMHBN1405_calib_test_offset_3_38_label3d_dannce.mat
# calib_file: [55]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_16/1691486NMCFF1033/df_converted_pos_synced_1691486NMCFF1033_calib_test_offset_3_38_label3d_dannce.mat
# update_dannce_mat_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_16/1691486NMCFF1033/df_converted_pos_synced_1691486NMCFF1033_calib_test_offset_3_38_label3d_dannce.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_16/1691486NMCFF1033/df_converted_pos_synced_1691486NMCFF1033_calib_test_offset_3_38_label3d_dannce.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_16/1691486NMCFF1033/df_converted_pos_synced_1691486NMCFF1033_calib_test_offset_3_38_label3d_dannce.mat.old
# updating rot mtx for cam_idx=0
# updating rot mtx for cam_idx=1
# updating rot mtx for cam_idx=2
# updating rot mtx for cam_idx=3
# updating rot mtx for cam_idx=4
# updating rot mtx for cam_idx=5
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_16/1691486NMCFF1033/df_converted_pos_synced_1691486NMCFF1033_calib_test_offset_3_38_label3d_dannce.mat
# calib_file: [56]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_16/1691486NMCFS1123/df_converted_pos_synced_1691486NMCFS1123_calib_test_offset_3_38_label3d_dannce.mat
# update_dannce_mat_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_16/1691486NMCFS1123/df_converted_pos_synced_1691486NMCFS1123_calib_test_offset_3_38_label3d_dannce.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_16/1691486NMCFS1123/df_converted_pos_synced_1691486NMCFS1123_calib_test_offset_3_38_label3d_dannce.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_16/1691486NMCFS1123/df_converted_pos_synced_1691486NMCFS1123_calib_test_offset_3_38_label3d_dannce.mat.old
# updating rot mtx for cam_idx=0
# updating rot mtx for cam_idx=1
# updating rot mtx for cam_idx=2
# updating rot mtx for cam_idx=3
# updating rot mtx for cam_idx=4
# updating rot mtx for cam_idx=5
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_16/1691486NMCFS1123/df_converted_pos_synced_1691486NMCFS1123_calib_test_offset_3_38_label3d_dannce.mat
# calib_file: [57]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_16/1691486NMHBN0927/df_converted_pos_synced_1691486NMHBN0927_calib_test_offset_3_38_label3d_dannce.mat
# update_dannce_mat_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_16/1691486NMHBN0927/df_converted_pos_synced_1691486NMHBN0927_calib_test_offset_3_38_label3d_dannce.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_16/1691486NMHBN0927/df_converted_pos_synced_1691486NMHBN0927_calib_test_offset_3_38_label3d_dannce.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_16/1691486NMHBN0927/df_converted_pos_synced_1691486NMHBN0927_calib_test_offset_3_38_label3d_dannce.mat.old
# updating rot mtx for cam_idx=0
# updating rot mtx for cam_idx=1
# updating rot mtx for cam_idx=2
# updating rot mtx for cam_idx=3
# updating rot mtx for cam_idx=4
# updating rot mtx for cam_idx=5
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_16/1691486NMHBN0927/df_converted_pos_synced_1691486NMHBN0927_calib_test_offset_3_38_label3d_dannce.mat
# calib_file: [58]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_19/240605PMC_window2_right2holes_11_30/df_converted_pos_synced_240605PMC_window2_right2holes_11_30_calib_test_offset_3_38_label3d_dannce.mat
# update_dannce_mat_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_19/240605PMC_window2_right2holes_11_30/df_converted_pos_synced_240605PMC_window2_right2holes_11_30_calib_test_offset_3_38_label3d_dannce.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_19/240605PMC_window2_right2holes_11_30/df_converted_pos_synced_240605PMC_window2_right2holes_11_30_calib_test_offset_3_38_label3d_dannce.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_19/240605PMC_window2_right2holes_11_30/df_converted_pos_synced_240605PMC_window2_right2holes_11_30_calib_test_offset_3_38_label3d_dannce.mat.old
# updating rot mtx for cam_idx=0
# updating rot mtx for cam_idx=1
# updating rot mtx for cam_idx=2
# updating rot mtx for cam_idx=3
# updating rot mtx for cam_idx=4
# updating rot mtx for cam_idx=5
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_19/240605PMC_window2_right2holes_11_30/df_converted_pos_synced_240605PMC_window2_right2holes_11_30_calib_test_offset_3_38_label3d_dannce.mat
# calib_file: [59]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_19/240605PMC_window2_right2holes_12_14/df_converted_pos_synced_240605PMC_window2_right2holes_12_14_calib_test_offset_3_38_label3d_dannce.mat
# update_dannce_mat_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_19/240605PMC_window2_right2holes_12_14/df_converted_pos_synced_240605PMC_window2_right2holes_12_14_calib_test_offset_3_38_label3d_dannce.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_19/240605PMC_window2_right2holes_12_14/df_converted_pos_synced_240605PMC_window2_right2holes_12_14_calib_test_offset_3_38_label3d_dannce.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_19/240605PMC_window2_right2holes_12_14/df_converted_pos_synced_240605PMC_window2_right2holes_12_14_calib_test_offset_3_38_label3d_dannce.mat.old
# updating rot mtx for cam_idx=0
# updating rot mtx for cam_idx=1
# updating rot mtx for cam_idx=2
# updating rot mtx for cam_idx=3
# updating rot mtx for cam_idx=4
# updating rot mtx for cam_idx=5
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_19/240605PMC_window2_right2holes_12_14/df_converted_pos_synced_240605PMC_window2_right2holes_12_14_calib_test_offset_3_38_label3d_dannce.mat
# c3d: [0]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_03/1691486_left_right_habituation/COM_df_final/predict_results/com3d.mat
# update_com3d_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_03/1691486_left_right_habituation/COM_df_final/predict_results/com3d.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_03/1691486_left_right_habituation/COM_df_final/predict_results/com3d.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_03/1691486_left_right_habituation/COM_df_final/predict_results/com3d.mat.old
# fixing all 3d points for #samples={n_samples}
# updating on joint_idx=0
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_03/1691486_left_right_habituation/COM_df_final/predict_results/com3d.mat
# c3d: [1]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_10/1691485_left_hole_saline_10_35/COM_df_final/predict_results/com3d.mat
# update_com3d_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_10/1691485_left_hole_saline_10_35/COM_df_final/predict_results/com3d.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_10/1691485_left_hole_saline_10_35/COM_df_final/predict_results/com3d.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_10/1691485_left_hole_saline_10_35/COM_df_final/predict_results/com3d.mat.old
# fixing all 3d points for #samples={n_samples}
# updating on joint_idx=0
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_10/1691485_left_hole_saline_10_35/COM_df_final/predict_results/com3d.mat
# c3d: [2]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_10/1691485_no_hole_habituation_13_59/COM_df_final/predict_results/com3d.mat
# update_com3d_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_10/1691485_no_hole_habituation_13_59/COM_df_final/predict_results/com3d.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_10/1691485_no_hole_habituation_13_59/COM_df_final/predict_results/com3d.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_10/1691485_no_hole_habituation_13_59/COM_df_final/predict_results/com3d.mat.old
# fixing all 3d points for #samples={n_samples}
# updating on joint_idx=0
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_10/1691485_no_hole_habituation_13_59/COM_df_final/predict_results/com3d.mat
# c3d: [3]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_11/1691485BMCFF1505/COM_df_final/predict_results/com3d.mat
# update_com3d_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_11/1691485BMCFF1505/COM_df_final/predict_results/com3d.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_11/1691485BMCFF1505/COM_df_final/predict_results/com3d.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_11/1691485BMCFF1505/COM_df_final/predict_results/com3d.mat.old
# fixing all 3d points for #samples={n_samples}
# updating on joint_idx=0
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_11/1691485BMCFF1505/COM_df_final/predict_results/com3d.mat
# c3d: [4]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_15/1691485RMHBN1425/COM_df_final/predict_results/com3d.mat
# update_com3d_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_15/1691485RMHBN1425/COM_df_final/predict_results/com3d.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_15/1691485RMHBN1425/COM_df_final/predict_results/com3d.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_15/1691485RMHBN1425/COM_df_final/predict_results/com3d.mat.old
# fixing all 3d points for #samples={n_samples}
# updating on joint_idx=0
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_15/1691485RMHBN1425/COM_df_final/predict_results/com3d.mat
# c3d: [5]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_15/1691485RMPBF1531/COM_df_final/predict_results/com3d.mat
# update_com3d_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_15/1691485RMPBF1531/COM_df_final/predict_results/com3d.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_15/1691485RMPBF1531/COM_df_final/predict_results/com3d.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_15/1691485RMPBF1531/COM_df_final/predict_results/com3d.mat.old
# fixing all 3d points for #samples={n_samples}
# updating on joint_idx=0
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_15/1691485RMPBF1531/COM_df_final/predict_results/com3d.mat
# c3d: [6]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_15/1691485RMPBS1659/COM_df_final/predict_results/com3d.mat
# update_com3d_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_15/1691485RMPBS1659/COM_df_final/predict_results/com3d.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_15/1691485RMPBS1659/COM_df_final/predict_results/com3d.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_15/1691485RMPBS1659/COM_df_final/predict_results/com3d.mat.old
# fixing all 3d points for #samples={n_samples}
# updating on joint_idx=0
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_15/1691485RMPBS1659/COM_df_final/predict_results/com3d.mat
# c3d: [7]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_16/1691485RMHBN1405/COM_df_final/predict_results/com3d.mat
# update_com3d_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_16/1691485RMHBN1405/COM_df_final/predict_results/com3d.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_16/1691485RMHBN1405/COM_df_final/predict_results/com3d.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_16/1691485RMHBN1405/COM_df_final/predict_results/com3d.mat.old
# fixing all 3d points for #samples={n_samples}
# updating on joint_idx=0
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_16/1691485RMHBN1405/COM_df_final/predict_results/com3d.mat
# c3d: [8]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_19/240605PMC_window2_right2holes_11_30/COM_df_final/predict_results/com3d.mat
# update_com3d_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_19/240605PMC_window2_right2holes_11_30/COM_df_final/predict_results/com3d.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_19/240605PMC_window2_right2holes_11_30/COM_df_final/predict_results/com3d.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_19/240605PMC_window2_right2holes_11_30/COM_df_final/predict_results/com3d.mat.old
# fixing all 3d points for #samples={n_samples}
# updating on joint_idx=0
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_19/240605PMC_window2_right2holes_11_30/COM_df_final/predict_results/com3d.mat
# c3d: [9]: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_19/240605PMC_window2_right2holes_12_14/COM_df_final/predict_results/com3d.mat
# update_com3d_file: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_19/240605PMC_window2_right2holes_12_14/COM_df_final/predict_results/com3d.mat
# BACKUP src=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_19/240605PMC_window2_right2holes_12_14/COM_df_final/predict_results/com3d.mat dest=/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_19/240605PMC_window2_right2holes_12_14/COM_df_final/predict_results/com3d.mat.old
# fixing all 3d points for #samples={n_samples}
# updating on joint_idx=0
# Saving update mat file as: /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_19/240605PMC_window2_right2holes_12_14/COM_df_final/predict_results/com3d.mat

# %%
# example code to verify all z-values are positive in COM files

for fname in com3d_files:
    mtmp = loadmat(fname)
    # print("KEYS", mtmp.keys())
    n_samples = mtmp['com'].shape[0]
    print("FNAME: ", fname)
    sum_gt_z = sum(mtmp['com'][:,2] > 0)
    print(f"COM's with z-coord > zero {sum_gt_z}/{n_samples}\n")
# Out:
# FNAME:  /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_03/1691486_left_right_habituation/COM_df_final/predict_results/com3d.mat
# COM's with z-coord > zero 35992/35992
#
# FNAME:  /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_10/1691485_left_hole_saline_10_35/COM_df_final/predict_results/com3d.mat
# COM's with z-coord > zero 35990/35990
#
# FNAME:  /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_10/1691485_no_hole_habituation_13_59/COM_df_final/predict_results/com3d.mat
# COM's with z-coord > zero 35992/35992
#
# FNAME:  /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_11/1691485BMCFF1505/COM_df_final/predict_results/com3d.mat
# COM's with z-coord > zero 35995/35995
#
# FNAME:  /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_15/1691485RMHBN1425/COM_df_final/predict_results/com3d.mat
# COM's with z-coord > zero 35999/35999
#
# FNAME:  /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_15/1691485RMPBF1531/COM_df_final/predict_results/com3d.mat
# COM's with z-coord > zero 35996/35996
#
# FNAME:  /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_15/1691485RMPBS1659/COM_df_final/predict_results/com3d.mat
# COM's with z-coord > zero 35994/35994
#
# FNAME:  /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_16/1691485RMHBN1405/COM_df_final/predict_results/com3d.mat
# COM's with z-coord > zero 20996/20996
#
# FNAME:  /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_19/240605PMC_window2_right2holes_11_30/COM_df_final/predict_results/com3d.mat
# COM's with z-coord > zero 20994/20994
#
# FNAME:  /hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_19/240605PMC_window2_right2holes_12_14/COM_df_final/predict_results/com3d.mat
# COM's with z-coord > zero 20994/20994

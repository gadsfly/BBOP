# %%
import sys
import os
sys.path.append(os.path.abspath('../'))

from utlis.vis_valid_utlis.com_trag_updated import plot_com_all

base = '/hpc/group/tdunn/tdunn/Bryan_Rigs'
recording_list = [
        'BigOpenField/Oct3V1/2024_10_29/2social_mini_0605pmc_single_18_25', # good
        'BigOpenField/Oct3V1/2024_10_31/2social_mini_20240819V1r1_single_11_29', # good
        'BigOpenField/Oct3V1/2024_12_18/20240919v1l5r1mini_p20240717PMC_social_test_11_30', # good
        'BigOpenField/Oct3V1/2024_12_18/20240919v1l5r2mini_p20240717PMC_social_test_13_16', # ok
        'BigOpenField/Oct3V1/2025_03_11/20241224PMCLE1mini_p20240303PMC2_14_44', # not great
        'BigOpenField/Oct3V1/2025_04_10/20241212V1RE1L23Fmini_p20241212V1BE1L23F', # not great
        'BigOpenField/Oct3V1/2025_04_10/20241212V1RE1L23Fmini_p20241212V1LE1L23F',
        'BigOpenField/Oct3V1/2025_05_01/20250324PMCBmini_psamecageLE2_15_09'
    ] 

for recording in recording_list:
    base_recording = os.path.join(base, recording) 
    print(f'Processing recording: {base_recording}')
    # /hpc/group/tdunn/Bryan_Rigs/BigOpenField/Oct3V1/2024_10_29/2social_mini_0605pmc_single_18_25/yolo_tracking/predict_train_lone_social
    plot_com_all(base_recording,com_folder_name='yolo_tracking/predict_train_lone_social', perform_jump_indices=True) #COM/predict00  perform_video_generation=True
# Out:
# Processing recording: /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/Oct3V1/2024_10_29/2social_mini_0605pmc_single_18_25
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[1], line 23
#      21 print(f'Processing recording: {base_recording}')
#      22 # /hpc/group/tdunn/Bryan_Rigs/BigOpenField/Oct3V1/2024_10_29/2social_mini_0605pmc_single_18_25/yolo_tracking/predict_train_lone_social
# ---> 23 plot_com_all(base_recording,com_folder_name='yolo_tracking/predict_train_lone_social', perform_jump_indices=True)
#
# File /hpc/group/tdunn/lq53/BBOP/utlis/vis_valid_utlis/com_trag_updated.py:339, in plot_com_all(base_folder, com_folder_name, perform_jump_indices, perform_video_generation, perform_generate_com_video, cam, zmin, zmax, nf, sf)
#     337 com_folder_save = os.path.join(com_folder, 'vis')
#     338 if not os.path.exists(com_folder_save):
# ...

# %%
import sys
import os
sys.path.append(os.path.abspath('../..'))

from utlis.vis_valid_utlis.scom_traga_utlis import plot_com_all_social


com_path = "/hpc/group/tdunn/Bryan_Rigs/BigOpenField/Oct3V1/2024_11_07/2social_mini_20241015pmcr2_single_AO_13_24"
# "/hpc/group/tdunn/Bryan_Rigs/BigOpenField/Oct3V1/2024_10_03_micecolor_test/24Anshu_f_paint_2mice"

plot_com_all_social(com_path, perform_generate_com_video=True)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 3
#       1 com_path = "/hpc/group/tdunn/Bryan_Rigs/BigOpenField/Oct3V1/2024_10_03_micecolor_test/24Anshu_f_paint_2mice"
# ----> 3 plot_com_all_social(com_path)
#
# File /hpc/group/tdunn/lq53/BBOP/utlis/vis_valid_utlis/scom_traga_utlis.py:211, in plot_com_all_social(base_folder, com_folder_name, perform_jump_indices, perform_video_generation, perform_generate_com_video, zmin, zmax)
#     209 raw = load_com(com_mat)
#     210 if raw.ndim != 2 or raw.shape[1] % 3 != 0:
# --> 211     raise ValueError("Expected COM shape (frames, 3*N_animals)")
#     212 n_animals = raw.shape[1] // 3
#     213 com_data  = raw.reshape(-1, 3, n_animals)
#
# ValueError: Expected COM shape (frames, 3*N_animals)

# %%
# single rerun com
import os

dry_run = False 
txt_file = "/hpc/group/tdunn/Bryan_Rigs/BigOpenField/25juneon/com_repre.txt"
# "/hpc/group/tdunn/Bryan_Rigs/BigOpenField/Oct3V1/1_point_com_rerun.txt"
# "/hpc/group/tdunn/Bryan_Rigs/BigOpenField/Oct3V1/1_point_com_rerun.txt"
# "/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/paret/com_1point_reruns.txt"
# txt_file = "/hpc/group/tdunn/Bryan_Rigs/BigOpenField/Oct3V1/1_point_com_rerun.txt"
slurm_launch_file = '/hpc/group/tdunn/lq53/tianqing_pytorch_dannce/dannce_/slurm_launch_predict.py'

# def check_expdir(expdir):
#     if not os.path.exists(expdir):
#         print(f"Skipping: Experiment directory {expdir} does not exist")
#         return None  # Return None or skip processing this directory
#     return expdir


# Function to create the full expdir path and print the command for dry-run
def run_command(expdir_path, partition, dry_run=True):
    # expdir_path = os.path.join(base_path, date_folder, rec_file)
    
    # Check if the experiment directory exists before running the command
    # if check_expdir(expdir_path) is None:
    #     return  # Skip this execution if the directory does not exist
    
    # command = f"python {slurm_launch_file} --expdir {expdir_path} --predict_com"
    command = f"conda run -n sdannce python {slurm_launch_file} --expdir {expdir_path} --predict_com --allow_overwrite --partition {partition}" # --allow_overwrite remove allow_overwrite by default.

    if dry_run:
        print(f"[DRY-RUN] Command: {command}")
    else:
        print(f"Executing command: {command}")
        os.system(command)
# Read the experiment directories from the .txt file and execute the command for each
with open(txt_file, 'r') as f:
    for line in f:
        expdir_path = line.strip()
        if not expdir_path:
            continue  # Skip empty lines
        # expdir_path = os.path.join(base_path, relative_path)
        run_command(expdir_path, 'scavenger-gpu',dry_run) #tdunn scavenger-gpu
# Out:
# Executing command: conda run -n sdannce python /hpc/group/tdunn/lq53/tianqing_pytorch_dannce/dannce_/slurm_launch_predict.py --expdir /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_24/20250519PMCL23L2_enewcone_econe_oldecone --predict_com --allow_overwrite --partition scavenger-gpu
# Specified a single expdir; running predictions ...
# Running command:  cd /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_24/20250519PMCL23L2_enewcone_econe_oldecone
# dannce predict com /hpc/group/tdunn/tqxli/sdannce_scripts/configs/com_mouse_config.yaml --com-predict-weights=/hpc/group/tdunn/tqxli/sdannce_scripts/weights/COM/checkpoint-epoch20.pth --com-predict-dir=COM/predict00 --max-num-samples 100000 --batch-size=1
# Slurm out: /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_24/20250519PMCL23L2_enewcone_econe_oldecone/slurm/predict_com_20250519PMCL23L2_enewcone_econe_oldecone.out
# Submitted batch job 31161727
#
# Executing command: conda run -n sdannce python /hpc/group/tdunn/lq53/tianqing_pytorch_dannce/dannce_/slurm_launch_predict.py --expdir /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_25/20250407v1l23_socialblackcup_2 --predict_com --allow_overwrite --partition scavenger-gpu
# Specified a single expdir; running predictions ...
# Running command:  cd /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_25/20250407v1l23_socialblackcup_2
# dannce predict com /hpc/group/tdunn/tqxli/sdannce_scripts/configs/com_mouse_config.yaml --com-predict-weights=/hpc/group/tdunn/tqxli/sdannce_scripts/weights/COM/checkpoint-epoch20.pth --com-predict-dir=COM/predict00 --max-num-samples 100000 --batch-size=1
# Slurm out: /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_25/20250407v1l23_socialblackcup_2/slurm/predict_com_20250407v1l23_socialblackcup_2.out
# Submitted batch job 31161776
#
# Executing command: conda run -n sdannce python /hpc/group/tdunn/lq53/tianqing_pytorch_dannce/dannce_/slurm_launch_predict.py --expdir /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_25/20250407v1l23_socialblackcup --predict_com --allow_overwrite --partition scavenger-gpu
# Specified a single expdir; running predictions ...
# Running command:  cd /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_25/20250407v1l23_socialblackcup
# dannce predict com /hpc/group/tdunn/tqxli/sdannce_scripts/configs/com_mouse_config.yaml --com-predict-weights=/hpc/group/tdunn/tqxli/sdannce_scripts/weights/COM/checkpoint-epoch20.pth --com-predict-dir=COM/predict00 --max-num-samples 100000 --batch-size=1
# Slurm out: /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_25/20250407v1l23_socialblackcup/slurm/predict_com_20250407v1l23_socialblackcup.out
# Submitted batch job 31161782

# %%
#single com vis

import sys
import os
sys.path.append(os.path.abspath('../'))
from utlis.vis_valid_utlis.com_trag_updated import plot_com_all

txt_file = "/hpc/group/tdunn/Bryan_Rigs/BigOpenField/25juneon/com_repre.txt"
# txt_file = "/hpc/group/tdunn/Bryan_Rigs/BigOpenField/Oct3V1/1_point_com_rerun.txt"
# "/hpc/group/tdunn/Bryan_Rigs/BigOpenField/Oct3V1/1_point_com_rerun.txt" #"/hpc/group/tdunn/Bryan_Rigs/BigOpenField/Oct3V1/1_point_com_rerun.txt"
# txt_file = '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/paret/com_1point_reruns.txt'  # Update this to the path of your .txt file
# base_folder = '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_02/1691486_left_right_saline_1430'
rel_paths_to_skip = set()
with open(txt_file, 'r') as f:
    for line in f:
        rel_path = line.strip()
        if rel_path:
            rel_paths_to_skip.add(rel_path)
            
for b in rel_paths_to_skip:
    plot_com_all(b) # , perform_jump_indices=True, perform_video_generation=True#com_folder_name='COM/predict00', perform_jump_indices=True, perform_video_generation=False, perform_generate_com_video=False
# Out:
# plotting com_traga for /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_25/20250407v1l23_socialblackcup
# Analysis complete. Plots saved to: /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_25/20250407v1l23_socialblackcup/COM/predict00/vis
# plotting com_traga for /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_26/20250505v1l23r1_ecups
# Analysis complete. Plots saved to: /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_26/20250505v1l23r1_ecups/COM/predict00/vis
# plotting com_traga for /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_26/20250505v1l23r1_greencupsocial
# Analysis complete. Plots saved to: /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_26/20250505v1l23r1_greencupsocial/COM/predict00/vis
# plotting com_traga for /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_24/20250519PMCL23L2_enewcone_econe_oldecone
# Analysis complete. Plots saved to: /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_24/20250519PMCL23L2_enewcone_econe_oldecone/COM/predict00/vis
# plotting com_traga for /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_25/20250407v1l23_socialclearcup
# Analysis complete. Plots saved to: /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_25/20250407v1l23_socialclearcup/COM/predict00/vis
# plotting com_traga for /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_25/20250407v1l23_socialblackcup_2
# Analysis complete. Plots saved to: /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_25/20250407v1l23_socialblackcup_2/COM/predict00/vis

# %%
# single rerun dannce

import os

dry_run = False 
txt_file = "/hpc/group/tdunn/Bryan_Rigs/BigOpenField/25juneon/dannce_repp.txt"
# "/hpc/group/tdunn/Bryan_Rigs/BigOpenField/Oct3V1/rerun_dannc.txt"
# "/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/paret/dannce_return.txt"
# txt_file = 
slurm_launch_file = '/hpc/group/tdunn/lq53/tianqing_pytorch_dannce/dannce_/slurm_launch_predict.py'

# def check_expdir(expdir):
#     if not os.path.exists(expdir):
#         print(f"Skipping: Experiment directory {expdir} does not exist")
#         return None  # Return None or skip processing this directory
#     return expdir


# Function to create the full expdir path and print the command for dry-run
def run_command(expdir_path, partition, dry_run=True):
    # expdir_path = os.path.join(base_path, date_folder, rec_file)
    
    # Check if the experiment directory exists before running the command
    # if check_expdir(expdir_path) is None:
    #     return  # Skip this execution if the directory does not exist
    
    # command = f"python {slurm_launch_file} --expdir {expdir_path} --predict_com"
    command = f"conda run -n sdannce python {slurm_launch_file} --expdir {expdir_path} --predict_dannce --allow_overwrite --partition {partition}" # --allow_overwrite remove allow_overwrite by default.

    if dry_run:
        print(f"[DRY-RUN] Command: {command}")
    else:
        print(f"Executing command: {command}")
        os.system(command)
# Read the experiment directories from the .txt file and execute the command for each
with open(txt_file, 'r') as f:
    for line in f:
        expdir_path = line.strip()
        if not expdir_path:
            continue  # Skip empty lines
        # expdir_path = os.path.join(base_path, relative_path)
        run_command(expdir_path, 'tdunn',dry_run) # cavenger-gpu
# Out:
# Executing command: conda run -n sdannce python /hpc/group/tdunn/lq53/tianqing_pytorch_dannce/dannce_/slurm_launch_predict.py --expdir /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_25/20250407v1l23_socialblackcup --predict_dannce --allow_overwrite --partition tdunn
# Specified a single expdir; running predictions ...
# Running command:  cd /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_25/20250407v1l23_socialblackcup
# dannce predict dannce /hpc/group/tdunn/tqxli/sdannce_scripts/configs/dannce_mouse_config.yaml --dannce-predict-model=/hpc/group/tdunn/tqxli/sdannce_scripts/weights/DANNCE/train04_20241111_ft_mouse_demo/checkpoint-epoch60.pth --dannce-predict-dir=DANNCE/predict00 --com-file=COM/predict00/com3d0.mat --max-num-samples 100000 --batch-size=1
# Slurm out: /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_25/20250407v1l23_socialblackcup/slurm/predict_dannce_20250407v1l23_socialblackcup.out
# Submitted batch job 31289842
#
# Executing command: conda run -n sdannce python /hpc/group/tdunn/lq53/tianqing_pytorch_dannce/dannce_/slurm_launch_predict.py --expdir /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_25/20250407v1l23_socialclearcup --predict_dannce --allow_overwrite --partition tdunn
# Specified a single expdir; running predictions ...
# Running command:  cd /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_25/20250407v1l23_socialclearcup
# dannce predict dannce /hpc/group/tdunn/tqxli/sdannce_scripts/configs/dannce_mouse_config.yaml --dannce-predict-model=/hpc/group/tdunn/tqxli/sdannce_scripts/weights/DANNCE/train04_20241111_ft_mouse_demo/checkpoint-epoch60.pth --dannce-predict-dir=DANNCE/predict00 --com-file=COM/predict00/com3d0.mat --max-num-samples 100000 --batch-size=1
# Slurm out: /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_25/20250407v1l23_socialclearcup/slurm/predict_dannce_20250407v1l23_socialclearcup.out
# Submitted batch job 31289843
#
# Executing command: conda run -n sdannce python /hpc/group/tdunn/lq53/tianqing_pytorch_dannce/dannce_/slurm_launch_predict.py --expdir /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_24/20250519PMCL23L2_enewcone_econe_oldecone --predict_dannce --allow_overwrite --partition tdunn
# Specified a single expdir; running predictions ...
# Running command:  cd /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_24/20250519PMCL23L2_enewcone_econe_oldecone
# dannce predict dannce /hpc/group/tdunn/tqxli/sdannce_scripts/configs/dannce_mouse_config.yaml --dannce-predict-model=/hpc/group/tdunn/tqxli/sdannce_scripts/weights/DANNCE/train04_20241111_ft_mouse_demo/checkpoint-epoch60.pth --dannce-predict-dir=DANNCE/predict00 --com-file=COM/predict00/com3d0.mat --max-num-samples 100000 --batch-size=1
# Slurm out: /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_24/20250519PMCL23L2_enewcone_econe_oldecone/slurm/predict_dannce_20250519PMCL23L2_enewcone_econe_oldecone.out
# Submitted batch job 31289931

# %%
# single rerun dannce

import os

dry_run = False 
txt_file = "/hpc/group/tdunn/Bryan_Rigs/BigOpenField/25juneon/com_repre.txt"
# "/hpc/group/tdunn/Bryan_Rigs/BigOpenField/25juneon/dannce_repp.txt"
# "/hpc/group/tdunn/Bryan_Rigs/BigOpenField/Oct3V1/rerun_dannc.txt"
# "/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/paret/dannce_return.txt"
# txt_file = 
slurm_launch_file = '/hpc/group/tdunn/lq53/tianqing_pytorch_dannce/dannce_/slurm_launch_predict.py'

# def check_expdir(expdir):
#     if not os.path.exists(expdir):
#         print(f"Skipping: Experiment directory {expdir} does not exist")
#         return None  # Return None or skip processing this directory
#     return expdir


# Function to create the full expdir path and print the command for dry-run
def run_command(expdir_path, partition, dry_run=True):
    # expdir_path = os.path.join(base_path, date_folder, rec_file)
    
    # Check if the experiment directory exists before running the command
    # if check_expdir(expdir_path) is None:
    #     return  # Skip this execution if the directory does not exist
    
    # command = f"python {slurm_launch_file} --expdir {expdir_path} --predict_com"
    command = f"conda run -n sdannce python {slurm_launch_file} --expdir {expdir_path} --predict_dannce --allow_overwrite --partition {partition}" # --allow_overwrite remove allow_overwrite by default.

    if dry_run:
        print(f"[DRY-RUN] Command: {command}")
    else:
        print(f"Executing command: {command}")
        os.system(command)
# Read the experiment directories from the .txt file and execute the command for each
with open(txt_file, 'r') as f:
    for line in f:
        expdir_path = line.strip()
        if not expdir_path:
            continue  # Skip empty lines
        # expdir_path = os.path.join(base_path, relative_path)
        run_command(expdir_path, 'scavenger-gpu',dry_run) # cavenger-gpu
# Out:
# Executing command: conda run -n sdannce python /hpc/group/tdunn/lq53/tianqing_pytorch_dannce/dannce_/slurm_launch_predict.py --expdir /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_24/20250519PMCL23L2_enewcone_econe_oldecone --predict_dannce --allow_overwrite --partition scavenger-gpu
# Specified a single expdir; running predictions ...
# Running command:  cd /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_24/20250519PMCL23L2_enewcone_econe_oldecone
# dannce predict dannce /hpc/group/tdunn/tqxli/sdannce_scripts/configs/dannce_mouse_config.yaml --dannce-predict-model=/hpc/group/tdunn/tqxli/sdannce_scripts/weights/DANNCE/train04_20241111_ft_mouse_demo/checkpoint-epoch60.pth --dannce-predict-dir=DANNCE/predict00 --com-file=COM/predict00/com3d0.mat --max-num-samples 100000 --batch-size=1
# Slurm out: /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_24/20250519PMCL23L2_enewcone_econe_oldecone/slurm/predict_dannce_20250519PMCL23L2_enewcone_econe_oldecone.out
# Submitted batch job 31289996
#
# Executing command: conda run -n sdannce python /hpc/group/tdunn/lq53/tianqing_pytorch_dannce/dannce_/slurm_launch_predict.py --expdir /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_25/20250407v1l23_socialblackcup --predict_dannce --allow_overwrite --partition scavenger-gpu
# Specified a single expdir; running predictions ...
# Running command:  cd /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_25/20250407v1l23_socialblackcup
# dannce predict dannce /hpc/group/tdunn/tqxli/sdannce_scripts/configs/dannce_mouse_config.yaml --dannce-predict-model=/hpc/group/tdunn/tqxli/sdannce_scripts/weights/DANNCE/train04_20241111_ft_mouse_demo/checkpoint-epoch60.pth --dannce-predict-dir=DANNCE/predict00 --com-file=COM/predict00/com3d0.mat --max-num-samples 100000 --batch-size=1
# Slurm out: /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_25/20250407v1l23_socialblackcup/slurm/predict_dannce_20250407v1l23_socialblackcup.out
# Submitted batch job 31290093
#
# Executing command: conda run -n sdannce python /hpc/group/tdunn/lq53/tianqing_pytorch_dannce/dannce_/slurm_launch_predict.py --expdir /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_25/20250407v1l23_socialblackcup_2 --predict_dannce --allow_overwrite --partition scavenger-gpu
# Specified a single expdir; running predictions ...
# Running command:  cd /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_25/20250407v1l23_socialblackcup_2
# dannce predict dannce /hpc/group/tdunn/tqxli/sdannce_scripts/configs/dannce_mouse_config.yaml --dannce-predict-model=/hpc/group/tdunn/tqxli/sdannce_scripts/weights/DANNCE/train04_20241111_ft_mouse_demo/checkpoint-epoch60.pth --dannce-predict-dir=DANNCE/predict00 --com-file=COM/predict00/com3d0.mat --max-num-samples 100000 --batch-size=1
# Slurm out: /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_25/20250407v1l23_socialblackcup_2/slurm/predict_dannce_20250407v1l23_socialblackcup_2.out
# Submitted batch job 31290126
#
# Executing command: conda run -n sdannce python /hpc/group/tdunn/lq53/tianqing_pytorch_dannce/dannce_/slurm_launch_predict.py --expdir /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_25/20250407v1l23_socialblackcup --predict_dannce --allow_overwrite --partition scavenger-gpu
# Specified a single expdir; running predictions ...
# Running command:  cd /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_25/20250407v1l23_socialblackcup
# dannce predict dannce /hpc/group/tdunn/tqxli/sdannce_scripts/configs/dannce_mouse_config.yaml --dannce-predict-model=/hpc/group/tdunn/tqxli/sdannce_scripts/weights/DANNCE/train04_20241111_ft_mouse_demo/checkpoint-epoch60.pth --dannce-predict-dir=DANNCE/predict00 --com-file=COM/predict00/com3d0.mat --max-num-samples 100000 --batch-size=1
# Slurm out: /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_25/20250407v1l23_socialblackcup/slurm/predict_dannce_20250407v1l23_socialblackcup.out
# Submitted batch job 31290127
#
# Executing command: conda run -n sdannce python /hpc/group/tdunn/lq53/tianqing_pytorch_dannce/dannce_/slurm_launch_predict.py --expdir /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_25/20250407v1l23_socialclearcup --predict_dannce --allow_overwrite --partition scavenger-gpu
# Specified a single expdir; running predictions ...
# Running command:  cd /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_25/20250407v1l23_socialclearcup
# dannce predict dannce /hpc/group/tdunn/tqxli/sdannce_scripts/configs/dannce_mouse_config.yaml --dannce-predict-model=/hpc/group/tdunn/tqxli/sdannce_scripts/weights/DANNCE/train04_20241111_ft_mouse_demo/checkpoint-epoch60.pth --dannce-predict-dir=DANNCE/predict00 --com-file=COM/predict00/com3d0.mat --max-num-samples 100000 --batch-size=1
# Slurm out: /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_25/20250407v1l23_socialclearcup/slurm/predict_dannce_20250407v1l23_socialclearcup.out
# Submitted batch job 31290143
#
# Executing command: conda run -n sdannce python /hpc/group/tdunn/lq53/tianqing_pytorch_dannce/dannce_/slurm_launch_predict.py --expdir /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_26/20250505v1l23r1_ecups --predict_dannce --allow_overwrite --partition scavenger-gpu
# Specified a single expdir; running predictions ...
# Running command:  cd /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_26/20250505v1l23r1_ecups
# dannce predict dannce /hpc/group/tdunn/tqxli/sdannce_scripts/configs/dannce_mouse_config.yaml --dannce-predict-model=/hpc/group/tdunn/tqxli/sdannce_scripts/weights/DANNCE/train04_20241111_ft_mouse_demo/checkpoint-epoch60.pth --dannce-predict-dir=DANNCE/predict00 --com-file=COM/predict00/com3d0.mat --max-num-samples 100000 --batch-size=1
# Slurm out: /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_26/20250505v1l23r1_ecups/slurm/predict_dannce_20250505v1l23r1_ecups.out
# Submitted batch job 31290160
#
# Executing command: conda run -n sdannce python /hpc/group/tdunn/lq53/tianqing_pytorch_dannce/dannce_/slurm_launch_predict.py --expdir /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_26/20250505v1l23r1_greencupsocial --predict_dannce --allow_overwrite --partition scavenger-gpu
# Specified a single expdir; running predictions ...
# Running command:  cd /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_26/20250505v1l23r1_greencupsocial
# dannce predict dannce /hpc/group/tdunn/tqxli/sdannce_scripts/configs/dannce_mouse_config.yaml --dannce-predict-model=/hpc/group/tdunn/tqxli/sdannce_scripts/weights/DANNCE/train04_20241111_ft_mouse_demo/checkpoint-epoch60.pth --dannce-predict-dir=DANNCE/predict00 --com-file=COM/predict00/com3d0.mat --max-num-samples 100000 --batch-size=1
# Slurm out: /hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_26/20250505v1l23r1_greencupsocial/slurm/predict_dannce_20250505v1l23r1_greencupsocial.out
# Submitted batch job 31290165

# %%
#single com vis

import sys
import os
sys.path.append(os.path.abspath('../'))
from useful_files.sophie_check_dannce_mir_modif import dannce_valid

txt_file = "/hpc/group/tdunn/Bryan_Rigs/BigOpenField/25juneon/com_repre.txt"
# "/hpc/group/tdunn/Bryan_Rigs/BigOpenField/25juneon/dannce_repp.txt"
# txt_file = "/hpc/group/tdunn/Bryan_Rigs/BigOpenField/Oct3V1/1_point_com_rerun.txt"
# "/hpc/group/tdunn/Bryan_Rigs/BigOpenField/Oct3V1/1_point_com_rerun.txt" #"/hpc/group/tdunn/Bryan_Rigs/BigOpenField/Oct3V1/1_point_com_rerun.txt"
# txt_file = '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/paret/com_1point_reruns.txt'  # Update this to the path of your .txt file
# base_folder = '/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ/2024_07_02/1691486_left_right_saline_1430'
rel_paths_to_skip = set()
with open(txt_file, 'r') as f:
    for line in f:
        rel_path = line.strip()
        if rel_path:
            rel_paths_to_skip.add(rel_path)
            
for b in rel_paths_to_skip:
    dannce_valid(b) # , perform_jump_indices=True, perform_video_generation=True#com_folder_name='COM/predict00', perform_jump_indices=True, perform_video_generation=False, perform_generate_com_video=False
# Out:
# Plot saved as '/hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_25/20250407v1l23_socialblackcup/DANNCE/predict00/vis/2025_06_25_20250407v1l23_socialblackcup.jpg'.
# Plot saved as '/hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_26/20250505v1l23r1_ecups/DANNCE/predict00/vis/2025_06_26_20250505v1l23r1_ecups.jpg'.
# Plot saved as '/hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_26/20250505v1l23r1_greencupsocial/DANNCE/predict00/vis/2025_06_26_20250505v1l23r1_greencupsocial.jpg'.
# Plot saved as '/hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_24/20250519PMCL23L2_enewcone_econe_oldecone/DANNCE/predict00/vis/2025_06_24_20250519PMCL23L2_enewcone_econe_oldecone.jpg'.
# Plot saved as '/hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_25/20250407v1l23_socialclearcup/DANNCE/predict00/vis/2025_06_25_20250407v1l23_socialclearcup.jpg'.
# Plot saved as '/hpc/group/tdunn/tdunn/Bryan_Rigs/BigOpenField/25juneon/2025_06_25/20250407v1l23_socialblackcup_2/DANNCE/predict00/vis/2025_06_25_20250407v1l23_socialblackcup_2.jpg'.

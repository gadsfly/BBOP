# %%
import glob
import shutil
import os
import subprocess

parent_directory = "/home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/*/*/*/*/My_V4_Miniscope"  # Adjust the pattern as needed
locations = glob.glob(parent_directory)

# %%
locations
# Out:
# ['/home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R2/customEntValHere/2024_10_04/15_23_59/My_V4_Miniscope',
#  '/home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R2/customEntValHere/2024_10_14/16_03_58/My_V4_Miniscope',
#  '/home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R2/customEntValHere/2024_10_14/14_23_28/My_V4_Miniscope',
#  '/home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_07/19_10_41/My_V4_Miniscope',
#  '/home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_07/15_57_40/My_V4_Miniscope',
#  '/home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_07/14_53_59/My_V4_Miniscope',
#  '/home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_07/18_55_00/My_V4_Miniscope',
#  '/home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_07/18_00_05/My_V4_Miniscope',
#  '/home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_07/15_07_56/My_V4_Miniscope',
#  '/home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_07/18_16_09/My_V4_Miniscope',
#  '/home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_07/19_18_47/My_V4_Miniscope',
#  '/home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_08/14_41_53/My_V4_Miniscope',
#  '/home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_08/15_36_19/My_V4_Miniscope',
#  '/home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_08/16_23_13/My_V4_Miniscope',
#  '/home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_08/16_06_49/My_V4_Miniscope',
#  '/home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_08/15_53_33/My_V4_Miniscope',
#  '/home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_08/14_24_58/My_V4_Miniscope',
#  '/home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_08/14_08_38/My_V4_Miniscope',
#  '/home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_04/14_49_29/My_V4_Miniscope',
#  '/home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_14/16_36_18/My_V4_Miniscope',
#  '/home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_14/14_54_12/My_V4_Miniscope',
#  '/home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_14/16_54_16/My_V4_Miniscope',
#  '/home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_14/15_10_18/My_V4_Miniscope',
#  '/home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_14/16_38_19/My_V4_Miniscope',
#  '/home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_09_17/15_46_29/My_V4_Miniscope',
#  '/home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_09_17/15_33_52/My_V4_Miniscope',
#  '/home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_09_18/13_54_22/My_V4_Miniscope',
#  '/home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_09_18/13_34_29/My_V4_Miniscope',
#  '/home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_09_18/13_55_04/My_V4_Miniscope',
#  '/home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_17/14_41_28/My_V4_Miniscope',
#  '/home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_17/14_25_32/My_V4_Miniscope',
#  '/home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_17/14_09_19/My_V4_Miniscope',
#  '/home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_08/20_48_38/My_V4_Miniscope',
#  '/home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_08/20_32_38/My_V4_Miniscope',
#  '/home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_08/20_16_41/My_V4_Miniscope',
#  '/home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_08/19_44_49/My_V4_Miniscope',
#  '/home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_08/20_00_58/My_V4_Miniscope',
#  '/home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_04/21_08_15/My_V4_Miniscope',
#  '/home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_04/21_41_08/My_V4_Miniscope',
#  '/home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_04/20_16_14/My_V4_Miniscope',
#  '/home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_04/14_18_19/My_V4_Miniscope']

# %%
source_file = "/home/lq53/mir_data/24cont_miniscope/240918v1r1/2024_10_08/14_41_53/minian_simp_test/minian_mirpy_set.py"
for location in locations:
    destination_file = os.path.join(location, "minian_mirpy_set.py")
    if not os.path.exists(destination_file):
        shutil.copy(source_file, location)
        print(f"Copied script to {location}")
    else:
        print(f"Script already exists in {location}, skipping copy.")
# source_file = "/home/lq53/mir_data/24cont_miniscope/240918v1r1/2024_10_08/14_41_53/minian_simp_test/minian_mirpy_set.py"
# for location in locations:
#     shutil.copy(source_file, location)
# Out:
# Script already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R2/customEntValHere/2024_10_04/15_23_59/My_V4_Miniscope, skipping copy.
# Script already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R2/customEntValHere/2024_10_14/16_03_58/My_V4_Miniscope, skipping copy.
# Script already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R2/customEntValHere/2024_10_14/14_23_28/My_V4_Miniscope, skipping copy.
# Script already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_07/19_10_41/My_V4_Miniscope, skipping copy.
# Script already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_07/15_57_40/My_V4_Miniscope, skipping copy.
# Script already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_07/14_53_59/My_V4_Miniscope, skipping copy.
# Script already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_07/18_55_00/My_V4_Miniscope, skipping copy.
# Script already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_07/18_00_05/My_V4_Miniscope, skipping copy.
# Script already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_07/15_07_56/My_V4_Miniscope, skipping copy.
# Script already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_07/18_16_09/My_V4_Miniscope, skipping copy.
# Script already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_07/19_18_47/My_V4_Miniscope, skipping copy.
# Script already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_08/14_41_53/My_V4_Miniscope, skipping copy.
# Script already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_08/15_36_19/My_V4_Miniscope, skipping copy.
# Script already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_08/16_23_13/My_V4_Miniscope, skipping copy.
# Script already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_08/16_06_49/My_V4_Miniscope, skipping copy.
# Script already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_08/15_53_33/My_V4_Miniscope, skipping copy.
# Script already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_08/14_24_58/My_V4_Miniscope, skipping copy.
# Script already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_08/14_08_38/My_V4_Miniscope, skipping copy.
# Script already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_04/14_49_29/My_V4_Miniscope, skipping copy.
# Script already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_14/16_36_18/My_V4_Miniscope, skipping copy.
# Script already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_14/14_54_12/My_V4_Miniscope, skipping copy.
# Script already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_14/16_54_16/My_V4_Miniscope, skipping copy.
# Script already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_14/15_10_18/My_V4_Miniscope, skipping copy.
# Script already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_14/16_38_19/My_V4_Miniscope, skipping copy.
# Script already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_09_17/15_46_29/My_V4_Miniscope, skipping copy.
# Script already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_09_17/15_33_52/My_V4_Miniscope, skipping copy.
# Script already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_09_18/13_54_22/My_V4_Miniscope, skipping copy.
# Script already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_09_18/13_34_29/My_V4_Miniscope, skipping copy.
# Script already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_09_18/13_55_04/My_V4_Miniscope, skipping copy.
# Script already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_17/14_41_28/My_V4_Miniscope, skipping copy.
# Script already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_17/14_25_32/My_V4_Miniscope, skipping copy.
# Script already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_17/14_09_19/My_V4_Miniscope, skipping copy.
# Script already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_08/20_48_38/My_V4_Miniscope, skipping copy.
# Script already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_08/20_32_38/My_V4_Miniscope, skipping copy.
# Script already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_08/20_16_41/My_V4_Miniscope, skipping copy.
# Script already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_08/19_44_49/My_V4_Miniscope, skipping copy.
# Script already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_08/20_00_58/My_V4_Miniscope, skipping copy.
# Script already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_04/21_08_15/My_V4_Miniscope, skipping copy.
# Script already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_04/21_41_08/My_V4_Miniscope, skipping copy.
# Script already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_04/20_16_14/My_V4_Miniscope, skipping copy.
# Script already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_04/14_18_19/My_V4_Miniscope, skipping copy.

# %%
#a very good try, but prob copy and pasting is easiest...
# Loop through each location and copy the parameter file if it doesn't already exist
for location in locations:
    # Extract the animal ID from the folder structure
    path_parts = location.split('/')
    animal_id = path_parts[6]  # Adjust this index based on your folder structure
    print(animal_id)
    # Define the animal-specific parameter file path
    # '/home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/minian_param_mir.py'
    source_param_file = f"/home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/{animal_id}/customEntValHere/minian_param_mir.py"
    destination_param_file = os.path.join(location, "minian_param_mir.py")

    if not os.path.exists(destination_param_file):
        if os.path.exists(source_param_file):
            shutil.copy(source_param_file, location)
            print(f"Copied parameter file for {animal_id} to {location}")
        else:
            print(f"Parameter file for {animal_id} not found. Skipping {location}.")
    else:
        print(f"Parameter file already exists in {location}, skipping copy.")


# for location in locations:
#     # Extract the animal ID from the folder structure
#     path_parts = location.split('/')
#     animal_id = path_parts[5]  # Adjust this index based on where the animal ID is in the path

#     # Set the path to the parameter file for this specific animal
#     param_file = f"/home/lq53/mir_data/24cont_miniscope/{animal_id}/minian_param_mir.py"
    
#     # Check if the parameter file exists
#     if os.path.exists(param_file):
#         # Check if any .nc files exist in the location
#         nc_files = glob.glob(os.path.join(location, "*.nc"))
        
#         if nc_files:
#             # Skip execution if .nc files are found
#             print(f".nc files found in {location}. Skipping execution.")
#         else:
#             # Path to the script
#             script_path = os.path.join(location, "minian_mirpy_set.py")

#             # Command to execute the script with the correct parameter file
#             command = f"PYTHONPATH=$(dirname {param_file}) python {script_path}"
#             subprocess.run(command, shell=True)
#     else:
#         # Print a message if the parameter file does not exist
#         print(f"Parameter file for animal {animal_id} not found at {param_file}")
# Out:
# 20240916-V1-R2
# Parameter file already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R2/customEntValHere/2024_10_04/15_23_59/My_V4_Miniscope, skipping copy.
# 20240916-V1-R2
# Parameter file already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R2/customEntValHere/2024_10_14/16_03_58/My_V4_Miniscope, skipping copy.
# 20240916-V1-R2
# Parameter file already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R2/customEntValHere/2024_10_14/14_23_28/My_V4_Miniscope, skipping copy.
# 20240916-V1-R1
# Parameter file already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_07/19_10_41/My_V4_Miniscope, skipping copy.
# 20240916-V1-R1
# Parameter file already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_07/15_57_40/My_V4_Miniscope, skipping copy.
# 20240916-V1-R1
# Parameter file already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_07/14_53_59/My_V4_Miniscope, skipping copy.
# 20240916-V1-R1
# Parameter file already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_07/18_55_00/My_V4_Miniscope, skipping copy.
# 20240916-V1-R1
# Parameter file already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_07/18_00_05/My_V4_Miniscope, skipping copy.
# 20240916-V1-R1
# Parameter file already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_07/15_07_56/My_V4_Miniscope, skipping copy.
# 20240916-V1-R1
# Parameter file already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_07/18_16_09/My_V4_Miniscope, skipping copy.
# 20240916-V1-R1
# Parameter file already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_07/19_18_47/My_V4_Miniscope, skipping copy.
# 20240916-V1-R1
# Parameter file already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_08/14_41_53/My_V4_Miniscope, skipping copy.
# 20240916-V1-R1
# Parameter file already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_08/15_36_19/My_V4_Miniscope, skipping copy.
# 20240916-V1-R1
# Parameter file already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_08/16_23_13/My_V4_Miniscope, skipping copy.
# 20240916-V1-R1
# Parameter file already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_08/16_06_49/My_V4_Miniscope, skipping copy.
# 20240916-V1-R1
# Parameter file already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_08/15_53_33/My_V4_Miniscope, skipping copy.
# 20240916-V1-R1
# Parameter file already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_08/14_24_58/My_V4_Miniscope, skipping copy.
# 20240916-V1-R1
# Parameter file already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_08/14_08_38/My_V4_Miniscope, skipping copy.
# 20240916-V1-R1
# Parameter file already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_04/14_49_29/My_V4_Miniscope, skipping copy.
# 20240916-V1-R1
# Parameter file already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_14/16_36_18/My_V4_Miniscope, skipping copy.
# 20240916-V1-R1
# Parameter file already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_14/14_54_12/My_V4_Miniscope, skipping copy.
# 20240916-V1-R1
# Parameter file already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_14/16_54_16/My_V4_Miniscope, skipping copy.
# 20240916-V1-R1
# Parameter file already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_14/15_10_18/My_V4_Miniscope, skipping copy.
# 20240916-V1-R1
# Parameter file already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_14/16_38_19/My_V4_Miniscope, skipping copy.
# 20240819-V1-r1
# Parameter file already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_09_17/15_46_29/My_V4_Miniscope, skipping copy.
# 20240819-V1-r1
# Parameter file already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_09_17/15_33_52/My_V4_Miniscope, skipping copy.
# 20240819-V1-r1
# Parameter file already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_09_18/13_54_22/My_V4_Miniscope, skipping copy.
# 20240819-V1-r1
# Parameter file already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_09_18/13_34_29/My_V4_Miniscope, skipping copy.
# 20240819-V1-r1
# Parameter file already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_09_18/13_55_04/My_V4_Miniscope, skipping copy.
# 20240819-V1-r1
# Parameter file already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_17/14_41_28/My_V4_Miniscope, skipping copy.
# 20240819-V1-r1
# Parameter file already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_17/14_25_32/My_V4_Miniscope, skipping copy.
# 20240819-V1-r1
# Parameter file already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_17/14_09_19/My_V4_Miniscope, skipping copy.
# 20240819-V1-r1
# Parameter file already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_08/20_48_38/My_V4_Miniscope, skipping copy.
# 20240819-V1-r1
# Parameter file already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_08/20_32_38/My_V4_Miniscope, skipping copy.
# 20240819-V1-r1
# Parameter file already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_08/20_16_41/My_V4_Miniscope, skipping copy.
# 20240819-V1-r1
# Parameter file already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_08/19_44_49/My_V4_Miniscope, skipping copy.
# 20240819-V1-r1
# Parameter file already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_08/20_00_58/My_V4_Miniscope, skipping copy.
# 20240819-V1-r1
# Parameter file already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_04/21_08_15/My_V4_Miniscope, skipping copy.
# 20240819-V1-r1
# Parameter file already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_04/21_41_08/My_V4_Miniscope, skipping copy.
# 20240819-V1-r1
# Parameter file already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_04/20_16_14/My_V4_Miniscope, skipping copy.
# 20240819-V1-r1
# Parameter file already exists in /home/lq53/mir_data/Oct3V1mini/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_04/14_18_19/My_V4_Miniscope, skipping copy.

# %%
# Loop through each location and run the script
for location in locations:
    # Check if the necessary script and parameter file exist in the folder
    script_file = os.path.join(location, "minian_mirpy_set.py")
    param_file = os.path.join(location, "minian_param_mir.py")
    
    if os.path.exists(script_file) and os.path.exists(param_file):
        # Execute the script in the current location
        print(f"Running script in {location}")
        subprocess.run(["python", script_file], cwd=location)
    else:
        print(f"Missing script or parameter file in {location}, skipping execution.")

# %%
# # Path to your parameter file
# param_file = "/home/lq53/mir_data/24cont_miniscope/240918v1r1/2024_10_08/14_41_53/minian_simp_test/minian_param_mir.py"

# # Run the script in each location
# for location in locations:
#     script_path = os.path.join(location, "minian_mirpy_set.py")
#     command = f"PYTHONPATH={param_file} python {script_path}"
#     subprocess.run(command, shell=True)

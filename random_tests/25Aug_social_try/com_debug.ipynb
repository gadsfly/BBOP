# %%
import pandas as pd

path = "/data/big_rim/rsync_dcc_sum/Oct3V1/2025_05_16/20240303PMCBE0r1coatedmini_p20240303RE1/MIR_Aligned/only_com_aligned_predictions.h5"

df = pd.read_hdf(path, key='df')

# %%
df #looks like xyz, xyz is in order of xx yy zz. idiot
# Out:
#                        com1_x      com1_y      com1_z      com2_x     com2_y  \
# timestamp_ms_mini
# -99               -112.688743  145.815149  348.747546  336.611731  10.452756
#  5                -110.415565  145.815149  349.479536  336.611731   9.988041
#  102               -99.455881  145.604628  347.529673  335.616350   9.177259
#  203               -95.165467  150.907284  345.186795  332.979820   8.471768
#  304               -93.109993  150.907284  351.040975  333.731682  11.894398
# ...                       ...         ...         ...         ...        ...
#  449709           -358.616545 -324.515298  238.695673  205.154716   4.546665
#  449811           -351.729764 -323.689727  244.795068  206.324125   7.046721
#  449911           -336.777064 -349.069885  231.910605  232.735809   5.569941
#  450012           -347.603424 -334.299671  258.291763  211.359892   3.886029
#  450112           -334.800990 -323.764094  247.780325  207.446572   6.579794
#
# ...

# %%
import scipy.io as sio

com_path = "/data/big_rim/rsync_dcc_sum/Oct3V1/2025_05_16/20240303PMCBE0r1coatedmini_p20240303RE1/COM/predict00/com3d0.mat"
com_data = sio.loadmat(com_path)

# %%
com_data['com'][102:119,:,0]
# Out:
# array([[-100.64592942,  348.19324142,    9.12863069],
#        [-112.6887433 ,  348.74754607,   10.45275587],
#        [-112.6887433 ,  347.35963154,   10.68249702],
#        [-111.54904992,  347.35963154,   10.68249702],
#        [-110.41556479,  349.47953559,    9.98804072],
#        [-111.5146829 ,  347.35963154,   10.68249702],
#        [-102.28535432,  347.36636643,    9.17725944],
#        [ -99.4558809 ,  347.52967326,    9.17725944],
#        [-106.54148222,  348.19324142,   11.41110775],
#        [ -95.62140181,  348.72578931,    9.15447821],
#        [ -95.16546665,  345.18679524,    8.47176794],
#        [ -91.14946535,  348.33316143,    9.0251402 ],
#        [ -94.94313016,  349.87076108,   11.11920748],
#        [ -93.10999332,  351.04097474,   11.89439828],
#        [ -89.20087866,  351.22971901,   11.06444741],
#        [ -86.96474586,  350.2436992 ,    9.45161945],
#        [ -84.54543594,  348.71580974,   11.51170586]])

# %%
import sys
import os
sys.path.append(os.path.abspath('../..'))
from utlis.sync_utlis.mini_dannce_sync import generate_frame_mapping
import shutil

# %%
rec_path_norm = "/data/big_rim/rsync_dcc_sum/Oct3V1/2025_05_16/20241216V1RE1Fmini_p20241224PMCLE1"
# "/data/big_rim/rsync_dcc_sum/Oct3V1/2025_05_16/20241216V1RE1Fmini_p20241216RE2"
# "/data/big_rim/rsync_dcc_sum/Oct3V1/2024_12_31/20240919v1l5r2mini_p20240717PMC_social_14_04"
# "/data/big_rim/rsync_dcc_sum/Oct3V1/2024_12_18/20240919v1l5r1mini_p20240717PMC_social_test_11_30"
# "/data/big_rim/rsync_dcc_sum/Oct3V1/2025_05_16/20240303PMCBE0r1coatedmini_p20240303RE1"
# "/data/big_rim/rsync_dcc_sum/Oct3V1/2025_05_16/20240303PMCBE0r1coatedmini_p20240303RE1/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1/2025_05_16/20241216V1RE1Fmini_p20241224PMCLE1/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1/2024_11_01/2social_mini_20240819V1r1_AO_single_14_30/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1/2024_11_01/2social_mini_20240819V1r1_AO_single_14_30/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1/2024_12_18/20240919v1l5r1mini_11_21/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1/2025_02_13/20241225PMCLE1mini_11_06"

mini_path_norm = "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241216v1re1f/customEntValHere/2025_05_16/15_42_36"
# "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241216v1re1f/customEntValHere/2025_05_16/15_27_08"
# "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240919-V1-R2/customEntValHere/2024_12_31/14_05_14"
# "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240919-V1-R1/customEntValHere/2024_12_18/11_33_01"
# "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240303PMCBE0coatedr1/customEntValHere/2025_05_16/14_54_15"
# "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240303PMCBE0coatedr1/customEntValHere/2025_05_16/14_54_15/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241216v1re1f/customEntValHere/2025_05_16/15_42_36/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_11_01/14_40_33/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_11_01/14_40_33/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240919-V1-R1/customEntValHere/2024_12_18/11_22_07/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241224PMCLE1/customEntValHere/2025_02_13/11_07_37/"

nc_key = "wnd1500_stp700_max25_diff4.0_pnr1.1"
# "wnd1500_stp700_max25_diff5.0_pnr1.1"
# "wnd1000_stp700_max25_diff5.0_pnrauto"
# "wnd700_stp700_max25_diff4.0_pnrauto"
# "wnd1000_stp700_max15_diff5.0_pnr1.1"
# "wnd1000_stp700_max15_diff5.0_pnr1.1"
# "wnd1500_stp700_max25_diff4.0_pnr1.1"
# "wnd1500_stp700_max25_diff3.5_pnr1.1"
# "wnd1500_stp700_max15_diff3.5_pnrauto"
# "wnd700_stp700_max25_diff5.0_pnrauto"

def mirror_MIR_Aligned(rec_path, mini_path):
    src = os.path.join(rec_path, "MIR_Aligned")
    dst = os.path.join(mini_path, "MIR_Aligned")
    print(f"DEBUG: src exists? {os.path.isdir(src)} → {src}")
    if not os.path.isdir(src):
        print(f"[mirror] no MIR_Aligned at {src}")
        return
    os.makedirs(dst, exist_ok=True)
    shutil.copytree(src, dst, dirs_exist_ok=True)
    print(f"[mirror] copied MIR_Aligned → {dst}")


generate_frame_mapping(
        rec_path_norm,
        mini_path_norm,
        nc_key,
        only_com = True,
        start_frame=0,
        end_frame=500,
        threshold_mini=13,
        threshold_sixcam=2.5
    )



mirror_MIR_Aligned(rec_path_norm, mini_path_norm)
# Out:
# Camera index with data_frame starting at 1: 1
# Saved plot to /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241216v1re1f/customEntValHere/2025_05_16/15_42_36/My_WebCam/sync_mini.png
# Saved plot to /data/big_rim/rsync_dcc_sum/Oct3V1/2025_05_16/20241216V1RE1Fmini_p20241224PMCLE1/sync_mini.png
# Saved plot to /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241216v1re1f/customEntValHere/2025_05_16/15_42_36/My_WebCam/sync_cam2.png
# Saved plot to /data/big_rim/rsync_dcc_sum/Oct3V1/2025_05_16/20241216V1RE1Fmini_p20241224PMCLE1/sync_cam2.png
# Aligned data saved to /data/big_rim/rsync_dcc_sum/Oct3V1/2025_05_16/20241216V1RE1Fmini_p20241224PMCLE1/MIR_Aligned/only_com_aligned_predictions.h5
# produced final h5 files
# Using CA file: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241216v1re1f/customEntValHere/2025_05_16/15_42_36/My_V4_Miniscope/minian_dataset_wnd1500_stp700_max25_diff4.0_pnr1.1.nc
# ...

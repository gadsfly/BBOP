# %%
import sys
import os
sys.path.append(os.path.abspath('../..'))
from utlis.sync_utlis.mini_dannce_sync import generate_frame_mapping

# %%
rec_path_norm = "/data/big_rim/rsync_dcc_sum/Oct3V1/2025_02_13/20241225PMCLE1mini_11_06"

mini_path_norm = "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241224PMCLE1/customEntValHere/2025_02_13/11_07_37/"


generate_frame_mapping(
        rec_path_norm,
        mini_path_norm,
        start_frame=0,
        end_frame=500,
        threshold_mini=12,
        threshold_sixcam=3
    )
# Out:
# Camera index with data_frame starting at 1: 1
# offset:  -4218.4741200000135
# pred current shape(13000, 3, 22)
# preds transposed to (13000, 22, 3)
# Aligned data saved to /data/big_rim/rsync_dcc_sum/Oct3V1/2025_02_13/20241225PMCLE1mini_11_06/MIR_Aligned/aligned_predictions.h5
# Frame mapping data saved to /data/big_rim/rsync_dcc_sum/Oct3V1/2025_02_13/20241225PMCLE1mini_11_06/MIR_Aligned/frame_mapping.json
# aligned_pred_3d_flat.shape: (4259, 66)
# aligned_pred_3d.shape: (4259, 22, 3)
# aligned_com.shape: (4259, 3)

# %%
ffmpeg -i input_video.mp4 -vf "fps=10,scale=640:-1:flags=lanczos" -t 10 output.gif

# %%
ffmpeg -i /home/lq53/mir_repos/BBOP/random_tests/25oct_dataset_prep/side_by_side.mp4 -vf "fps=10,scale=640:-1:flags=lanczos" -t 10 side_by_side.gif

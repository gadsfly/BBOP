# %%
import os
import sys


# Add project root so that the functions can be imported
sys.path.append(os.path.abspath('../..'))
from utlis.sync_utlis.mini_dannce_sync import (
    run_mini_dannce_sync
)

rec_path = "/data/big_rim/rsync_dcc_sum/Oct3V1/2025_02_27/20241015PMCBE1mini_12_24/"
mini_path = "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241015PMCBE1/customEntValHere/2025_02_27/12_25_53/"
key = "wnd700_stp700_max15_diff3.5_pnr1.1"

run_mini_dannce_sync(rec_path, mini_path, key,
                     start_frame=0,
    end_frame=500,
    threshold_mini=20,
    threshold_sixcam=3)
# Out:
# Camera index with data_frame starting at 1: 1
# offset:  -3974.9278559999957
# pred current shape(13000, 3, 22)
# preds transposed to (13000, 22, 3)
# Aligned data saved to /data/big_rim/rsync_dcc_sum/Oct3V1/2025_02_27/20241015PMCBE1mini_12_24/MIR_Aligned/aligned_predictions.h5
# Frame mapping data saved to /data/big_rim/rsync_dcc_sum/Oct3V1/2025_02_27/20241015PMCBE1mini_12_24/MIR_Aligned/frame_mapping.json
# aligned_pred_3d_flat.shape: (6376, 66)
# aligned_pred_3d.shape: (6376, 22, 3)
# aligned_com.shape: (6376, 3)
# Data loaded successfully!
# Calcium data shape: (45, 6722)
# Timestamps shape: (6722,)
# Interpolated Ca data shape: (45, 6376)
# ΔF/F interpolated shape: (45, 6376)
# DataFrame with Ca and ΔF/F signals merged:
# Updated DataFrame with Ca and ΔF/F data saved to /data/big_rim/rsync_dcc_sum/Oct3V1/2025_02_27/20241015PMCBE1mini_12_24/MIR_Aligned/aligned_predictions_with_ca_and_dF_F_wnd700_stp700_max15_diff3.5_pnr1.1.h5

# %%
import os
import sys


# Add project root so that the functions can be imported
sys.path.append(os.path.abspath('../..'))
from utlis.sync_utlis.mini_dannce_sync import (
    run_mini_dannce_sync
)

rec_path = "/data/big_rim/rsync_dcc_sum/Oct3V1/2025_02_13/20241225PMCLE1mini_11_06/"
mini_path = "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241224PMCLE1/customEntValHere/2025_02_13/11_07_37/"
key = "wnd1500_stp700_max15_diff3.5_pnrauto"

run_mini_dannce_sync(rec_path, mini_path, key,
                     start_frame=0,
    end_frame=500,
    threshold_mini=13,
    threshold_sixcam=3)

# %%
import sys
import os
sys.path.append(os.path.abspath('../..'))

from utlis.scan_engine_utlis.scan_eng_big_utlis import log_experiment_data
from status_field_config_mini_250220 import STATUS_FIELDS_CONFIG
if __name__ == "__main__":
    root_dir = "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted" #"/data/big_rim/mir_data/Oct3V1mini/Oct3V1mini_sorted"
    failed_paths_file = None #'/data/big_rim/mir_data/Oct3V1mini/Oct3V1mini_sorted/sync_failed.txt'
    manual_log_path = "/home/lq53/mir_repos/BBOP/random_tests/25mar_minibbop_integration/mini_sanity_240324_mannual.csv"
    # 1) Delete all parquet files first
    # remove_all_parquet_files(root_dir)

    # 2) Then log only My_V4_Miniscope
    force_reprocess = []
    rescan_days = 0.001  # Lower for quick re-scan testing

    log_experiment_data(root_dir, manual_log_path, failed_paths_file, STATUS_FIELDS_CONFIG,
                        force_reprocess=force_reprocess,
                        rescan_days=rescan_days) #manual_log_path
# Out:
# Match found: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241212v1l1r1/customEntValHere/2024_12_31/11_31_05/My_V4_Miniscope
# Match found: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_11_01/14_40_33/My_V4_Miniscope
# Match found: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240910-V1-R/customEntValHere/2024_11_01/13_09_59/My_V4_Miniscope
# Match found: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240910-V1-R/customEntValHere/2024_11_01/12_52_48/My_V4_Miniscope
# Match found: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_11_01/14_57_45/My_V4_Miniscope
# Match found: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240910-V1-R/customEntValHere/2024_11_01/11_39_00/My_V4_Miniscope
# Log for 20241212v1l1r1/customEntValHere/2024_12_31/11_31_05 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241212v1l1r1/customEntValHere/2024_12_31/11_31_05/folder_log.parquet
# Match found: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_31/11_31_56/My_V4_Miniscope
# Match found: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240919-V1-R1/customEntValHere/2024_12_18/11_22_07/My_V4_Miniscope
# Match found: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_31/11_50_32/My_V4_Miniscope
# Log for 20241002PMCLE1/customEntValHere/2025_02_27/14_00_06 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241002PMCLE1/customEntValHere/2025_02_27/14_00_06/folder_log.parquet
# Match found: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_17/14_09_19/My_V4_Miniscope
# Match found: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241002-pmc-r2/customEntValHere/2024_10_25/16_27_28/My_V4_Miniscope
# Match found: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_14/16_38_19/My_V4_Miniscope
# Match found: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241002-pmc-r2/customEntValHere/2024_10_25/15_50_39/My_V4_Miniscope
# Log for 20240919V1L5/customEntValHere/2024_10_31/13_14_16 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240919V1L5/customEntValHere/2024_10_31/13_14_16/folder_log.parquet
# Match found: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R2/customEntValHere/2024_10_14/16_03_58/My_V4_Miniscope
# Match found: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R2/customEntValHere/2024_10_14/14_23_28/My_V4_Miniscope
# Match found: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R2/customEntValHere/2024_10_25/14_31_19/My_V4_Miniscope
# Match found: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240717-PMC-r1/customEntValHere/2024_10_24/12_32_37/My_V4_Miniscope
# Match found: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241002-pmc-r2/customEntValHere/2024_10_25/17_09_14/My_V4_Miniscope
# Log for 20240919-V1-R1/customEntValHere/2024_12_31/14_24_53 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240919-V1-R1/customEntValHere/2024_12_31/14_24_53/folder_log.parquet
# Match found: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_17/14_25_32/My_V4_Miniscope
# Match found: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_14/14_54_12/My_V4_Miniscope
# Match found: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/202401015-PMC-r2/customEntValHere/2024_11_07/13_25_34/My_V4_Miniscope
# Match found: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_14/16_54_16/My_V4_Miniscope
# Log for 20241212v1l1r1/customEntValHere/2024_12_31/11_41_01 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241212v1l1r1/customEntValHere/2024_12_31/11_41_01/folder_log.parquet
# Match found: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241001-PMC-r2/customEntValHere/2024_10_24/16_20_26/My_V4_Miniscope
# Match found: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/202401015-PMC-r1/customEntValHere/2024_11_07/14_53_09/My_V4_Miniscope
# Match found: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/202401015-PMC-r1/customEntValHere/2024_11_06/16_16_30/My_V4_Miniscope
# Match found: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241001-PMC-r2/customEntValHere/2024_10_24/15_27_55/My_V4_Miniscope
# Match found: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/202401015-PMC-r2/customEntValHere/2024_11_07/13_04_45/My_V4_Miniscope
# Log for 20240819-V1-r1/customEntValHere/2024_09_18/13_54_22 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_09_18/13_54_22/folder_log.parquet
# Match found: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241001PMCRE2/customEntValHere/2025_02_12/14_01_13/My_V4_Miniscope
# Match found: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/202401015-PMC-r2/customEntValHere/2024_11_06/17_13_26/My_V4_Miniscope
# Log for 20240919-V1-R1/customEntValHere/2024_12_18/11_33_01 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240919-V1-R1/customEntValHere/2024_12_18/11_33_01/folder_log.parquet
# Match found: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241001PMCRE2/customEntValHere/2025_02_12/15_36_16/My_V4_Miniscope
# Match found: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240919-V1-R2/customEntValHere/2024_12_18/13_08_19/My_V4_Miniscope
# Match found: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241001PMCRE2/customEntValHere/2025_02_12/13_45_01/My_V4_Miniscope
# Match found: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241002-PMC-R1/customEntValHere/2024_10_25/15_02_11/My_V4_Miniscope
# Log for 20240819-V1-r1/customEntValHere/2024_10_04/14_18_19 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_04/14_18_19/folder_log.parquet
# Match found: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241212v1l1r2/customEntValHere/2024_12_31/12_07_27/My_V4_Miniscope
# Match found: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/202401015-PMC-r2/customEntValHere/2024_11_06/16_57_35/My_V4_Miniscope
# Match found: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240919-V1-R2/customEntValHere/2024_12_31/13_55_41/My_V4_Miniscope
# Match found: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241002-PMC-R1/customEntValHere/2024_10_24/13_07_09/My_V4_Miniscope
# Match found: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241224PMCLE1/customEntValHere/2025_02_13/11_07_37/My_V4_Miniscope
# Match found: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241015PMCBE1/customEntValHere/2025_02_27/12_25_53/My_V4_Miniscope
# Log for 20241002PMCLE1/customEntValHere/2025_02_27/14_10_39 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241002PMCLE1/customEntValHere/2025_02_27/14_10_39/folder_log.parquet
# Log for 20240919-V1-R1/customEntValHere/2024_12_31/14_31_31 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240919-V1-R1/customEntValHere/2024_12_31/14_31_31/folder_log.parquet
# Log for 20240819-V1-r1/customEntValHere/2024_11_01/14_40_33 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_11_01/14_40_33/folder_log.parquet
# Log for 20240819-V1-r1/customEntValHere/2024_09_17/15_46_29 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_09_17/15_46_29/folder_log.parquet
# Log for 20240819-V1-r1/customEntValHere/2024_10_04/21_41_08 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_04/21_41_08/folder_log.parquet
# Log for 20240910-V1-R/customEntValHere/2024_11_13/16_18_24 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240910-V1-R/customEntValHere/2024_11_13/16_18_24/folder_log.parquet
# Log for 20240910-V1-R/customEntValHere/2024_11_01/13_09_59 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240910-V1-R/customEntValHere/2024_11_01/13_09_59/folder_log.parquet
# Log for 20240819-V1-r1/customEntValHere/2024_10_04/21_08_15 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_04/21_08_15/folder_log.parquet
# Log for 20240910-V1-R/customEntValHere/2024_11_01/12_52_48 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240910-V1-R/customEntValHere/2024_11_01/12_52_48/folder_log.parquet
# Log for 20240819-V1-r1/customEntValHere/2024_10_04/20_16_14 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_04/20_16_14/folder_log.parquet
# Log for 20240819-V1-r1/customEntValHere/2024_11_01/14_57_45 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_11_01/14_57_45/folder_log.parquet
# Log for 20240910-V1-R/customEntValHere/2024_11_01/11_39_00 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240910-V1-R/customEntValHere/2024_11_01/11_39_00/folder_log.parquet
# Log for 20241002PMCLE1/customEntValHere/2025_02_27/14_00_26 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241002PMCLE1/customEntValHere/2025_02_27/14_00_26/folder_log.parquet
# Log for 20240819-V1-r1/customEntValHere/2024_10_31/11_31_56 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_31/11_31_56/folder_log.parquet
# Log for 2024-016v1l1r1/customEntValHere/2025_01_23/19_17_52 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/2024-016v1l1r1/customEntValHere/2025_01_23/19_17_52/folder_log.parquet
# Log for 20240819-V1-r1/customEntValHere/2024_09_17/15_33_52 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_09_17/15_33_52/folder_log.parquet
# Log for 20240919V1L5/customEntValHere/2024_10_31/13_24_56 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240919V1L5/customEntValHere/2024_10_31/13_24_56/folder_log.parquet
# Log for 20240919-V1-R1/customEntValHere/2024_12_18/11_22_07 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240919-V1-R1/customEntValHere/2024_12_18/11_22_07/folder_log.parquet
# Log for 20240819-V1-r1/customEntValHere/2024_10_08/20_48_38 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_08/20_48_38/folder_log.parquet
# Log for 20240819-V1-r1/customEntValHere/2024_10_31/11_50_32 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_31/11_50_32/folder_log.parquet
# Log for 20240916-V1-R2/customEntValHere/2024_10_04/15_23_59 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R2/customEntValHere/2024_10_04/15_23_59/folder_log.parquet
# Log for 20240819-V1-r1/customEntValHere/2024_09_18/13_34_29 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_09_18/13_34_29/folder_log.parquet
# Log for 20241002-pmc-r2/customEntValHere/2024_10_25/16_43_45 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241002-pmc-r2/customEntValHere/2024_10_25/16_43_45/folder_log.parquet
# Log for 20240819-V1-r1/customEntValHere/2024_09_18/13_55_04 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_09_18/13_55_04/folder_log.parquet
# Log for 20240819-V1-r1/customEntValHere/2024_10_17/14_09_19 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_17/14_09_19/folder_log.parquet
# Log for 20240916-V1-R2/customEntValHere/2024_10_25/14_30_45 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R2/customEntValHere/2024_10_25/14_30_45/folder_log.parquet
# Log for 20240819-V1-r1/customEntValHere/2024_10_08/20_16_41 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_08/20_16_41/folder_log.parquet
# Log for 20240916-V1-R1/customEntValHere/2024_10_14/16_36_18 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_14/16_36_18/folder_log.parquet
# Log for 20240717-PMC-r1/customEntValHere/2024_10_24/#12_32_37 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240717-PMC-r1/customEntValHere/2024_10_24/#12_32_37/folder_log.parquet
# Log for 20241002-pmc-r2/customEntValHere/2024_10_25/17_24_56 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241002-pmc-r2/customEntValHere/2024_10_25/17_24_56/folder_log.parquet
# Log for 20241002-pmc-r2/customEntValHere/2024_10_25/16_27_28 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241002-pmc-r2/customEntValHere/2024_10_25/16_27_28/folder_log.parquet
# Log for 20240916-V1-R1/customEntValHere/2024_10_14/16_38_19 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_14/16_38_19/folder_log.parquet
# Log for 20240916-V1-R1/customEntValHere/2024_10_07/19_10_41 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_07/19_10_41/folder_log.parquet
# Log for 20240916-V1-R1/customEntValHere/2024_10_07/18_16_09 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_07/18_16_09/folder_log.parquet
# Log for 20241002-pmc-r2/customEntValHere/2024_10_25/15_50_39 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241002-pmc-r2/customEntValHere/2024_10_25/15_50_39/folder_log.parquet
# Log for 20240916-V1-R1/customEntValHere/2024_10_07/14_53_59 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_07/14_53_59/folder_log.parquet
# Log for 20240819-V1-r1/customEntValHere/2024_10_17/14_41_28 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_17/14_41_28/folder_log.parquet
# Log for 20240916-V1-R2/customEntValHere/2024_10_14/16_03_58 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R2/customEntValHere/2024_10_14/16_03_58/folder_log.parquet
# Log for 20240916-V1-R1/customEntValHere/2024_10_07/15_57_40 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_07/15_57_40/folder_log.parquet
# Log for 20240916-V1-R1/customEntValHere/2024_10_07/18_55_00 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_07/18_55_00/folder_log.parquet
# Log for 20240916-V1-R2/customEntValHere/2024_10_14/14_23_28 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R2/customEntValHere/2024_10_14/14_23_28/folder_log.parquet
# Log for 20240916-V1-R2/customEntValHere/2024_10_25/14_31_19 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R2/customEntValHere/2024_10_25/14_31_19/folder_log.parquet
# Log for 20240717-PMC-r1/customEntValHere/2024_10_24/12_32_37 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240717-PMC-r1/customEntValHere/2024_10_24/12_32_37/folder_log.parquet
# Log for 20240916-V1-R1/customEntValHere/2024_10_07/18_00_05 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_07/18_00_05/folder_log.parquet
# Log for 20240819-V1-r1/customEntValHere/2024_10_08/19_44_49 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_08/19_44_49/folder_log.parquet
# Log for 20240916-V1-R1/customEntValHere/2024_10_07/19_18_47 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_07/19_18_47/folder_log.parquet
# Log for 20240916-V1-R1/customEntValHere/2024_10_04/14_49_29 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_04/14_49_29/folder_log.parquet
# Log for 20240819-V1-r1/customEntValHere/2024_10_08/20_32_38 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_08/20_32_38/folder_log.parquet
# Log for 20240916-V1-R1/customEntValHere/2024_10_14/15_10_18 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_14/15_10_18/folder_log.parquet
# Log for 20241002-pmc-r2/customEntValHere/2024_10_25/17_09_14 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241002-pmc-r2/customEntValHere/2024_10_25/17_09_14/folder_log.parquet
# Log for 20240916-V1-R1/customEntValHere/2024_10_08/15_53_33 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_08/15_53_33/folder_log.parquet
# Log for 20240819-V1-r1/customEntValHere/2024_10_17/14_25_32 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_17/14_25_32/folder_log.parquet
# Log for 20240916-V1-R1/customEntValHere/2024_10_14/14_54_12 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_14/14_54_12/folder_log.parquet
# Log for 20240916-V1-R1/customEntValHere/2024_10_08/14_08_38 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_08/14_08_38/folder_log.parquet
# Log for 20240916-V1-R1/customEntValHere/2024_10_08/16_06_49 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_08/16_06_49/folder_log.parquet
# Log for 20240916-V1-R1/customEntValHere/2024_10_08/15_36_19 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_08/15_36_19/folder_log.parquet
# Log for 20240916-V1-R1/customEntValHere/2024_10_08/16_23_13 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_08/16_23_13/folder_log.parquet
# Log for 20240916-V1-R1/customEntValHere/2024_10_08/14_24_58 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_08/14_24_58/folder_log.parquet
# Log for 202401015-PMC-r2/customEntValHere/2024_11_07/13_25_34 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/202401015-PMC-r2/customEntValHere/2024_11_07/13_25_34/folder_log.parquet
# Log for 20240916-V1-R1/customEntValHere/2024_10_14/16_54_16 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_14/16_54_16/folder_log.parquet
# Log for 20241001PMCRE2/customEntValHere/2025_02_12/15_32_01 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241001PMCRE2/customEntValHere/2025_02_12/15_32_01/folder_log.parquet
# Log for 20240819-V1-r1/customEntValHere/2024_10_08/20_00_58 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_08/20_00_58/folder_log.parquet
# Log for 202401015-PMC-r2/customEntValHere/2024_11_06/16_47_29 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/202401015-PMC-r2/customEntValHere/2024_11_06/16_47_29/folder_log.parquet
# Log for 20241001PMCRE2/customEntValHere/2025_02_12/15_18_28 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241001PMCRE2/customEntValHere/2025_02_12/15_18_28/folder_log.parquet
# Log for 20240916-V1-R1/customEntValHere/2024_10_07/15_07_56 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_07/15_07_56/folder_log.parquet
# Log for 20241001-PMC-r2/customEntValHere/2024_10_24/16_20_26 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241001-PMC-r2/customEntValHere/2024_10_24/16_20_26/folder_log.parquet
# Log for 20241001-PMC-r2/customEntValHere/2024_10_24/16_04_24 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241001-PMC-r2/customEntValHere/2024_10_24/16_04_24/folder_log.parquet
# Log for 202401015-PMC-r1/customEntValHere/2024_11_07/14_53_09 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/202401015-PMC-r1/customEntValHere/2024_11_07/14_53_09/folder_log.parquet
# Log for 202401015-PMC-r1/customEntValHere/2024_11_06/16_16_30 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/202401015-PMC-r1/customEntValHere/2024_11_06/16_16_30/folder_log.parquet
# Log for 202401015-PMC-r1/customEntValHere/2024_11_06/15_37_17 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/202401015-PMC-r1/customEntValHere/2024_11_06/15_37_17/folder_log.parquet
# Log for 20240916-V1-R1/customEntValHere/2024_10_08/14_41_53 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_08/14_41_53/folder_log.parquet
# Log for 20241001-PMC-r2/customEntValHere/2024_10_24/15_27_55 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241001-PMC-r2/customEntValHere/2024_10_24/15_27_55/folder_log.parquet
# Log for 20241212v1l1r2/customEntValHere/2024_12_31/12_15_27 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241212v1l1r2/customEntValHere/2024_12_31/12_15_27/folder_log.parquet
# Log for 202401015-PMC-r2/customEntValHere/2024_11_07/13_04_45 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/202401015-PMC-r2/customEntValHere/2024_11_07/13_04_45/folder_log.parquet
# Log for 20241001PMCRE2/customEntValHere/2025_02_12/14_01_13 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241001PMCRE2/customEntValHere/2025_02_12/14_01_13/folder_log.parquet
# Log for 202401015-PMC-r2/customEntValHere/2024_11_06/17_13_26 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/202401015-PMC-r2/customEntValHere/2024_11_06/17_13_26/folder_log.parquet
# Log for 20241212v1l1r2/customEntValHere/2024_12_31/11_56_32 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241212v1l1r2/customEntValHere/2024_12_31/11_56_32/folder_log.parquet
# Log for 20241001PMCRE2/customEntValHere/2025_02_12/15_23_02 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241001PMCRE2/customEntValHere/2025_02_12/15_23_02/folder_log.parquet
# Log for 202401015-PMC-r1/customEntValHere/2024_11_07/14_36_12 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/202401015-PMC-r1/customEntValHere/2024_11_07/14_36_12/folder_log.parquet
# Log for 20241002-PMC-R1/customEntValHere/2024_10_25/15_18_32 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241002-PMC-R1/customEntValHere/2024_10_25/15_18_32/folder_log.parquet
# Log for 20241001PMCRE2/customEntValHere/2025_02_12/15_36_16 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241001PMCRE2/customEntValHere/2025_02_12/15_36_16/folder_log.parquet
# Log for 20241224PMCLE1/customEntValHere/2025_02_13/11_00_39 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241224PMCLE1/customEntValHere/2025_02_13/11_00_39/folder_log.parquet
# Log for 20240919-V1-R2/customEntValHere/2024_12_18/13_08_19 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240919-V1-R2/customEntValHere/2024_12_18/13_08_19/folder_log.parquet
# Log for 20241224PMCLE1/customEntValHere/2025_03_11/14_43_22 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241224PMCLE1/customEntValHere/2025_03_11/14_43_22/folder_log.parquet
# Log for 20241002-PMC-R1/customEntValHere/2024_10_24/13_23_51 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241002-PMC-R1/customEntValHere/2024_10_24/13_23_51/folder_log.parquet
# Log for 20241224PMCLE1/customEntValHere/2025_02_13/10_52_07 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241224PMCLE1/customEntValHere/2025_02_13/10_52_07/folder_log.parquet
# Log for 20241001PMCRE2/customEntValHere/2025_02_12/13_45_01 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241001PMCRE2/customEntValHere/2025_02_12/13_45_01/folder_log.parquet
# Log for 20241015PMCBE1/customEntValHere/2025_02_27/12_34_44 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241015PMCBE1/customEntValHere/2025_02_27/12_34_44/folder_log.parquet
# Log for 20240919-V1-R2/customEntValHere/2024_12_18/13_26_38 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240919-V1-R2/customEntValHere/2024_12_18/13_26_38/folder_log.parquet
# Log for 20241002-PMC-R1/customEntValHere/2024_10_25/15_02_11 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241002-PMC-R1/customEntValHere/2024_10_25/15_02_11/folder_log.parquet
# Log for 20240919-V1-R2/customEntValHere/2024_12_18/13_16_57 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240919-V1-R2/customEntValHere/2024_12_18/13_16_57/folder_log.parquet
# Log for 20241212v1l1r2/customEntValHere/2024_12_31/12_07_27 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241212v1l1r2/customEntValHere/2024_12_31/12_07_27/folder_log.parquet
# Log for 20240919-V1-R2/customEntValHere/2024_12_31/14_05_14 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240919-V1-R2/customEntValHere/2024_12_31/14_05_14/folder_log.parquet
# Log for 20241224PMCLE1/customEntValHere/2025_03_11/14_46_25 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241224PMCLE1/customEntValHere/2025_03_11/14_46_25/folder_log.parquet
# Log for 20241224PMCLE1/customEntValHere/2025_03_11/14_10_14 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241224PMCLE1/customEntValHere/2025_03_11/14_10_14/folder_log.parquet
# Log for 20241224PMCLE1/customEntValHere/2025_03_11/14_22_12 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241224PMCLE1/customEntValHere/2025_03_11/14_22_12/folder_log.parquet
# Log for 202401015-PMC-r2/customEntValHere/2024_11_06/16_57_35 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/202401015-PMC-r2/customEntValHere/2024_11_06/16_57_35/folder_log.parquet
# Log for 20241224PMCLE1/customEntValHere/2025_02_13/11_16_46 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241224PMCLE1/customEntValHere/2025_02_13/11_16_46/folder_log.parquet
# Log for 20241224PMCLE1/customEntValHere/2025_02_13/10_56_08 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241224PMCLE1/customEntValHere/2025_02_13/10_56_08/folder_log.parquet
# Log for 20240919-V1-R2/customEntValHere/2024_12_31/13_55_41 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240919-V1-R2/customEntValHere/2024_12_31/13_55_41/folder_log.parquet
# Log for 20241002-PMC-R1/customEntValHere/2024_10_24/13_07_09 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241002-PMC-R1/customEntValHere/2024_10_24/13_07_09/folder_log.parquet
# Log for 20241212v1l1r2/customEntValHere/2024_12_31/12_16_45 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241212v1l1r2/customEntValHere/2024_12_31/12_16_45/folder_log.parquet
# Log for 20241224PMCLE1/customEntValHere/2025_02_13/11_07_37 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241224PMCLE1/customEntValHere/2025_02_13/11_07_37/folder_log.parquet
# Log for 20241224PMCLE1/customEntValHere/2025_02_13/11_58_39 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241224PMCLE1/customEntValHere/2025_02_13/11_58_39/folder_log.parquet
# Log for 20241015PMCBE1/customEntValHere/2025_02_27/12_25_53 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241015PMCBE1/customEntValHere/2025_02_27/12_25_53/folder_log.parquet
# Log for 20241224PMCLE1/customEntValHere/2025_02_13/11_23_53 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241224PMCLE1/customEntValHere/2025_02_13/11_23_53/folder_log.parquet
# Log for 20241224PMCLE1/customEntValHere/2025_03_11/14_13_12 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241224PMCLE1/customEntValHere/2025_03_11/14_13_12/folder_log.parquet
# Log for 20241224PMCLE1/customEntValHere/2025_02_13/11_48_21 saved at /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241224PMCLE1/customEntValHere/2025_02_13/11_48_21/folder_log.parquet

# %%
# sys.path.append(os.path.abspath('../..'))
from utlis.scan_engine_utlis.scan_engine_utlis import read_all_parquet_files
# base_folder = "/hpc/group/tdunn/Bryan_Rigs/BigOpenField/24summ"
all_mini = read_all_parquet_files(root_dir)

# %%
import pyarrow.compute as pc
table = all_mini #combined_df


filter_mask = pc.and_(
    pc.equal(table['minian'], '0'), 
    pc.equal(table['valid_rec'], '1') #not_equal
)


# Apply the filter and print the results
filtered_table_mini = table.filter(filter_mask)

# Print each row of the filtered table
print(filtered_table_mini.to_pandas())  # This will display the filtered data in a familiar pandas-like format
# Out:
#   minian minian_selected valid_rec                   timestamp  \
# 0      0               0         1  2025-03-25T13:35:13.420218
# 1      0               0         1  2025-03-25T13:35:13.438425
# 2      0               0         1  2025-03-25T13:35:13.443312
# 3      0               0         1  2025-03-25T13:35:13.392047
# 4      0               0         1  2025-03-25T13:35:13.443494
# 5      0               0         1  2025-03-25T13:35:13.445259
# 6      0               0         1  2025-03-25T13:35:13.445531
#
#          animal_id      custom_label        date       time
# 0  20240717-PMC-r1  customEntValHere  2024_10_24  #12_32_37
# 1   20241001PMCRE2  customEntValHere  2025_02_12   15_23_02
# 2  20241002-PMC-R1  customEntValHere  2024_10_24   13_23_51
# 3   20241212v1l1r1  customEntValHere  2024_12_31   11_41_01
# 4   20241224PMCLE1  customEntValHere  2025_02_13   11_23_53
# 5   20241224PMCLE1  customEntValHere  2025_02_13   11_48_21
# 6   20241224PMCLE1  customEntValHere  2025_02_13   11_58_39

# %%
import pyarrow as pa
import subprocess
import os

def run_param_search_from_table(filtered_table_mini):
    """
    Iterate through each row in `filtered_table_mini` (a PyArrow Table),
    construct the session_dir from relevant columns, and then call
    param_search_driver.py in a subprocess with the desired arguments.
    """
    # Convert table to a list of dictionaries, each representing one row
    rows = filtered_table_mini.to_pylist()

    for row in rows:
        # Extract needed columns (adjust the column names as necessary)
        # e.g. row["animal_id"], row["custom_label"], row["date"], row["time"]
        animal_id    = row["animal_id"]       # e.g. "20241015PMCBE1"
        custom_label = row["custom_label"]    # e.g. "customEntValHere"
        date_str     = row["date"]            # e.g. "2025_03_11"
        time_str     = row["time"]            # e.g. "14_22_12"

        # Build the session_dir path based on your folder structure.
        # Example:
        #   /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/{animal_id}/{custom_label}/{date_str}/{time_str}/My_V4_Miniscope
        session_dir = os.path.join(
            "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted",
            animal_id,
            custom_label,
            date_str,
            time_str,
            "My_V4_Miniscope"
        )

        # (Optional) Check that it exists or not, or create if needed:
        if not os.path.exists(session_dir):
            print(f"Warning: session_dir not found: {session_dir}")
            # If you want to create it:
            # os.makedirs(session_dir, exist_ok=True)

        print(f"\n=== Running param_search_driver for session ===")
        print(f"Animal:       {animal_id}")
        print(f"Session dir:  {session_dir}")

        # Now call param_search_driver.py, passing in the appropriate args.
        # Adjust environment calls if needed (conda, absolute path, etc.)
        cmd = [
            "conda", "run", "-n", "minian",
            "python",               # or "conda", "run", "-n", "my_env", "python" if you prefer
            "param_search_driver_single.py",
            "--session_dir", session_dir,
            "--animal", animal_id
        ]

        result = subprocess.run(cmd, capture_output=True, text=True)
        
        if result.stdout:
            print("[STDOUT]", result.stdout)
        if result.stderr:
            print("[STDERR]", result.stderr)

# Example usage:
# Suppose you've already loaded your arrow table into `filtered_table_mini`.
# You can now call:

run_param_search_from_table(filtered_table_mini)
# Out:
# === Running param_search_driver for session ===
# Animal:       20240717-PMC-r1
# Session dir:  /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240717-PMC-r1/customEntValHere/2024_10_24/#12_32_37/My_V4_Miniscope
# [STDOUT] Running combination: wnd1500_stp700_max15_diff3.0_pnr1.1
# Errors: python: can't open file 'minian_mirpy_set.py': [Errno 2] No such file or directory
#
# Warning: Output file not found for combination wnd1500_stp700_max15_diff3.0_pnr1.1.
#
#
#
# === Running param_search_driver for session ===
# Animal:       20241001PMCRE2
# Session dir:  /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241001PMCRE2/customEntValHere/2025_02_12/15_23_02/My_V4_Miniscope
# [STDOUT] Running combination: wnd1500_stp700_max15_diff3.0_pnr1.1
# loading 9 videos in folder /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241001PMCRE2/customEntValHere/2025_02_12/15_23_02/My_V4_Miniscope
# constructing chunks
# computing max projections
# calculating local maximum
# selecting seeds
# computing peak-noise ratio
# selecting seeds
# performing KS test
# computing distance
# computing correlations
# pixel recompute ratio: 0.9620853080568721
# computing correlations
# merging seeds
# optimizing computation graph
# pixel recompute ratio: 1.0146835443037974
# computing correlations
# building spatial matrix
# computing spatial overlap
# computing temporal correlation
# pixel recompute ratio: 0.0
# computing correlations
#
# Errors: ffmpeg version 4.2.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.5.0 (crosstool-NG 1.24.0.123_1667d2b)
#   configuration: --prefix=/home/lq53/miniconda3/envs/minian --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1590573566052/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# ffmpeg version 4.2.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.5.0 (crosstool-NG 1.24.0.123_1667d2b)
#   configuration: --prefix=/home/lq53/miniconda3/envs/minian --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1590573566052/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# ffmpeg version 4.2.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.5.0 (crosstool-NG 1.24.0.123_1667d2b)
#   configuration: --prefix=/home/lq53/miniconda3/envs/minian --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1590573566052/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, avi, from '/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241001PMCRE2/customEntValHere/2025_02_12/15_23_02/My_V4_Miniscope/0.avi':
#   Metadata:
#     encoder         : Lavf58.29.100
#   Duration: 00:00:16.67, start: 0.000000, bitrate: 79640 kb/s
#     Stream #0:0: Video: ffv1 (FFV1 / 0x31564646), gray, 600x600, 79705 kb/s, 60 fps, 60 tbr, 60 tbn, 60 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (ffv1 (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# ffmpeg version 4.2.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.5.0 (crosstool-NG 1.24.0.123_1667d2b)
#   configuration: --prefix=/home/lq53/miniconda3/envs/minian --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1590573566052/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame
# ffmpeg version 4.2.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.5.0 (crosstool-NG 1.24.0.123_1667d2b)
#   configuration: --prefix=/home/lq53/miniconda3/envs/minian --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1590573566052/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, avi, from '/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241001PMCRE2/customEntValHere/2025_02_12/15_23_02/My_V4_Miniscope/1.avi':
#   Metadata:
#     encoder         : Lavf58.29.100
#   Duration: 00:00:16.67, start: 0.000000, bitrate: 79343 kb/s
#     Stream #0:0: Video: ffv1 (FFV1 / 0x31564646), gray, 600x600, 79408 kb/s, 60 fps, 60 tbr, 60 tbn, 60 tbc
# Input #0, avi, from '/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241001PMCRE2/customEntValHere/2025_02_12/15_23_02/My_V4_Miniscope/3.avi':
#   Metadata:
#     encoder         : Lavf58.29.100
#   Duration: 00:00:16.67, start: 0.000000, bitrate: 79607 kb/s
#     Stream #0:0: Video: ffv1 (FFV1 / 0x31564646), gray, 600x600, 79673 kb/s, 60 fps, 60 tbr, 60 tbn, 60 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (ffv1 (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Stream mapping:
#   Stream #0:0 -> #0:0 (ffv1 (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# ffmpeg version 4.2.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.5.0 (crosstool-NG 1.24.0.123_1667d2b)
#   configuration: --prefix=/home/lq53/miniconda3/envs/minian --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1590573566052/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, avi, from '/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241001PMCRE2/customEntValHere/2025_02_12/15_23_02/My_V4_Miniscope/4.avi':
#   Metadata:
#     encoder         : Lavf58.29.100
#   Duration: 00:00:16.67, start: Input #0, avi, from '/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241001PMCRE2/customEntValHere/2025_02_12/15_23_02/My_V4_Miniscope/2.avi':
# 0.000000, bitrate:   Metadata:
# 79644 kb/s    encoder         :
# Lavf58.29.100
#   Duration: 00:00:16.67, start: 0.000000, bitrate: 79428 kb/s
#     Stream #0:0: Video: ffv1 (FFV1 / 0x31564646), gray, 600x600, 79710 kb/s, 60 fps, 60 tbr, 60 tbn,     Stream #0:060 tbc: Video: ffv1 (FFV1 / 0x31564646), gray, 600x600, 79493 kb/s
# , 60 fps, 60 tbr, 60 tbn, 60 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (ffv1 (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Stream mapping:
#   Stream #0:0 -> #0:0 (ffv1 (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: rawvideo (Y800 / 0x30303859), gray, 600x600, q=2-31, 172800 kb/s, ffmpeg version 4.2.360 fps, 60 tbn, 60 tbc Copyright (c) 2000-2020 the FFmpeg developers
#
#     Metadata:
#   built with gcc 7.5.0 (crosstool-NG 1.24.0.123_1667d2b)
#       encoder         : Lavc58.54.100 rawvideo  configuration: --prefix=/home/lq53/miniconda3/envs/minian --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1590573566052/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame
#
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# ffmpeg version 4.2.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.5.0 (crosstool-NG 1.24.0.123_1667d2b)
#   configuration: --prefix=/home/lq53/miniconda3/envs/minian --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1590573566052/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, avi, from '/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241001PMCRE2/customEntValHere/2025_02_12/15_23_02/My_V4_Miniscope/5.avi':
#   Metadata:
#     encoder         : Lavf58.29.100
#   Duration: 00:00:16.67, start: 0.000000, bitrate: 79220 kb/s
#     Stream #0:0: Video: ffv1 (FFV1 / 0x31564646), gray, 600x600, 79285 kb/s, 60 fps, 60 tbr, 60 tbn, 60 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (ffv1 (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: rawvideo (Y800 / 0x30303859), gray, 600x600, q=2-31, 172800 kb/s, 60 fps, 60 tbn, 60 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 rawvideo
# Input #0, avi, from '/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241001PMCRE2/customEntValHere/2025_02_12/15_23_02/My_V4_Miniscope/7.avi':
#   Metadata:
#     encoder         : Lavf58.29.100
#   Duration: 00:00:16.67, start: 0.000000, bitrate: 79062 kb/s
#     Stream #0:0: Video: ffv1 (FFV1 / 0x31564646), gray, 600x600, 79127 kb/s, 60 fps, 60 tbr, 60 tbn, 60 tbc
# Input #0, avi, from '/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241001PMCRE2/customEntValHere/2025_02_12/15_23_02/My_V4_Miniscope/6.avi':
#   Metadata:
#     encoder         : Lavf58.29.100
#   Duration: 00:00:16.67, start: 0.000000, bitrate: 79450 kb/s
#     Stream #0:0: Video: ffv1 (FFV1 / 0x31564646), gray, 600x600, 79515 kb/s, 60 fps, 60 tbr, 60 tbn, 60 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (ffv1 (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Stream mapping:
#   Stream #0:0 -> #0:0 (ffv1 (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: rawvideo (Y800 / 0x30303859), gray, 600x600, q=2-31, 172800 kb/s, 60 fps, 60 tbn, 60 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 rawvideo
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: rawvideo (Y800 / 0x30303859), gray, 600x600, q=2-31, 172800 kb/s, 60 fps, 60 tbn, 60 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 rawvideo
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: rawvideo (Y800 / 0x30303859), gray, 600x600, q=2-31, 172800 kb/s, 60 fps, 60 tbn, 60 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 rawvideo
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: rawvideo (Y800 / 0x30303859), gray, 600x600, q=2-31, 172800 kb/s, 60 fps, 60 tbn, 60 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 rawvideo
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: rawvideo (Y800 / 0x30303859), gray, 600x600, q=2-31, 172800 kb/s, 60 fps, 60 tbn, 60 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 rawvideo
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: rawvideo (Y800 / 0x30303859), gray, 600x600, q=2-31, 172800 kb/s, 60 fps, 60 tbn, 60 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 rawvideo
# frame=  205 fps=0.0 q=-0.0 size=   72070kB time=00:00:03.41 bitrate=172800.0kbits/s speed=6.79x
# frame=  215 fps=0.0 q=-0.0 size=   75586kB time=00:00:03.58 bitrate=172800.0kbits/s speed=7.17x
# frame=  214 fps=0.0 q=-0.0 size=   75234kB time=00:00:03.56 bitrate=172800.0kbits/s speed=7.06x
# frame=  176 fps=0.0 q=-0.0 size=   61875kB time=00:00:02.93 bitrate=172800.0kbits/s speed=5.86x
# frame=  216 fps=0.0 q=-0.0 size=   75938kB time=00:00:03.60 bitrate=172800.0kbits/s speed=7.14x
# frame=  181 fps=0.0 q=-0.0 size=   63633kB time=00:00:03.01 bitrate=172800.0kbits/s speed=6.02x
# frame=  203 fps=0.0 q=-0.0 size=   71367kB time=00:00:03.38 bitrate=172800.0kbits/s speed=6.76x
# frame=  180 fps=0.0 q=-0.0 size=   63281kB time=00:00:03.00 bitrate=172800.0kbits/s speed=5.86x
# frame=  317 fps=317 q=-0.0 size=  111445kB time=00:00:05.28 bitrate=172800.0kbits/s speed=5.28x
# frame=  414 fps=412 q=-0.0 size=  145547kB time=00:00:06.90 bitrate=172800.0kbits/s speed=6.87x
# frame=  395 fps=394 q=-0.0 size=  138867kB time=00:00:06.58 bitrate=172800.0kbits/s speed=6.56x
# frame=  408 fps=403 q=-0.0 size=  143438kB time=00:00:06.80 bitrate=172800.0kbits/s speed=6.72x
# frame=  397 fps=396 q=-0.0 size=  139570kB time=00:00:06.61 bitrate=172800.0kbits/s speed= 6.6x
# frame=  361 fps=358 q=-0.0 size=  126914kB time=00:00:06.01 bitrate=172800.0kbits/s speed=5.96x
# frame=  372 fps=369 q=-0.0 size=  130781kB time=00:00:06.20 bitrate=172800.0kbits/s speed=6.14x
# frame=  335 fps=330 q=-0.0 size=  117773kB time=00:00:05.58 bitrate=172800.0kbits/s speed= 5.5x
# frame=  489 fps=325 q=-0.0 size=  171914kB time=00:00:08.15 bitrate=172800.0kbits/s speed=5.42x
# frame=  598 fps=394 q=-0.0 size=  210234kB time=00:00:09.96 bitrate=172800.0kbits/s speed=6.57x
# frame=  576 fps=382 q=-0.0 size=  202500kB time=00:00:09.60 bitrate=172800.0kbits/s speed=6.36x
# frame=  608 fps=402 q=-0.0 size=  213750kB time=00:00:10.13 bitrate=172800.0kbits/s speed=6.69x
# frame=  587 fps=389 q=-0.0 size=  206367kB time=00:00:09.78 bitrate=172800.0kbits/s speed=6.48x
# frame=  571 fps=376 q=-0.0 size=  200742kB time=00:00:09.51 bitrate=172800.0kbits/s speed=6.27x
# frame=  527 fps=348 q=-0.0 size=  185273kB time=00:00:08.78 bitrate=172800.0kbits/s speed= 5.8x
# frame=  490 fps=322 q=-0.0 size=  172266kB time=00:00:08.16 bitrate=172800.0kbits/s speed=5.37x
# frame=  685 fps=341 q=-0.0 size=  240820kB time=00:00:11.41 bitrate=172800.0kbits/s speed=5.69x
# frame=  780 fps=387 q=-0.0 size=  274219kB time=00:00:13.00 bitrate=172800.0kbits/s speed=6.44x
# frame=  756 fps=376 q=-0.0 size=  265781kB time=00:00:12.60 bitrate=172800.0kbits/s speed=6.26x
# frame=  767 fps=381 q=-0.0 size=  269648kB time=00:00:12.78 bitrate=172800.0kbits/s speed=6.34x
# frame=  718 fps=355 q=-0.0 size=  252422kB time=00:00:11.96 bitrate=172800.0kbits/s speed=5.92x
# frame=  742 fps=368 q=-0.0 size=  260859kB time=00:00:12.36 bitrate=172800.0kbits/s speed=6.14x
# frame=  717 fps=356 q=-0.0 size=  252070kB time=00:00:11.95 bitrate=172800.0kbits/s speed=5.93x
# frame=  681 fps=336 q=-0.0 size=  239414kB time=00:00:11.35 bitrate=172800.0kbits/s speed=5.59x
# frame=  863 fps=344 q=-0.0 size=  303398kB time=00:00:14.38 bitrate=172800.0kbits/s speed=5.73x
# frame=  947 fps=376 q=-0.0 size=  332930kB time=00:00:15.78 bitrate=172800.0kbits/s speed=6.27x
# frame=  946 fps=376 q=-0.0 size=  332578kB time=00:00:15.76 bitrate=172800.0kbits/s speed=6.26x
# frame=  920 fps=365 q=-0.0 size=  323438kB time=00:00:15.33 bitrate=172800.0kbits/s speed=6.09x
# frame=  899 fps=357 q=-0.0 size=  316055kB time=00:00:14.98 bitrate=172800.0kbits/s speed=5.94x
# frame=  928 fps=368 q=-0.0 size=  326250kB time=00:00:15.46 bitrate=172800.0kbits/s speed=6.14x
# frame=  887 fps=352 q=-0.0 size=  311836kB time=00:00:14.78 bitrate=172800.0kbits/s speed=5.87x
# frame=  852 fps=337 q=-0.0 size=  299531kB time=00:00:14.20 bitrate=172800.0kbits/s speed=5.61x
# frame= 1000 fps=375 q=-0.0 Lsize=  351562kB time=00:00:16.66 bitrate=172800.0kbits/s speed=6.25x
# video:351562kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# ffmpeg version 4.2.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.5.0 (crosstool-NG 1.24.0.123_1667d2b)
#   configuration: --prefix=/home/lq53/miniconda3/envs/minian --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1590573566052/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# frame= 1000 fps=370 q=-0.0 Lsize=  351562kB time=00:00:16.66 bitrate=172800.0kbits/s speed=6.17x
# video:351562kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# Input #0, avi, from '/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241001PMCRE2/customEntValHere/2025_02_12/15_23_02/My_V4_Miniscope/8.avi':
#   Metadata:
#     encoder         : Lavf58.29.100
#   Duration: 00:00:15.35, start: 0.000000, bitrate: 78997 kb/s
#     Stream #0:0: Video: ffv1 (FFV1 / 0x31564646), gray, 600x600, 79069 kb/s, 60 fps, 60 tbr, 60 tbn, 60 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (ffv1 (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: rawvideo (Y800 / 0x30303859), gray, 600x600, q=2-31, 172800 kb/s, 60 fps, 60 tbn, 60 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 rawvideo
# frame= 1000 fps=367 q=-0.0 Lsize=  351562kB time=00:00:16.66 bitrate=172800.0kbits/s speed=6.11x
# video:351562kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# frame= 1000 fps=363 q=-0.0 Lsize=  351562kB time=00:00:16.66 bitrate=172800.0kbits/s speed=6.06x
# video:351562kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# frame= 1000 fps=358 q=-0.0 Lsize=  351562kB time=00:00:16.66 bitrate=172800.0kbits/s speed=5.97x
# video:351562kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# frame= 1000 fps=352 q=-0.0 Lsize=  351562kB time=00:00:16.66 bitrate=172800.0kbits/s speed=5.87x
# video:351562kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# frame= 1000 fps=352 q=-0.0 Lsize=  351562kB time=00:00:16.66 bitrate=172800.0kbits/s speed=5.87x
# video:351562kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# frame= 1000 fps=339 q=-0.0 Lsize=  351562kB time=00:00:16.66 bitrate=172800.0kbits/s speed=5.65x
# video:351562kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# frame=  152 fps=0.0 q=-0.0 size=   53438kB time=00:00:02.53 bitrate=172800.0kbits/s speed=4.98x
# frame=  247 fps=245 q=-0.0 size=   86836kB time=00:00:04.11 bitrate=172800.0kbits/s speed=4.08x
# frame=  349 fps=229 q=-0.0 size=  122695kB time=00:00:05.81 bitrate=172800.0kbits/s speed=3.82x
# frame=  454 fps=224 q=-0.0 size=  159609kB time=00:00:07.56 bitrate=172800.0kbits/s speed=3.73x
# frame=  551 fps=217 q=-0.0 size=  193711kB time=00:00:09.18 bitrate=172800.0kbits/s speed=3.62x
# frame=  646 fps=213 q=-0.0 size=  227109kB time=00:00:10.76 bitrate=172800.0kbits/s speed=3.54x
# frame=  742 fps=209 q=-0.0 size=  260859kB time=00:00:12.36 bitrate=172800.0kbits/s speed=3.49x
# frame=  841 fps=208 q=-0.0 size=  295664kB time=00:00:14.01 bitrate=172800.0kbits/s speed=3.46x
# frame=  921 fps=208 q=-0.0 Lsize=  323789kB time=00:00:15.35 bitrate=172800.0kbits/s speed=3.46x
# video:323789kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# ffmpeg version 4.2.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.5.0 (crosstool-NG 1.24.0.123_1667d2b)
#   configuration: --prefix=/home/lq53/miniconda3/envs/minian --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1590573566052/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, rawvideo, from 'pipe:':
#   Duration: N/A, start: 0.000000, bitrate: 144000 kb/s
#     Stream #0:0: Video: rawvideo (Y800 / 0x30303859), gray, 1200x600, 144000 kb/s, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 (rawvideo) -> pad
#   pad -> Stream #0:0 (libx264)
# [libx264 @ 0x55a7ed9a9e40] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x55a7ed9a9e40] profile Constrained Baseline, level 3.1
# [libx264 @ 0x55a7ed9a9e40] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=0 ref=1 deblock=0:0:0 analyse=0:0 me=dia subme=0 psy=1 psy_rd=1.00:0.00 mixed_ref=0 me_range=16 chroma_me=1 trellis=0 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=0 threads=19 lookahead_threads=3 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=0 weightp=0 keyint=250 keyint_min=25 scenecut=0 intra_refresh=0 rc=crf mbtree=0 crf=18.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=0
# Output #0, mp4, to '/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241001PMCRE2/customEntValHere/2025_02_12/15_23_02/My_V4_Miniscope/minian_mc.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1200x600, q=-1--1, 30 fps, 15360 tbn, 30 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  122 fps=0.0 q=22.0 size=    8704kB time=00:00:03.36 bitrate=21178.9kbits/s dup=20 drop=0 speed=4.53x
# frame=  242 fps=163 q=22.0 size=   19200kB time=00:00:07.36 bitrate=21351.0kbits/s dup=40 drop=0 speed=4.95x
# frame=  362 fps=166 q=22.0 size=   29696kB time=00:00:11.36 bitrate=21401.9kbits/s dup=60 drop=0 speed=5.21x
# frame=  482 fps=166 q=22.0 size=   39936kB time=00:00:15.36 bitrate=21289.9kbits/s dup=80 drop=0 speed=5.29x
# frame=  597 fps=175 q=22.0 size=   49920kB time=00:00:19.20 bitrate=21299.1kbits/s dup=99 drop=0 speed=5.63x
# frame=  662 fps=161 q=22.0 size=   55552kB time=00:00:21.36 bitrate=21298.6kbits/s dup=110 drop=0 speed= 5.2x
# frame=  782 fps=161 q=22.0 size=   66048kB time=00:00:25.36 bitrate=21329.7kbits/s dup=130 drop=0 speed=5.22x
# frame=  902 fps=160 q=22.0 size=   76544kB time=00:00:29.36 bitrate=21352.4kbits/s dup=150 drop=0 speed=5.21x
# frame= 1022 fps=160 q=22.0 size=   87296kB time=00:00:33.36 bitrate=21432.4kbits/s dup=170 drop=0 speed=5.21x
# frame= 1142 fps=159 q=22.0 size=   97792kB time=00:00:37.36 bitrate=21439.2kbits/s dup=190 drop=0 speed=5.21x
# frame= 1262 fps=159 q=22.0 size=  108288kB time=00:00:41.36 bitrate=21444.7kbits/s dup=210 drop=0 speed=5.21x
# frame= 1382 fps=160 q=22.0 size=  119040kB time=00:00:45.36 bitrate=21495.4kbits/s dup=230 drop=0 speed=5.24x
# frame= 1502 fps=160 q=22.0 size=  129536kB time=00:00:49.36 bitrate=21495.4kbits/s dup=250 drop=0 speed=5.25x
# frame= 1622 fps=160 q=22.0 size=  140032kB time=00:00:53.36 bitrate=21495.5kbits/s dup=270 drop=0 speed=5.25x
# frame= 1742 fps=160 q=22.0 size=  150528kB time=00:00:57.36 bitrate=21495.5kbits/s dup=290 drop=0 speed=5.25x
# frame= 1862 fps=159 q=22.0 size=  161024kB time=00:01:01.36 bitrate=21495.5kbits/s dup=310 drop=0 speed=5.26x
# frame= 1982 fps=160 q=22.0 size=  171520kB time=00:01:05.36 bitrate=21495.5kbits/s dup=330 drop=0 speed=5.29x
# frame= 2102 fps=161 q=22.0 size=  182016kB time=00:01:09.36 bitrate=21495.5kbits/s dup=350 drop=0 speed=5.33x
# frame= 2222 fps=162 q=22.0 size=  192768kB time=00:01:13.36 bitrate=21524.1kbits/s dup=370 drop=0 speed=5.36x
# frame= 2342 fps=163 q=22.0 size=  203264kB time=00:01:17.36 bitrate=21522.7kbits/s dup=390 drop=0 speed=5.38x
# frame= 2462 fps=163 q=22.0 size=  213760kB time=00:01:21.36 bitrate=21521.4kbits/s dup=410 drop=0 speed=5.39x
# frame= 2582 fps=164 q=22.0 size=  224256kB time=00:01:25.36 bitrate=21520.2kbits/s dup=430 drop=0 speed=5.41x
# frame= 2702 fps=164 q=22.0 size=  234752kB time=00:01:29.36 bitrate=21519.1kbits/s dup=450 drop=0 speed=5.42x
# frame= 2822 fps=164 q=22.0 size=  245248kB time=00:01:33.36 bitrate=21518.1kbits/s dup=470 drop=0 speed=5.44x
# frame= 2942 fps=165 q=22.0 size=  255744kB time=00:01:37.36 bitrate=21517.2kbits/s dup=490 drop=0 speed=5.47x
# frame= 3062 fps=166 q=22.0 size=  266240kB time=00:01:41.36 bitrate=21516.3kbits/s dup=510 drop=0 speed= 5.5x
# frame= 3182 fps=166 q=22.0 size=  276736kB time=00:01:45.36 bitrate=21515.5kbits/s dup=530 drop=0 speed=5.51x
# frame= 3302 fps=167 q=22.0 size=  287488kB time=00:01:49.36 bitrate=21534.0kbits/s dup=550 drop=0 speed=5.53x
# frame= 3405 fps=168 q=22.0 size=  296448kB time=00:01:52.80 bitrate=21529.3kbits/s dup=567 drop=0 speed=5.56x
# frame= 3482 fps=167 q=22.0 size=  303360kB time=00:01:55.36 bitrate=21541.1kbits/s dup=580 drop=0 speed=5.52x
# frame= 3602 fps=167 q=22.0 size=  313856kB time=00:01:59.36 bitrate=21539.6kbits/s dup=600 drop=0 speed=5.55x
# frame= 3722 fps=168 q=22.0 size=  324608kB time=00:02:03.36 bitrate=21555.2kbits/s dup=620 drop=0 speed=5.56x
# frame= 3842 fps=168 q=22.0 size=  335360kB time=00:02:07.36 bitrate=21569.8kbits/s dup=640 drop=0 speed=5.57x
# frame= 3962 fps=168 q=22.0 size=  345856kB time=00:02:11.36 bitrate=21567.5kbits/s dup=660 drop=0 speed=5.58x
# frame= 4082 fps=168 q=22.0 size=  356608kB time=00:02:15.36 bitrate=21580.9kbits/s dup=680 drop=0 speed=5.59x
# frame= 4202 fps=169 q=22.0 size=  367104kB time=00:02:19.36 bitrate=21578.4kbits/s dup=700 drop=0 speed= 5.6x
# frame= 4322 fps=169 q=22.0 size=  377600kB time=00:02:23.36 bitrate=21576.1kbits/s dup=720 drop=0 speed= 5.6x
# frame= 4442 fps=169 q=22.0 size=  388096kB time=00:02:27.36 bitrate=21574.0kbits/s dup=740 drop=0 speed= 5.6x
# frame= 4562 fps=169 q=22.0 size=  398848kB time=00:02:31.36 bitrate=21585.7kbits/s dup=760 drop=0 speed= 5.6x
# frame= 4682 fps=169 q=22.0 size=  409344kB time=00:02:35.36 bitrate=21583.4kbits/s dup=780 drop=0 speed= 5.6x
# frame= 4802 fps=169 q=22.0 size=  419840kB time=00:02:39.36 bitrate=21581.2kbits/s dup=800 drop=0 speed=5.61x
# frame= 4922 fps=169 q=22.0 size=  430336kB time=00:02:43.36 bitrate=21579.1kbits/s dup=820 drop=0 speed=5.62x
# frame= 5042 fps=170 q=22.0 size=  441088kB time=00:02:47.36 bitrate=21589.7kbits/s dup=840 drop=0 speed=5.63x
# frame= 5162 fps=170 q=22.0 size=  451584kB time=00:02:51.36 bitrate=21587.5kbits/s dup=860 drop=0 speed=5.63x
# frame= 5282 fps=170 q=22.0 size=  462336kB time=00:02:55.36 bitrate=21597.4kbits/s dup=880 drop=0 speed=5.65x
# frame= 5402 fps=170 q=22.0 size=  472832kB time=00:02:59.36 bitrate=21595.1kbits/s dup=900 drop=0 speed=5.65x
# frame= 5522 fps=170 q=22.0 size=  483328kB time=00:03:03.36 bitrate=21592.9kbits/s dup=920 drop=0 speed=5.65x
# frame= 5642 fps=170 q=22.0 size=  493824kB time=00:03:07.36 bitrate=21590.8kbits/s dup=940 drop=0 speed=5.66x
# frame= 5762 fps=171 q=22.0 size=  504576kB time=00:03:11.36 bitrate=21599.8kbits/s dup=960 drop=0 speed=5.67x
# frame= 5882 fps=171 q=22.0 size=  515328kB time=00:03:15.36 bitrate=21608.4kbits/s dup=980 drop=0 speed=5.67x
# frame= 6002 fps=171 q=22.0 size=  525824kB time=00:03:19.36 bitrate=21606.2kbits/s dup=1000 drop=0 speed=5.68x
# More than 1000 frames duplicated
# frame= 6122 fps=171 q=22.0 size=  536320kB time=00:03:23.36 bitrate=21604.0kbits/s dup=1020 drop=0 speed=5.69x
# frame= 6242 fps=171 q=22.0 size=  546816kB time=00:03:27.36 bitrate=21601.9kbits/s dup=1040 drop=0 speed=5.69x
# frame= 6362 fps=171 q=22.0 size=  557312kB time=00:03:31.36 bitrate=21599.9kbits/s dup=1060 drop=0 speed=5.69x
# frame= 6482 fps=171 q=22.0 size=  567808kB time=00:03:35.36 bitrate=21598.0kbits/s dup=1080 drop=0 speed=5.68x
# frame= 6602 fps=171 q=22.0 size=  578304kB time=00:03:39.36 bitrate=21596.1kbits/s dup=1100 drop=0 speed=5.68x
# frame= 6722 fps=171 q=22.0 size=  588800kB time=00:03:43.36 bitrate=21594.3kbits/s dup=1120 drop=0 speed=5.68x
# frame= 6842 fps=171 q=22.0 size=  599040kB time=00:03:47.36 bitrate=21583.4kbits/s dup=1140 drop=0 speed=5.68x
# frame= 6962 fps=171 q=22.0 size=  609536kB time=00:03:51.36 bitrate=21581.8kbits/s dup=1160 drop=0 speed=5.68x
# frame= 7082 fps=171 q=22.0 size=  620032kB time=00:03:55.36 bitrate=21580.4kbits/s dup=1180 drop=0 speed=5.67x
# frame= 7202 fps=170 q=22.0 size=  630528kB time=00:03:59.36 bitrate=21579.0kbits/s dup=1200 drop=0 speed=5.66x
# frame= 7322 fps=170 q=22.0 size=  641280kB time=00:04:03.36 bitrate=21586.2kbits/s dup=1220 drop=0 speed=5.65x
# frame= 7442 fps=170 q=22.0 size=  651520kB time=00:04:07.36 bitrate=21576.3kbits/s dup=1240 drop=0 speed=5.65x
# frame= 7562 fps=170 q=22.0 size=  662016kB time=00:04:11.36 bitrate=21575.0kbits/s dup=1260 drop=0 speed=5.64x
# frame= 7682 fps=170 q=22.0 size=  672512kB time=00:04:15.36 bitrate=21573.8kbits/s dup=1280 drop=0 speed=5.64x
# frame= 7802 fps=169 q=22.0 size=  683008kB time=00:04:19.36 bitrate=21572.6kbits/s dup=1300 drop=0 speed=5.63x
# frame= 7922 fps=169 q=22.0 size=  693504kB time=00:04:23.36 bitrate=21571.4kbits/s dup=1320 drop=0 speed=5.63x
# frame= 8042 fps=169 q=22.0 size=  704000kB time=00:04:27.36 bitrate=21570.3kbits/s dup=1340 drop=0 speed=5.63x
# frame= 8162 fps=169 q=22.0 size=  714496kB time=00:04:31.36 bitrate=21569.2kbits/s dup=1360 drop=0 speed=5.63x
# frame= 8282 fps=169 q=22.0 size=  725248kB time=00:04:35.36 bitrate=21575.7kbits/s dup=1380 drop=0 speed=5.63x
# frame= 8402 fps=170 q=22.0 size=  735744kB time=00:04:39.36 bitrate=21574.6kbits/s dup=1400 drop=0 speed=5.64x
# frame= 8522 fps=170 q=22.0 size=  746240kB time=00:04:43.36 bitrate=21573.5kbits/s dup=1420 drop=0 speed=5.64x
# frame= 8642 fps=170 q=22.0 size=  756736kB time=00:04:47.36 bitrate=21572.4kbits/s dup=1440 drop=0 speed=5.64x
# frame= 8762 fps=169 q=22.0 size=  767232kB time=00:04:51.36 bitrate=21571.3kbits/s dup=1460 drop=0 speed=5.63x
# frame= 8882 fps=169 q=22.0 size=  777728kB time=00:04:55.36 bitrate=21570.3kbits/s dup=1480 drop=0 speed=5.64x
# frame= 9002 fps=169 q=22.0 size=  788224kB time=00:04:59.36 bitrate=21569.3kbits/s dup=1500 drop=0 speed=5.63x
# frame= 9122 fps=169 q=22.0 size=  798464kB time=00:05:03.36 bitrate=21561.4kbits/s dup=1520 drop=0 speed=5.63x
# frame= 9242 fps=169 q=22.0 size=  808960kB time=00:05:07.36 bitrate=21560.6kbits/s dup=1540 drop=0 speed=5.63x
# frame= 9362 fps=169 q=22.0 size=  819456kB time=00:05:11.36 bitrate=21559.7kbits/s dup=1560 drop=0 speed=5.63x
# frame= 9482 fps=169 q=22.0 size=  829696kB time=00:05:15.36 bitrate=21552.3kbits/s dup=1580 drop=0 speed=5.63x
# frame= 9602 fps=169 q=22.0 size=  840192kB time=00:05:19.36 bitrate=21551.6kbits/s dup=1600 drop=0 speed=5.62x
# frame= 9722 fps=169 q=22.0 size=  850688kB time=00:05:23.36 bitrate=21550.9kbits/s dup=1620 drop=0 speed=5.62x
# frame= 9842 fps=169 q=22.0 size=  861184kB time=00:05:27.36 bitrate=21550.2kbits/s dup=1640 drop=0 speed=5.61x
# frame= 9962 fps=169 q=22.0 size=  871680kB time=00:05:31.36 bitrate=21549.5kbits/s dup=1660 drop=0 speed=5.62x
# frame=10082 fps=169 q=22.0 size=  881920kB time=00:05:35.36 bitrate=21542.7kbits/s dup=1680 drop=0 speed=5.62x
# frame=10202 fps=169 q=22.0 size=  892416kB time=00:05:39.36 bitrate=21542.1kbits/s dup=1700 drop=0 speed=5.62x
# frame=10322 fps=169 q=22.0 size=  902656kB time=00:05:43.36 bitrate=21535.5kbits/s dup=1720 drop=0 speed=5.63x
# frame=10442 fps=169 q=22.0 size=  913152kB time=00:05:47.36 bitrate=21535.0kbits/s dup=1740 drop=0 speed=5.63x
# frame=10562 fps=169 q=22.0 size=  923648kB time=00:05:51.36 bitrate=21534.6kbits/s dup=1760 drop=0 speed=5.63x
# frame=10682 fps=169 q=22.0 size=  934144kB time=00:05:55.36 bitrate=21534.1kbits/s dup=1780 drop=0 speed=5.63x
# frame=10705 fps=170 q=-1.0 Lsize=  937967kB time=00:05:56.80 bitrate=21535.4kbits/s dup=1784 drop=0 speed=5.65x
# video:937919kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.005110%
# [libx264 @ 0x55a7ed9a9e40] frame I:43    Avg QP:18.91  size:152656
# [libx264 @ 0x55a7ed9a9e40] frame P:10662 Avg QP:22.19  size: 89464
# [libx264 @ 0x55a7ed9a9e40] mb I  I16..4: 100.0%  0.0%  0.0%
# [libx264 @ 0x55a7ed9a9e40] mb P  I16..4: 51.8%  0.0%  0.0%  P16..4: 46.2%  0.0%  0.0%  0.0%  0.0%    skip: 2.0%
# [libx264 @ 0x55a7ed9a9e40] coded y,uvDC,uvAC intra: 99.2% 0.0% 0.0% inter: 85.4% 0.0% 0.0%
# [libx264 @ 0x55a7ed9a9e40] i16 v,h,dc,p: 14% 17% 57% 13%
# [libx264 @ 0x55a7ed9a9e40] i8c dc,h,v,p: 100%  0%  0%  0%
# [libx264 @ 0x55a7ed9a9e40] kb/s:21532.27
# Traceback (most recent call last):
#   File "minian_mirpy_set.py", line 144, in <module>
#     A, C = unit_merge(A_init, C_init, **param_init_merge)
#   File "/home/lq53/mir_repos/minian/minian/minian/cnmf.py", line 1456, in unit_merge
#     adj = adj_corr(C, A_inter, nod_df, freq=noise_freq)
#   File "/home/lq53/mir_repos/minian/minian/minian/cnmf.py", line 1844, in adj_corr
#     corr_df = graph_optimize_corr(varr, G, freq, idx_dims=nod_df.columns)
#   File "/home/lq53/mir_repos/minian/minian/minian/cnmf.py", line 1805, in graph_optimize_corr
#     corr = pd.Series(np.concatenate(corr_ls), index=np.concatenate(idx_ls), name="corr")
#   File "<__array_function__ internals>", line 5, in concatenate
# ValueError: need at least one array to concatenate
#
# Warning: Output file not found for combination wnd1500_stp700_max15_diff3.0_pnr1.1.
#
#
#
# === Running param_search_driver for session ===
# Animal:       20241002-PMC-R1
# Session dir:  /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241002-PMC-R1/customEntValHere/2024_10_24/13_23_51/My_V4_Miniscope
# [STDOUT] Running combination: wnd1500_stp700_max15_diff3.0_pnr1.1
# loading 8 videos in folder /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241002-PMC-R1/customEntValHere/2024_10_24/13_23_51/My_V4_Miniscope
#
# Errors: Traceback (most recent call last):
#   File "minian_mirpy_set.py", line 86, in <module>
#     varr = load_videos(dpath, **param_load_videos)
#   File "/home/lq53/mir_repos/minian/minian/minian/utilities.py", line 118, in load_videos
#     varr_list = [movie_load_func(v) for v in vlist]
#   File "/home/lq53/mir_repos/minian/minian/minian/utilities.py", line 118, in <listcomp>
#     varr_list = [movie_load_func(v) for v in vlist]
#   File "/home/lq53/mir_repos/minian/minian/minian/utilities.py", line 228, in load_avi_lazy
#     f = int(video_info["nb_frames"])
# KeyError: 'nb_frames'
#
# Warning: Output file not found for combination wnd1500_stp700_max15_diff3.0_pnr1.1.
#
#
#
# === Running param_search_driver for session ===
# Animal:       20241212v1l1r1
# Session dir:  /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241212v1l1r1/customEntValHere/2024_12_31/11_41_01/My_V4_Miniscope
# [STDOUT] Running combination: wnd1500_stp700_max25_diff3.0_pnr1.1
# loading 5 videos in folder /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241212v1l1r1/customEntValHere/2024_12_31/11_41_01/My_V4_Miniscope
# constructing chunks
# computing max projections
# calculating local maximum
# selecting seeds
# computing peak-noise ratio
# selecting seeds
# performing KS test
# computing distance
# computing correlations
# pixel recompute ratio: 0.926829268292683
# computing correlations
# merging seeds
# optimizing computation graph
# pixel recompute ratio: 1.0081243376898623
# computing correlations
# building spatial matrix
# computing spatial overlap
# computing temporal correlation
# pixel recompute ratio: 0.0
# computing correlations
#
# Errors: ffmpeg version 4.2.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.5.0 (crosstool-NG 1.24.0.123_1667d2b)
#   configuration: --prefix=/home/lq53/miniconda3/envs/minian --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1590573566052/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# ffmpeg version 4.2.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.5.0 (crosstool-NG 1.24.0.123_1667d2b)
#   configuration: --prefix=/home/lq53/miniconda3/envs/minian --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1590573566052/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# ffmpeg version 4.2.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.5.0 (crosstool-NG 1.24.0.123_1667d2b)
#   configuration: --prefix=/home/lq53/miniconda3/envs/minian --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1590573566052/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame
# ffmpeg version 4.2.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.5.0 (crosstool-NG 1.24.0.123_1667d2b)
#   configuration: --prefix=/home/lq53/miniconda3/envs/minian --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1590573566052/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, avi, from '/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241212v1l1r1/customEntValHere/2024_12_31/11_41_01/My_V4_Miniscope/2.avi':
#   Metadata:
#     encoder         : Lavf58.29.100
#   Duration: 00:00:16.67, start: 0.000000, bitrate: 76234 kb/s
#     Stream #0:0: Video: ffv1 (FFV1 / 0x31564646), gray, 600x600, 76295 kb/s, 60 fps, 60 tbr, 60 tbn, 60 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (ffv1 (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Input #0, avi, from '/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241212v1l1r1/customEntValHere/2024_12_31/11_41_01/My_V4_Miniscope/0.avi':
#   Metadata:
#     encoder         : Lavf58.29.100
#   Duration: 00:00:16.67, start: 0.000000, bitrate: 76335 kb/s
#     Stream #0:0: Video: ffv1 (FFV1 / 0x31564646), gray, 600x600, 76397 kb/s, 60 fps, 60 tbr, 60 tbn, 60 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (ffv1 (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# ffmpeg version 4.2.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.5.0 (crosstool-NG 1.24.0.123_1667d2b)
#   configuration: --prefix=/home/lq53/miniconda3/envs/minian --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1590573566052/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, avi, from '/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241212v1l1r1/customEntValHere/2024_12_31/11_41_01/My_V4_Miniscope/1.avi':
#   Metadata:
#     encoder         : Lavf58.29.100
#   Duration: 00:00:16.67, start: 0.000000, bitrate: 76286 kb/s
#     Stream #0:0: Video: ffv1 (FFV1 / 0x31564646), gray, 600x600, 76348 kb/s, 60 fps, 60 tbr, 60 tbn, 60 tbc
# Input #0, avi, from '/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241212v1l1r1/customEntValHere/2024_12_31/11_41_01/My_V4_Miniscope/3.avi':
#   Metadata:
#     encoder         : Lavf58.29.100
#   Duration: 00:00:16.67, start: 0.000000, bitrate: 76239 kb/s
#     Stream #0:0: Video: ffv1 (FFV1 / 0x31564646), gray, 600x600, 76301 kb/s, 60 fps, 60 tbr, 60 tbn, 60 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (ffv1 (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Stream mapping:
#   Stream #0:0 -> #0:0 (ffv1 (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: rawvideo (Y800 / 0x30303859), gray, 600x600, q=2-31, 172800 kb/s, 60 fps, 60 tbn, 60 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 rawvideo
# Input #0, avi, from '/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241212v1l1r1/customEntValHere/2024_12_31/11_41_01/My_V4_Miniscope/4.avi':
#   Metadata:
#     encoder         : Lavf58.29.100
#   Duration: 00:00:03.48, start: 0.000000, bitrate: 76072 kb/s
#     Stream #0:0: Video: ffv1 (FFV1 / 0x31564646), gray, 600x600, 76413 kb/s, 60 fps, 60 tbr, 60 tbn, 60 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (ffv1 (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: rawvideo (Y800 / 0x30303859), gray, 600x600, q=2-31, 172800 kb/s, 60 fps, 60 tbn, 60 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 rawvideo
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: rawvideo (Y800 / 0x30303859), gray, 600x600, q=2-31, 172800 kb/s, 60 fps, 60 tbn, 60 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 rawvideo
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: rawvideo (Y800 / 0x30303859), gray, 600x600, q=2-31, 172800 kb/s, 60 fps, 60 tbn, 60 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 rawvideo
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: rawvideo (Y800 / 0x30303859), gray, 600x600, q=2-31, 172800 kb/s, 60 fps, 60 tbn, 60 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 rawvideo
# frame=  133 fps=0.0 q=-0.0 size=   46758kB time=00:00:02.21 bitrate=172800.0kbits/s speed=4.43x
# frame=  144 fps=0.0 q=-0.0 size=   50625kB time=00:00:02.40 bitrate=172800.0kbits/s speed=4.72x
# ...
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: rawvideo (Y800 / 0x30303859), gray, 600x600, q=2-31, 172800 kb/s, 60 fps, 60 tbn, 60 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 rawvideo
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: rawvideo (Y800 / 0x30303859), gray, 600x600, q=2-31, 172800 kb/s, 60 fps, 60 tbn, 60 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 rawvideo
# frame=  143 fps=0.0 q=-0.0 size=   50273kB time=00:00:02.38 bitrate=172800.0kbits/s speed=4.76x
# frame=  163 fps=0.0 q=-0.0 size=   57305kB time=00:00:02.71 bitrate=172800.0kbits/s speed=5.38x
# frame=  148 fps=0.0 q=-0.0 size=   52031kB time=00:00:02.46 bitrate=172800.0kbits/s speed= 4.9x
# frame=  128 fps=0.0 q=-0.0 size=   45000kB time=00:00:02.13 bitrate=172800.0kbits/s speed=4.18x
# frame=  130 fps=0.0 q=-0.0 size=   45703kB time=00:00:02.16 bitrate=172800.0kbits/s speed=4.26x
# frame=  227 fps=226 q=-0.0 size=   79805kB time=00:00:03.78 bitrate=172800.0kbits/s speed=3.77x
# frame=  225 fps=222 q=-0.0 size=   79102kB time=00:00:03.75 bitrate=172800.0kbits/s speed= 3.7x
# frame=  204 fps=201 q=-0.0 size=   71719kB time=00:00:03.40 bitrate=172800.0kbits/s speed=3.35x
# frame=  240 fps=236 q=-0.0 size=   84375kB time=00:00:04.00 bitrate=172800.0kbits/s speed=3.93x
# frame=  214 fps=208 q=-0.0 size=   75234kB time=00:00:03.56 bitrate=172800.0kbits/s speed=3.47x
# frame=  308 fps=205 q=-0.0 size=  108281kB time=00:00:05.13 bitrate=172800.0kbits/s speed=3.41x
# frame=  291 fps=192 q=-0.0 size=  102305kB time=00:00:04.85 bitrate=172800.0kbits/s speed= 3.2x
# frame=  320 fps=211 q=-0.0 size=  112500kB time=00:00:05.33 bitrate=172800.0kbits/s speed=3.51x
# frame=  300 fps=197 q=-0.0 size=  105469kB time=00:00:05.00 bitrate=172800.0kbits/s speed=3.29x
# frame=  300 fps=196 q=-0.0 size=  105469kB time=00:00:05.00 bitrate=172800.0kbits/s speed=3.27x
# frame=  383 fps=190 q=-0.0 size=  134648kB time=00:00:06.38 bitrate=172800.0kbits/s speed=3.17x
# frame=  385 fps=190 q=-0.0 size=  135352kB time=00:00:06.41 bitrate=172800.0kbits/s speed=3.16x
# frame=  382 fps=189 q=-0.0 size=  134297kB time=00:00:06.36 bitrate=172800.0kbits/s speed=3.15x
# frame=  404 fps=199 q=-0.0 size=  142031kB time=00:00:06.73 bitrate=172800.0kbits/s speed=3.32x
# frame=  371 fps=183 q=-0.0 size=  130430kB time=00:00:06.18 bitrate=172800.0kbits/s speed=3.05x
# frame=  457 fps=182 q=-0.0 size=  160664kB time=00:00:07.61 bitrate=172800.0kbits/s speed=3.03x
# frame=  456 fps=180 q=-0.0 size=  160312kB time=00:00:07.60 bitrate=172800.0kbits/s speed=   3x
# frame=  470 fps=186 q=-0.0 size=  165234kB time=00:00:07.83 bitrate=172800.0kbits/s speed=3.09x
# frame=  455 fps=180 q=-0.0 size=  159961kB time=00:00:07.58 bitrate=172800.0kbits/s speed=2.99x
# frame=  480 fps=189 q=-0.0 size=  168750kB time=00:00:08.00 bitrate=172800.0kbits/s speed=3.15x
# frame=  484 fps=187 q=-0.0 Lsize=  170156kB time=00:00:08.06 bitrate=172800.0kbits/s speed=3.11x
# video:170156kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# frame=  548 fps=181 q=-0.0 size=  192656kB time=00:00:09.13 bitrate=172800.0kbits/s speed=3.02x
# frame=  558 fps=184 q=-0.0 size=  196172kB time=00:00:09.30 bitrate=172800.0kbits/s speed=3.06x
# frame=  559 fps=184 q=-0.0 size=  196523kB time=00:00:09.31 bitrate=172800.0kbits/s speed=3.07x
# frame=  523 fps=172 q=-0.0 size=  183867kB time=00:00:08.71 bitrate=172800.0kbits/s speed=2.87x
# frame=  643 fps=182 q=-0.0 size=  226055kB time=00:00:10.71 bitrate=172800.0kbits/s speed=3.03x
# frame=  638 fps=180 q=-0.0 size=  224297kB time=00:00:10.63 bitrate=172800.0kbits/s speed=   3x
# frame=  633 fps=179 q=-0.0 size=  222539kB time=00:00:10.55 bitrate=172800.0kbits/s speed=2.98x
# frame=  598 fps=169 q=-0.0 size=  210234kB time=00:00:09.96 bitrate=172800.0kbits/s speed=2.81x
# frame=  709 fps=175 q=-0.0 size=  249258kB time=00:00:11.81 bitrate=172800.0kbits/s speed=2.92x
# frame=  717 fps=177 q=-0.0 size=  252070kB time=00:00:11.95 bitrate=172800.0kbits/s speed=2.96x
# frame=  730 fps=180 q=-0.0 size=  256641kB time=00:00:12.16 bitrate=172800.0kbits/s speed=3.01x
# frame=  672 fps=166 q=-0.0 size=  236250kB time=00:00:11.20 bitrate=172800.0kbits/s speed=2.76x
# frame=  820 fps=180 q=-0.0 size=  288281kB time=00:00:13.66 bitrate=172800.0kbits/s speed=3.01x
# frame=  793 fps=174 q=-0.0 size=  278789kB time=00:00:13.21 bitrate=172800.0kbits/s speed= 2.9x
# frame=  798 fps=175 q=-0.0 size=  280547kB time=00:00:13.30 bitrate=172800.0kbits/s speed=2.91x
# frame=  756 fps=166 q=-0.0 size=  265781kB time=00:00:12.60 bitrate=172800.0kbits/s speed=2.76x
# frame=  899 fps=178 q=-0.0 size=  316055kB time=00:00:14.98 bitrate=172800.0kbits/s speed=2.97x
# frame=  883 fps=175 q=-0.0 size=  310430kB time=00:00:14.71 bitrate=172800.0kbits/s speed=2.91x
# frame=  874 fps=172 q=-0.0 size=  307266kB time=00:00:14.56 bitrate=172800.0kbits/s speed=2.87x
# frame=  836 fps=165 q=-0.0 size=  293906kB time=00:00:13.93 bitrate=172800.0kbits/s speed=2.74x
# frame=  985 fps=177 q=-0.0 size=  346289kB time=00:00:16.41 bitrate=172800.0kbits/s speed=2.95x
# frame=  955 fps=171 q=-0.0 size=  335742kB time=00:00:15.91 bitrate=172800.0kbits/s speed=2.86x
# frame=  958 fps=172 q=-0.0 size=  336797kB time=00:00:15.96 bitrate=172800.0kbits/s speed=2.87x
# frame=  910 fps=163 q=-0.0 size=  319922kB time=00:00:15.16 bitrate=172800.0kbits/s speed=2.71x
# frame= 1000 fps=177 q=-0.0 Lsize=  351562kB time=00:00:16.66 bitrate=172800.0kbits/s speed=2.95x
# video:351562kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# frame= 1000 fps=173 q=-0.0 Lsize=  351562kB time=00:00:16.66 bitrate=172800.0kbits/s speed=2.89x
# video:351562kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# frame= 1000 fps=172 q=-0.0 Lsize=  351562kB time=00:00:16.66 bitrate=172800.0kbits/s speed=2.86x
# video:351562kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# frame= 1000 fps=164 q=-0.0 Lsize=  351562kB time=00:00:16.66 bitrate=172800.0kbits/s speed=2.74x
# video:351562kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# ffmpeg version 4.2.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.5.0 (crosstool-NG 1.24.0.123_1667d2b)
#   configuration: --prefix=/home/lq53/miniconda3/envs/minian --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1590573566052/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, rawvideo, from 'pipe:':
#   Duration: N/A, start: 0.000000, bitrate: 144000 kb/s
#     Stream #0:0: Video: rawvideo (Y800 / 0x30303859), gray, 1200x600, 144000 kb/s, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 (rawvideo) -> pad
#   pad -> Stream #0:0 (libx264)
# [libx264 @ 0x5595ff417e40] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x5595ff417e40] profile Constrained Baseline, level 3.1
# [libx264 @ 0x5595ff417e40] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=0 ref=1 deblock=0:0:0 analyse=0:0 me=dia subme=0 psy=1 psy_rd=1.00:0.00 mixed_ref=0 me_range=16 chroma_me=1 trellis=0 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=0 threads=19 lookahead_threads=3 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=0 weightp=0 keyint=250 keyint_min=25 scenecut=0 intra_refresh=0 rc=crf mbtree=0 crf=18.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=0
# Output #0, mp4, to '/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241224PMCLE1/customEntValHere/2025_02_13/11_58_39/My_V4_Miniscope/minian_mc.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1200x600, q=-1--1, 30 fps, 15360 tbn, 30 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  120 fps=0.0 q=26.0 size=   15616kB time=00:00:03.30 bitrate=38764.9kbits/s dup=20 drop=0 speed=6.58x
# frame=  182 fps=154 q=25.0 size=   25344kB time=00:00:05.36 bitrate=38686.2kbits/s dup=30 drop=0 speed=4.55x
# frame=  302 fps=158 q=25.0 size=   43776kB time=00:00:09.36 bitrate=38285.9kbits/s dup=50 drop=0 speed=4.91x
# frame=  422 fps=161 q=25.0 size=   62464kB time=00:00:13.36 bitrate=38282.0kbits/s dup=70 drop=0 speed=5.09x
# frame=  542 fps=162 q=25.0 size=   80384kB time=00:00:17.36 bitrate=37917.7kbits/s dup=90 drop=0 speed= 5.2x
# frame=  662 fps=162 q=25.0 size=   99328kB time=00:00:21.36 bitrate=38082.3kbits/s dup=110 drop=0 speed=5.22x
# frame=  782 fps=161 q=25.0 size=  118016kB time=00:00:25.36 bitrate=38112.4kbits/s dup=130 drop=0 speed=5.23x
# frame=  902 fps=161 q=25.0 size=  136192kB time=00:00:29.36 bitrate=37991.5kbits/s dup=150 drop=0 speed=5.23x
# frame= 1022 fps=160 q=25.0 size=  154624kB time=00:00:33.36 bitrate=37962.4kbits/s dup=170 drop=0 speed=5.21x
# frame= 1142 fps=160 q=25.0 size=  172800kB time=00:00:37.36 bitrate=37883.4kbits/s dup=190 drop=0 speed=5.24x
# frame= 1262 fps=160 q=25.0 size=  191744kB time=00:00:41.36 bitrate=37971.8kbits/s dup=210 drop=0 speed=5.25x
# frame= 1382 fps=160 q=25.0 size=  210688kB time=00:00:45.36 bitrate=38044.5kbits/s dup=230 drop=0 speed=5.25x
# frame= 1502 fps=159 q=25.0 size=  229632kB time=00:00:49.36 bitrate=38105.5kbits/s dup=250 drop=0 speed=5.24x
# frame= 1622 fps=160 q=25.0 size=  248576kB time=00:00:53.36 bitrate=38157.4kbits/s dup=270 drop=0 speed=5.25x
# frame= 1742 fps=160 q=25.0 size=  267520kB time=00:00:57.36 bitrate=38202.0kbits/s dup=290 drop=0 speed=5.26x
# frame= 1862 fps=159 q=25.0 size=  286720kB time=00:01:01.36 bitrate=38275.0kbits/s dup=310 drop=0 speed=5.25x
# frame= 1982 fps=159 q=25.0 size=  305920kB time=00:01:05.36 bitrate=38339.0kbits/s dup=330 drop=0 speed=5.26x
# frame= 2102 fps=160 q=25.0 size=  324864kB time=00:01:09.36 bitrate=38365.5kbits/s dup=350 drop=0 speed=5.28x
# frame= 2222 fps=160 q=25.0 size=  343808kB time=00:01:13.36 bitrate=38389.0kbits/s dup=370 drop=0 speed=5.28x
# frame= 2342 fps=160 q=25.0 size=  362752kB time=00:01:17.36 bitrate=38410.1kbits/s dup=390 drop=0 speed=5.28x
# frame= 2462 fps=159 q=25.0 size=  381952kB time=00:01:21.36 bitrate=38454.9kbits/s dup=410 drop=0 speed=5.24x
# frame= 2582 fps=159 q=25.0 size=  401152kB time=00:01:25.36 bitrate=38495.5kbits/s dup=430 drop=0 speed=5.26x
# frame= 2702 fps=159 q=25.0 size=  420096kB time=00:01:29.36 bitrate=38509.0kbits/s dup=450 drop=0 speed=5.26x
# frame= 2822 fps=159 q=25.0 size=  439040kB time=00:01:33.36 bitrate=38521.4kbits/s dup=470 drop=0 speed=5.27x
# frame= 2942 fps=159 q=25.0 size=  457984kB time=00:01:37.36 bitrate=38532.7kbits/s dup=490 drop=0 speed=5.27x
# frame= 3062 fps=159 q=25.0 size=  476672kB time=00:01:41.36 bitrate=38522.5kbits/s dup=510 drop=0 speed=5.28x
# frame= 3182 fps=160 q=25.0 size=  495616kB time=00:01:45.36 bitrate=38532.9kbits/s dup=530 drop=0 speed=5.28x
# frame= 3302 fps=160 q=25.0 size=  514304kB time=00:01:49.36 bitrate=38523.4kbits/s dup=550 drop=0 speed= 5.3x
# frame= 3422 fps=161 q=25.0 size=  532992kB time=00:01:53.36 bitrate=38514.6kbits/s dup=570 drop=0 speed=5.32x
# frame= 3542 fps=161 q=25.0 size=  551680kB time=00:01:57.36 bitrate=38506.3kbits/s dup=590 drop=0 speed=5.32x
# frame= 3662 fps=161 q=25.0 size=  570624kB time=00:02:01.36 bitrate=38515.9kbits/s dup=610 drop=0 speed=5.33x
# frame= 3782 fps=161 q=25.0 size=  589824kB time=00:02:05.36 bitrate=38541.6kbits/s dup=630 drop=0 speed=5.33x
# frame= 3902 fps=160 q=25.0 size=  609024kB time=00:02:09.36 bitrate=38565.7kbits/s dup=650 drop=0 speed=5.32x
# frame= 4022 fps=161 q=25.0 size=  628224kB time=00:02:13.36 bitrate=38588.4kbits/s dup=670 drop=0 speed=5.32x
# frame= 4142 fps=161 q=25.0 size=  647168kB time=00:02:17.36 bitrate=38594.5kbits/s dup=690 drop=0 speed=5.33x
# frame= 4262 fps=161 q=25.0 size=  666112kB time=00:02:21.36 bitrate=38600.2kbits/s dup=710 drop=0 speed=5.33x
# frame= 4382 fps=161 q=25.0 size=  685056kB time=00:02:25.36 bitrate=38605.7kbits/s dup=730 drop=0 speed=5.33x
# frame= 4502 fps=161 q=25.0 size=  704000kB time=00:02:29.36 bitrate=38610.8kbits/s dup=750 drop=0 speed=5.34x
# frame= 4622 fps=161 q=25.0 size=  722944kB time=00:02:33.36 bitrate=38615.7kbits/s dup=770 drop=0 speed=5.35x
# frame= 4742 fps=161 q=25.0 size=  741632kB time=00:02:37.36 bitrate=38607.0kbits/s dup=790 drop=0 speed=5.36x
# frame= 4862 fps=161 q=25.0 size=  760576kB time=00:02:41.36 bitrate=38611.7kbits/s dup=810 drop=0 speed=5.35x
# frame= 4982 fps=161 q=25.0 size=  779264kB time=00:02:45.36 bitrate=38603.5kbits/s dup=830 drop=0 speed=5.35x
# frame= 5102 fps=161 q=25.0 size=  798208kB time=00:02:49.36 bitrate=38608.1kbits/s dup=850 drop=0 speed=5.35x
# frame= 5222 fps=161 q=25.0 size=  817152kB time=00:02:53.36 bitrate=38612.4kbits/s dup=870 drop=0 speed=5.35x
# frame= 5342 fps=161 q=25.0 size=  836096kB time=00:02:57.36 bitrate=38616.6kbits/s dup=890 drop=0 speed=5.36x
# frame= 5381 fps=162 q=-1.0 Lsize=  845362kB time=00:02:59.33 bitrate=38616.4kbits/s dup=897 drop=0 speed= 5.4x
# video:845336kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.003025%
# [libx264 @ 0x5595ff417e40] frame I:22    Avg QP:21.68  size:238729
# [libx264 @ 0x5595ff417e40] frame P:5359  Avg QP:25.23  size:160547
# [libx264 @ 0x5595ff417e40] mb I  I16..4: 100.0%  0.0%  0.0%
# [libx264 @ 0x5595ff417e40] mb P  I16..4: 52.1%  0.0%  0.0%  P16..4: 45.3%  0.0%  0.0%  0.0%  0.0%    skip: 2.7%
# [libx264 @ 0x5595ff417e40] coded y,uvDC,uvAC intra: 100.0% 0.0% 0.0% inter: 90.7% 0.0% 0.0%
# [libx264 @ 0x5595ff417e40] i16 v,h,dc,p: 16% 17% 56% 11%
# [libx264 @ 0x5595ff417e40] i8c dc,h,v,p: 100%  0%  0%  0%
# [libx264 @ 0x5595ff417e40] kb/s:38608.00
# /home/lq53/mir_repos/minian/minian/minian/initialization.py:340: RuntimeWarning: divide by zero encountered in floor_divide
#   for _, seed_sub in seeds.groupby(np.arange(len(seeds)) // chk_size):
# /home/lq53/mir_repos/minian/minian/minian/initialization.py:509: RuntimeWarning: divide by zero encountered in floor_divide
#   for _, seed_sub in seeds.groupby(np.arange(len(seeds)) // chk_size):
# Traceback (most recent call last):
#   File "minian_mirpy_set.py", line 144, in <module>
#     A, C = unit_merge(A_init, C_init, **param_init_merge)
#   File "/home/lq53/mir_repos/minian/minian/minian/cnmf.py", line 1456, in unit_merge
#     adj = adj_corr(C, A_inter, nod_df, freq=noise_freq)
#   File "/home/lq53/mir_repos/minian/minian/minian/cnmf.py", line 1844, in adj_corr
#     corr_df = graph_optimize_corr(varr, G, freq, idx_dims=nod_df.columns)
#   File "/home/lq53/mir_repos/minian/minian/minian/cnmf.py", line 1805, in graph_optimize_corr
#     corr = pd.Series(np.concatenate(corr_ls), index=np.concatenate(idx_ls), name="corr")
#   File "<__array_function__ internals>", line 5, in concatenate
# ValueError: need at least one array to concatenate
#
# Warning: Output file not found for combination wnd1500_stp700_max15_diff3.0_pnr1.1.

# %%
import pyarrow.compute as pc
table = all_mini #combined_df


filter_mask = pc.and_(
    pc.equal(table['minian'], '1'), 
    # pc.equal(table['valid_rec'], '1') #not_equal 
    pc.equal(table['mapped'], '1') #not_equal
)


# Apply the filter and print the results
filtered_table_mini = table.filter(filter_mask)

# Print each row of the filtered table
print(filtered_table_mini.to_pandas())  # This will display the filtered data in a familiar pandas-like format
# Out:
#    minian minian_selected valid_rec mapped       quality  \
# 0       1               0         1      1  out_of_focus
# 1       1               1         1      1  out_of_focus
# 2       1               0         1      1     good_vein
# 3       1               1         1      1          good
# 4       1               1         1      1  param_adjust
# 5       1               1         1      1  param_adjust
# 6       1               1         1      1           bad
# 7       1               1         1      1  param_adjust
# 8       1               0         1      1          good
# 9       1               1         1      1  param_adjust
# 10      1               1         1      1  param_adjust
# 11      1               1         1      1  param_adjust
# 12      1               1         1      1  param_adjust
# 13      1               0         1      1          good
# 14      1               1         1      1          good
# 15      1               1         1      1  param_adjust
# 16      1               1         1      1  param_adjust
# 17      1               1         1      1     good_vein
# 18      1               1         1      1     good_vein
# 19      1               1         1      1          good
# 20      1               1         1      1          good
# 21      1               1         1      1  param_adjust
# 22      1               0         1      1  param_adjust
# 23      1               0         1      1  param_adjust
# 24      1               0         1      1  param_adjust
# 25      1               0         1      1  param_adjust
# 26      1               1         1      1  param_adjust
# 27      1               0         1      1  param_adjust
# 28      1               0         1      1  param_adjust
# 29      1               1         1      1  param_adjust
# 30      1               0         1      1  param_adjust
# 31      1               0         1      1  param_adjust
# 32      1               0         1      1     good_vein
# 33      1               1         1      1  param_adjust
# 34      1               1         1      1     good_vein
# 35      1               0         1      1  param_adjust
# 36      1               1         1      1  param_adjust
# 37      1               1         1      1  param_adjust
# 38      1               0         1      1  param_adjust
#
#                      timestamp         animal_id      custom_label  \
# 0   2025-03-25T14:03:16.865839  202401015-PMC-r1  customEntValHere
# 1   2025-03-25T14:03:16.870256  202401015-PMC-r1  customEntValHere
# 2   2025-03-25T14:03:16.869884  202401015-PMC-r2  customEntValHere
# 3   2025-03-25T14:03:16.868403  202401015-PMC-r2  customEntValHere
# 4   2025-03-25T14:03:16.863673  202401015-PMC-r2  customEntValHere
# 5   2025-03-25T14:03:16.867006  202401015-PMC-r2  customEntValHere
# 6   2025-03-25T14:03:16.846600   20240717-PMC-r1  customEntValHere
# 7   2025-03-25T14:03:16.845377    20240819-V1-r1  customEntValHere
# 8   2025-03-25T14:03:16.856675    20240819-V1-r1  customEntValHere
# 9   2025-03-25T14:03:16.839405    20240819-V1-r1  customEntValHere
# 10  2025-03-25T14:03:16.836001    20240819-V1-r1  customEntValHere
# 11  2025-03-25T14:03:16.839145    20240819-V1-r1  customEntValHere
# 12  2025-03-25T14:03:16.840397    20240819-V1-r1  customEntValHere
# 13  2025-03-25T14:03:16.845233     20240910-V1-R  customEntValHere
# 14  2025-03-25T14:03:16.834235     20240910-V1-R  customEntValHere
# 15  2025-03-25T14:03:16.831835     20240910-V1-R  customEntValHere
# 16  2025-03-25T14:03:16.863300    20240916-V1-R1  customEntValHere
# 17  2025-03-25T14:03:16.855468    20240916-V1-R1  customEntValHere
# 18  2025-03-25T14:03:16.857422    20240916-V1-R1  customEntValHere
# 19  2025-03-25T14:03:16.849617    20240916-V1-R2  customEntValHere
# 20  2025-03-25T14:03:16.851910    20240916-V1-R2  customEntValHere
# 21  2025-03-25T14:03:16.850364    20240916-V1-R2  customEntValHere
# 22  2025-03-25T14:03:16.828927    20240919-V1-R1  customEntValHere
# 23  2025-03-25T14:03:16.875285    20240919-V1-R2  customEntValHere
# 24  2025-03-25T14:03:16.873490    20240919-V1-R2  customEntValHere
# 25  2025-03-25T14:03:16.863831   20241001-PMC-r2  customEntValHere
# 26  2025-03-25T14:03:16.867156   20241001-PMC-r2  customEntValHere
# 27  2025-03-25T14:03:16.872450    20241001PMCRE2  customEntValHere
# 28  2025-03-25T14:03:16.872727    20241001PMCRE2  customEntValHere
# 29  2025-03-25T14:03:16.866882    20241001PMCRE2  customEntValHere
# 30  2025-03-25T14:03:16.874549   20241002-PMC-R1  customEntValHere
# 31  2025-03-25T14:03:16.878100   20241002-PMC-R1  customEntValHere
# 32  2025-03-25T14:03:16.847689   20241002-pmc-r2  customEntValHere
# 33  2025-03-25T14:03:16.851450   20241002-pmc-r2  customEntValHere
# 34  2025-03-25T14:03:16.855179   20241002-pmc-r2  customEntValHere
# 35  2025-03-25T14:03:16.878165    20241015PMCBE1  customEntValHere
# 36  2025-03-25T14:03:16.829893    20241212v1l1r1  customEntValHere
# 37  2025-03-25T14:03:16.874966    20241212v1l1r2  customEntValHere
# 38  2025-03-25T14:03:16.878219    20241224PMCLE1  customEntValHere
#
#           date      time                                    experiment_path
# 0   2024_11_06  16_16_30  /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/...
# 1   2024_11_07  14_53_09  /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/...
# 2   2024_11_06  16_57_35  /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/...
# 3   2024_11_06  17_13_26  /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/...
# 4   2024_11_07  13_04_45  /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/...
# 5   2024_11_07  13_25_34  /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/...
# 6   2024_10_24  12_32_37  /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/...
# 7   2024_10_17  14_09_19  /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/...
# 8   2024_10_17  14_25_32  /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/...
# 9   2024_10_31  11_31_56  /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/...
# 10  2024_10_31  11_50_32  /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/...
# 11  2024_11_01  14_40_33  /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/...
# 12  2024_11_01  14_57_45  /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/...
# 13  2024_11_01  11_39_00  /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/...
# 14  2024_11_01  12_52_48  /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/...
# 15  2024_11_01  13_09_59  /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/...
# 16  2024_10_14  14_54_12  /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/...
# 17  2024_10_14  16_38_19  /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/...
# 18  2024_10_14  16_54_16  /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/...
# 19  2024_10_14  14_23_28  /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/...
# 20  2024_10_14  16_03_58  /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/...
# 21  2024_10_25  14_31_19  /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/...
# 22  2024_12_18  11_22_07  /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/...
# 23  2024_12_18  13_08_19  /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/...
# 24  2024_12_31  13_55_41  /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/...
# 25  2024_10_24  15_27_55  /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/...
# 26  2024_10_24  16_20_26  /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/...
# 27  2025_02_12  13_45_01  /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/...
# 28  2025_02_12  14_01_13  /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/...
# 29  2025_02_12  15_36_16  /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/...
# 30  2024_10_24  13_07_09  /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/...
# 31  2024_10_25  15_02_11  /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/...
# 32  2024_10_25  15_50_39  /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/...
# 33  2024_10_25  16_27_28  /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/...
# 34  2024_10_25  17_09_14  /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/...
# 35  2025_02_27  12_25_53  /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/...
# 36  2024_12_31  11_31_05  /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/...
# 37  2024_12_31  12_07_27  /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/...
# 38  2025_02_13  11_07_37  /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/...

# %%
import pyarrow.compute as pc
table = all_mini #combined_df


# filter_mask = pc.and_(
#     pc.equal(table['minian'], '1'), 
#     pc.equal(table['valid_rec'], '1') #not_equal
# )



# Apply the filter and print the results
mini_valid = table.filter(pc.equal(table['valid_rec'], '1'))

# Print each row of the filtered table
print(mini_valid.to_pandas())  # This will display the filtered data in a familiar pandas-like format
# Out:
#    minian valid_rec         rec_name                   timestamp  \
# 0       0         1  My_V4_Miniscope  2025-02-20T14:04:55.587550
# 1       1         1  My_V4_Miniscope  2025-02-20T14:04:55.603356
# 2       1         1  My_V4_Miniscope  2025-02-20T14:04:55.605187
# 3       1         1  My_V4_Miniscope  2025-02-20T14:04:55.604662
# 4       1         1  My_V4_Miniscope  2025-02-20T14:04:55.603020
# ..    ...       ...              ...                         ...
# 73      0         1  My_V4_Miniscope  2025-02-20T14:04:55.605502
# 74      0         1  My_V4_Miniscope  2025-02-20T14:04:55.605380
# 75      0         1  My_V4_Miniscope  2025-02-20T14:04:55.605005
# 76      0         1  My_V4_Miniscope  2025-02-20T14:04:55.605462
# 77      0         1  My_V4_Miniscope  2025-02-20T14:04:55.605342
#
#            animal_id      custom_label        date      time calib_files
# 0     2024-016v1l1r1  customEntValHere  2025_01_23  19_17_52          []
# 1   202401015-PMC-r1  customEntValHere  2024_11_06  16_16_30          []
# 2   202401015-PMC-r1  customEntValHere  2024_11_07  14_36_12          []
# 3   202401015-PMC-r1  customEntValHere  2024_11_07  14_53_09          []
# 4   202401015-PMC-r2  customEntValHere  2024_11_06  16_57_35          []
# ..               ...               ...         ...       ...         ...
# 73    20241212v1l1r2  customEntValHere  2024_12_31  12_16_45          []
# 74    20241224PMCLE1  customEntValHere  2025_02_13  11_07_37          []
# 75    20241224PMCLE1  customEntValHere  2025_02_13  11_23_53          []
# 76    20241224PMCLE1  customEntValHere  2025_02_13  11_48_21          []
# 77    20241224PMCLE1  customEntValHere  2025_02_13  11_58_39          []
#
# [78 rows x 9 columns]

# %%
# below works well, but, sometimes there is something that i filterted, or not yet processed, will lead to a mismatch.

#  import os
# import re
# import json
# import pyarrow.compute as pc

# # --- Helper functions ---

# def parse_time_str(time_str):
#     """Parse a time string 'HH_MM_SS' or 'HH_MM' into a tuple (hour, minute, second)."""
#     parts = time_str.split('_')
#     if len(parts) == 3:
#         return int(parts[0]), int(parts[1]), int(parts[2])
#     elif len(parts) == 2:
#         return int(parts[0]), int(parts[1]), 0
#     else:
#         raise ValueError(f"Invalid time format: {time_str}")

# def time_to_seconds(hour, minute, second):
#     return hour * 3600 + minute * 60 + second

# def parse_rec_time(rec_file):
#     """
#     Extract a time tuple from a rec_file string.
#     E.g., for "20241002PMCr2_15_42" it takes the last two underscore tokens as hour and minute.
#     """
#     tokens = rec_file.split('_')
#     if len(tokens) >= 2:
#         try:
#             hour = int(tokens[-2])
#             minute = int(tokens[-1])
#             return hour, minute, 0
#         except ValueError:
#             # fallback: use regex extraction
#             matches_hour = re.findall(r'\d+', tokens[-2])
#             matches_min = re.findall(r'\d+', tokens[-1])
#             if matches_hour and matches_min:
#                 return int(matches_hour[0]), int(matches_min[0]), 0
#     return None

# def build_mini_path(mini_root, animal_id, custom_label, date_str, time_str):
#     """
#     Build the miniscope path using:
#       mini_root / animal_id / custom_label / date_str / time_str / My_V4_Miniscope
#     """
#     return os.path.join(mini_root, animal_id, custom_label, date_str, time_str, "My_V4_Miniscope")

# def build_rec_path(rec_base, date_folder, rec_file):
#     """
#     Build the rec path as:
#       rec_base / date_folder / rec_file / DANNCE / predict00 / save_data_AVG.mat
#     """
#     return os.path.join(rec_base, date_folder, rec_file, "DANNCE", "predict00", "save_data_AVG.mat")

# # --- Main matching function using PyArrow filtering ---

# def match_mini_to_rec(filtered_table_mini, filtered_table, mini_root, rec_base, time_threshold=3600):
#     """
#     For each miniscope record (from filtered_table_mini), filter the rec table (filtered_table)
#     by matching the 'date' (in mini) to 'date_folder' (in rec) using pyarrow.compute.
    
#     Then, among rec candidates, pick the one with the smallest time difference
#     (using mini 'time' vs. time parsed from rec_file). Only candidates with a difference
#     less than time_threshold (in seconds) are accepted.
    
#     Returns a dictionary mapping the built mini_path to the matched rec_path (or None).
#     """
#     mapping = {}
    
#     # Iterate over mini records as a list of dicts (expected to be small after filtering)
#     for mini_rec in filtered_table_mini.to_pylist():
#         mini_date = mini_rec["date"]         # e.g., "2024_10_25"
#         mini_time_str = mini_rec["time"]      # e.g., "15_50_39"
#         animal_id = mini_rec["animal_id"]
#         custom_label = mini_rec["custom_label"]
        
#         try:
#             mini_h, mini_m, mini_s = parse_time_str(mini_time_str)
#         except Exception as e:
#             print(f"Skipping mini record with invalid time '{mini_time_str}': {e}")
#             continue
#         mini_seconds = time_to_seconds(mini_h, mini_m, mini_s)
        
#         # Build the full mini path
#         mini_path = build_mini_path(mini_root, animal_id, custom_label, mini_date, mini_time_str)
        
#         # Filter the rec table for rows with matching date_folder using pyarrow
#         cond = pc.equal(filtered_table.column("date_folder"), mini_date)
#         rec_date_table = filtered_table.filter(cond)
        
#         rec_candidates = rec_date_table.to_pylist()  # should be a small subset
#         best_diff = None
#         best_rec = None
        
#         for rec in rec_candidates:
#             rec_file = rec["rec_file"]
#             rec_time = parse_rec_time(rec_file)
#             if rec_time is None:
#                 continue
#             rec_seconds = time_to_seconds(*rec_time)
#             diff = abs(mini_seconds - rec_seconds)
#             if best_diff is None or diff < best_diff:
#                 best_diff = diff
#                 best_rec = rec
        
#         if best_rec is not None and best_diff <= time_threshold:
#             rec_path = build_rec_path(rec_base, mini_date, best_rec["rec_file"])
#         else:
#             rec_path = None
        
#         mapping[mini_path] = rec_path
#         print(f"Mini: {mini_path}\nMatched Rec: {rec_path} (Time diff: {best_diff})\n")
    
#     return mapping

# # --- Example usage in a Jupyter cell ---
# # (Assuming filtered_table_mini and filtered_table are already defined PyArrow Tables)

# # Define your root directories (update these as needed)
# mini_root = "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted"  # e.g., the base directory for miniscope data
# rec_base  = "/data/big_rim/rsync_dcc_sum/Oct3V1"   # e.g., the base directory for rec prediction folders

# # Run the matching code (using the already-filtered PyArrow tables)
# mapping = match_mini_to_rec(mini_valid, all_df, mini_root, rec_base) #if we only use filtered, sometimes there will be mismatch, and that will be bad.

# # Optionally, you can save the mapping to a JSON file
# with open("mini_to_rec_mapping.json", "w") as f:
#     json.dump(mapping, f, indent=4)
# Out:
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/202401015-PMC-r1/customEntValHere/2024_11_06/16_16_30/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_11_06/20241015pmcr1_16_12/DANNCE/predict00/save_data_AVG.mat (Time diff: 270)
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/202401015-PMC-r1/customEntValHere/2024_11_07/14_36_12/My_V4_Miniscope
# Matched Rec: None (Time diff: 6252)
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/202401015-PMC-r1/customEntValHere/2024_11_07/14_53_09/My_V4_Miniscope
# Matched Rec: None (Time diff: 7269)
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/202401015-PMC-r2/customEntValHere/2024_11_06/16_57_35/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_11_06/20241015pmcr2_16_53/DANNCE/predict00/save_data_AVG.mat (Time diff: 275)
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/202401015-PMC-r2/customEntValHere/2024_11_07/13_04_45/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_11_07/20241015pmcr2_AO_12_52/DANNCE/predict00/save_data_AVG.mat (Time diff: 765)
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/202401015-PMC-r2/customEntValHere/2024_11_07/13_25_34/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_11_07/20241015pmcr2_AO_12_52/DANNCE/predict00/save_data_AVG.mat (Time diff: 2014)
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240717-PMC-r1/customEntValHere/2024_10_24/12_32_37/My_V4_Miniscope
# Matched Rec: None (Time diff: 9263)
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_09_18/13_34_29/My_V4_Miniscope
# Matched Rec: None (Time diff: 45149)
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_09_18/13_55_04/My_V4_Miniscope
# Matched Rec: None (Time diff: 46384)
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_04/14_18_19/My_V4_Miniscope
# Matched Rec: None (Time diff: 21101)
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_04/20_16_14/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_04/20240819V1r1_20_10/DANNCE/predict00/save_data_AVG.mat (Time diff: 374)
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_04/21_08_15/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_04/20240819V1r1_21_05/DANNCE/predict00/save_data_AVG.mat (Time diff: 195)
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_04/21_41_08/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_04/20240819V1r1_21_40/DANNCE/predict00/save_data_AVG.mat (Time diff: 68)
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_08/20_16_41/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_08/20240819V1r1_20_17/DANNCE/predict00/save_data_AVG.mat (Time diff: 19)
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_17/14_09_19/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_17/20240819V1r1_14_25/DANNCE/predict00/save_data_AVG.mat (Time diff: 941)
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_17/14_41_28/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_17/20240819V1r1_14_40/DANNCE/predict00/save_data_AVG.mat (Time diff: 88)
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_31/11_31_56/My_V4_Miniscope
# Matched Rec: None (Time diff: None)
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_31/11_50_32/My_V4_Miniscope
# Matched Rec: None (Time diff: None)
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_11_01/14_40_33/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_11_01/20240819V1r1_AO_14_56/DANNCE/predict00/save_data_AVG.mat (Time diff: 927)
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_11_01/14_57_45/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_11_01/20240819V1r1_AO_14_56/DANNCE/predict00/save_data_AVG.mat (Time diff: 105)
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240910-V1-R/customEntValHere/2024_11_01/11_39_00/My_V4_Miniscope
# Matched Rec: None (Time diff: 4260)
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240910-V1-R/customEntValHere/2024_11_01/12_52_48/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_11_01/20240910V1r_AO_12_50/DANNCE/predict00/save_data_AVG.mat (Time diff: 168)
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240910-V1-R/customEntValHere/2024_11_01/13_09_59/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_11_01/20240910V1r_AO_12_50/DANNCE/predict00/save_data_AVG.mat (Time diff: 1199)
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240910-V1-R/customEntValHere/2024_11_13/16_18_24/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_11_13/20240910v1r_cricket_cyliner_test_16_17/DANNCE/predict00/save_data_AVG.mat (Time diff: 84)
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_04/14_49_29/My_V4_Miniscope
# Matched Rec: None (Time diff: 19231)
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_07/14_53_59/My_V4_Miniscope
# Matched Rec: None (Time diff: 10861)
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_07/15_07_56/My_V4_Miniscope
# Matched Rec: None (Time diff: 10024)
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_07/15_57_40/My_V4_Miniscope
# Matched Rec: None (Time diff: 7040)
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_07/18_00_05/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_07/20240916v1r1_17_55/DANNCE/predict00/save_data_AVG.mat (Time diff: 305)
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_08/14_24_58/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_08/20240916v1r1_14_20/DANNCE/predict00/save_data_AVG.mat (Time diff: 298)
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_08/14_41_53/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_08/20240916v1r1_14_40/DANNCE/predict00/save_data_AVG.mat (Time diff: 113)
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_08/15_36_19/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_08/20240916v1r1_15_35/DANNCE/predict00/save_data_AVG.mat (Time diff: 79)
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_08/16_06_49/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_08/20240916v1r1_16_03/DANNCE/predict00/save_data_AVG.mat (Time diff: 229)
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_08/16_23_13/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_08/20240916v1r1_16_22/DANNCE/predict00/save_data_AVG.mat (Time diff: 73)
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_14/14_54_12/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_14/20240916v1r1_14_53/DANNCE/predict00/save_data_AVG.mat (Time diff: 72)
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_14/15_10_18/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_14/20240916v1r1_14_53/DANNCE/predict00/save_data_AVG.mat (Time diff: 1038)
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_14/16_38_19/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_14/20240916v1r1_16_37/DANNCE/predict00/save_data_AVG.mat (Time diff: 79)
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_14/16_54_16/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_14/20240916v1r1_16_53/DANNCE/predict00/save_data_AVG.mat (Time diff: 76)
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R2/customEntValHere/2024_10_14/14_23_28/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_14/20240916v1r2_14_30/DANNCE/predict00/save_data_AVG.mat (Time diff: 392)
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R2/customEntValHere/2024_10_14/16_03_58/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_14/20240916v1r2_15_58/DANNCE/predict00/save_data_AVG.mat (Time diff: 358)
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R2/customEntValHere/2024_10_25/14_31_19/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_25/20240916v1r2_14_30/DANNCE/predict00/save_data_AVG.mat (Time diff: 79)
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240919V1L5/customEntValHere/2024_10_31/13_24_56/My_V4_Miniscope
# Matched Rec: None (Time diff: None)
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241001-PMC-r2/customEntValHere/2024_10_24/15_27_55/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_24/20241001PMCr2_15_07/DANNCE/predict00/save_data_AVG.mat (Time diff: 1255)
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241001-PMC-r2/customEntValHere/2024_10_24/16_20_26/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_24/20241001PMCr2_16_19/DANNCE/predict00/save_data_AVG.mat (Time diff: 86)
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241002-PMC-R1/customEntValHere/2024_10_24/13_07_09/My_V4_Miniscope
# Matched Rec: None (Time diff: 7191)
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241002-PMC-R1/customEntValHere/2024_10_25/15_02_11/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_25/20241002PMCr1_14_54/DANNCE/predict00/save_data_AVG.mat (Time diff: 491)
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241002-pmc-r2/customEntValHere/2024_10_25/15_50_39/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_25/20241002PMCr2_16_25/DANNCE/predict00/save_data_AVG.mat (Time diff: 2061)
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241002-pmc-r2/customEntValHere/2024_10_25/16_27_28/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_25/20241002PMCr2_16_25/DANNCE/predict00/save_data_AVG.mat (Time diff: 148)
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241002-pmc-r2/customEntValHere/2024_10_25/17_09_14/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_25/20241002PMCr2_16_25/DANNCE/predict00/save_data_AVG.mat (Time diff: 2654)
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241002-pmc-r2/customEntValHere/2024_10_25/17_24_56/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_25/20241002PMCr2_16_25/DANNCE/predict00/save_data_AVG.mat (Time diff: 3596)

# %%
import os
import re
import json
import datetime
import pyarrow.compute as pc

# ----- Helper Functions -----

def parse_time_str(time_str):
    """
    Parse a time string in the format 'HH_MM_SS' or 'HH_MM' into a tuple (hour, minute, second).
    """
    parts = time_str.split('_')
    if len(parts) == 3:
        return int(parts[0]), int(parts[1]), int(parts[2])
    elif len(parts) == 2:
        return int(parts[0]), int(parts[1]), 0
    else:
        raise ValueError(f"Invalid time format: {time_str}")

def time_to_seconds(hour, minute, second):
    return hour * 3600 + minute * 60 + second

def get_rec_time_from_videos(rec_base, date_folder, rec_file):
    """
    Given the rec_base, date_folder, and rec_file, build the videos folder path:
        videos_path = f"{rec_base}/{date_folder}/{rec_file}/videos"
    and return the time-of-day (hour, minute, second) based on its modification time.
    """
    videos_path = os.path.join(rec_base, date_folder, rec_file, "videos")
    try:
        # Using the modification time as a proxy for creation time.
        timestamp = os.path.getmtime(videos_path)
        dt = datetime.datetime.fromtimestamp(timestamp)
        return dt.hour, dt.minute, dt.second
    except Exception as e:
        print(f"Error getting time for {videos_path}: {e}")
        return None

def build_mini_path(mini_root, animal_id, custom_label, date_str, time_str):
    """
    Build the miniscope path using:
      mini_root / animal_id / custom_label / date_str / time_str / My_V4_Miniscope
    """
    return os.path.join(mini_root, animal_id, custom_label, date_str, time_str, "My_V4_Miniscope")

def build_rec_path(rec_base, date_folder, rec_file):
    """
    Build the rec path as:
      rec_base / date_folder / rec_file / DANNCE / predict00 / save_data_AVG.mat
    """
    return os.path.join(rec_base, date_folder, rec_file, "DANNCE", "predict00", "save_data_AVG.mat")

# ----- Matching Function Using PyArrow Filtering -----

def match_mini_to_rec_all(filtered_table_mini, all_rec_table, filtered_rec_table, mini_root, rec_base, time_threshold=3600):
    """
    For each processed miniscope record in filtered_table_mini, find the best matching rec candidate from all_rec_table.
    Instead of parsing the rec_file for a time, this version uses the modification time of the rec video's folder.
    Then check if the candidate is in filtered_rec_table to mark it as valid.
    
    Parameters:
      filtered_table_mini: PyArrow Table with processed miniscope records (columns: "date", "time", "animal_id", "custom_label", etc.)
      all_rec_table: PyArrow Table with all rec entries (columns: "date_folder", "rec_file", etc.)
      filtered_rec_table: PyArrow Table with rec entries that passed further processing.
      mini_root: Base directory for constructing the full miniscope path.
      rec_base: Base directory for constructing the rec prediction path.
      time_threshold: Maximum allowed time difference (in seconds) for a match to be considered valid.
    
    Returns:
      A dictionary mapping each constructed mini_path to a dict with:
          "rec_path": the constructed rec prediction file path (or None),
          "time_diff": the time difference (in seconds) between mini time and rec video time,
          "valid": True if the candidate is in filtered_rec_table and within threshold, else False.
    """
    mapping = {}
    
    # Loop over each processed miniscope record
    for mini_rec in filtered_table_mini.to_pylist():
        mini_date = mini_rec["date"]         # e.g., "2024_10_25"
        mini_time_str = mini_rec["time"]      # e.g., "15_50_39"
        animal_id = mini_rec["animal_id"]
        custom_label = mini_rec["custom_label"]
        
        try:
            mini_h, mini_m, mini_s = parse_time_str(mini_time_str)
        except Exception as e:
            print(f"Skipping mini record with invalid time '{mini_time_str}': {e}")
            continue
        mini_seconds = time_to_seconds(mini_h, mini_m, mini_s)
        
        # Build the full mini path
        mini_path = build_mini_path(mini_root, animal_id, custom_label, mini_date, mini_time_str)
        
        # Filter all_rec_table for rec entries with matching date_folder using pyarrow
        cond_date = pc.equal(all_rec_table.column("date_folder"), mini_date)
        rec_date_table = all_rec_table.filter(cond_date)
        rec_candidates = rec_date_table.to_pylist()  # This subset should be small
        
        best_diff = None
        best_rec = None
        
        # Loop through candidates to find the rec with the smallest time difference
        for rec in rec_candidates:
            rec_file = rec["rec_file"]
            rec_time = get_rec_time_from_videos(rec_base, mini_date, rec_file)
            if rec_time is None:
                continue
            rec_seconds = time_to_seconds(*rec_time)
            diff = abs(mini_seconds - rec_seconds)
            if best_diff is None or diff < best_diff:
                best_diff = diff
                best_rec = rec
        
        # Determine the rec_path and check validity
        if best_rec is not None:
            rec_path = build_rec_path(rec_base, mini_date, best_rec["rec_file"])
            # Check if this candidate is in the filtered_rec_table (i.e., further validated recs)
            cond_filtered = pc.equal(filtered_rec_table.column("rec_file"), best_rec["rec_file"])
            filtered_candidates = filtered_rec_table.filter(cond_filtered)
            is_filtered = filtered_candidates.num_rows > 0
            # Mark candidate as valid if within threshold and exists in filtered_rec_table
            valid_candidate = (best_diff is not None and best_diff <= time_threshold) and is_filtered
        else:
            rec_path = None
            best_diff = None
            valid_candidate = False
        
        mapping[mini_path] = {"rec_path": rec_path, "time_diff": best_diff, "valid": valid_candidate}
        print(f"Mini: {mini_path}\nMatched Rec: {rec_path} (Time diff: {best_diff}) Valid: {valid_candidate}\n")
    
    return mapping

def resolve_duplicates(mapping):
    """
    Ensure that each rec_path is only matched to one mini_path.
    For any rec_path that appears for multiple mini_paths, only keep the one with the smallest time_diff.
    The other mini_paths will have their rec_path set to None and valid flag set to False.
    """
    # Build a dictionary mapping rec_path to a list of (mini_path, time_diff) tuples.
    rec_to_mini = {}
    for mini_path, info in mapping.items():
        rec = info["rec_path"]
        if rec is None:
            continue
        rec_to_mini.setdefault(rec, []).append((mini_path, info["time_diff"]))
    
    # For each rec_path that is assigned to multiple mini_paths,
    # keep only the mini_path with the smallest time_diff.
    for rec, mini_list in rec_to_mini.items():
        if len(mini_list) > 1:
            best_mini, best_diff = min(mini_list, key=lambda x: x[1])
            for mini_path, diff in mini_list:
                if mini_path != best_mini:
                    mapping[mini_path]["rec_path"] = None
                    mapping[mini_path]["valid"] = False
                    print(f"Duplicate resolved: {mini_path} lost rec_path {rec} (time_diff {diff} > {best_diff})")
    return mapping

# ----- Example Usage in a Jupyter Cell -----

# Assume the following PyArrow tables are already defined in your notebook:
#   - filtered_table_mini: processed miniscope entries (valid miniscope data)
#   - all_rec_table: full set of rec entries (e.g., all_df)
#   - filtered_rec_table: rec entries that passed further processing (the "good" recs)

# Define your base directories (update these paths as needed)
mini_root = "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted"  # Base directory for miniscope data
rec_base  = "/data/big_rim/rsync_dcc_sum/Oct3V1"              # Base directory for rec prediction folders

# Run the matching function using the PyArrow tables and the specified time threshold
mapping = match_mini_to_rec_all(filtered_table_mini, all_df, filtered_table, mini_root, rec_base, time_threshold=20)

# Resolve duplicate rec_path assignments so that each rec is matched only once
mapping = resolve_duplicates(mapping)

# Optionally, save the mapping to a JSON file for further processing
with open("mini_to_rec_mapping.json", "w") as f:
    json.dump(mapping, f, indent=4)
# Out:
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/202401015-PMC-r1/customEntValHere/2024_11_06/16_16_30/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_11_06/20241015pmcr1_16_12/DANNCE/predict00/save_data_AVG.mat (Time diff: 109) Valid: False
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/202401015-PMC-r1/customEntValHere/2024_11_07/14_36_12/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_11_07/20241015pmcr1_AO_14_52/DANNCE/predict00/save_data_AVG.mat (Time diff: 1012) Valid: False
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/202401015-PMC-r1/customEntValHere/2024_11_07/14_53_09/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_11_07/20241015pmcr1_AO_14_52/DANNCE/predict00/save_data_AVG.mat (Time diff: 5) Valid: False
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/202401015-PMC-r2/customEntValHere/2024_11_06/16_57_35/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_11_06/20241015pmcr2_16_53/DANNCE/predict00/save_data_AVG.mat (Time diff: 2) Valid: True
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/202401015-PMC-r2/customEntValHere/2024_11_07/13_04_45/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_11_07/20241015pmcr2_AO_12_52/DANNCE/predict00/save_data_AVG.mat (Time diff: 4) Valid: True
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/202401015-PMC-r2/customEntValHere/2024_11_07/13_25_34/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_11_07/2social_mini_20241015pmcr2_single_AO_13_24/DANNCE/predict00/save_data_AVG.mat (Time diff: 4) Valid: False
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240717-PMC-r1/customEntValHere/2024_10_24/12_32_37/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_24/202420717PMCr1_/DANNCE/predict00/save_data_AVG.mat (Time diff: 3) Valid: True
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_09_18/13_34_29/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_09_18/20240819_V1_r1_2/DANNCE/predict00/save_data_AVG.mat (Time diff: 10887) Valid: False
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_09_18/13_55_04/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_09_18/20240819_V1_r1_2/DANNCE/predict00/save_data_AVG.mat (Time diff: 12122) Valid: False
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_04/14_18_19/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_04/20240916V1r2/DANNCE/predict00/save_data_AVG.mat (Time diff: 13548) Valid: False
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_04/20_16_14/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_04/20240916V1r2/DANNCE/predict00/save_data_AVG.mat (Time diff: 35023) Valid: False
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_04/21_08_15/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_04/20240916V1r2/DANNCE/predict00/save_data_AVG.mat (Time diff: 38144) Valid: False
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_04/21_41_08/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_04/20240916V1r2/DANNCE/predict00/save_data_AVG.mat (Time diff: 40117) Valid: False
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_08/20_16_41/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_08/20240916v1r1_16_22/DANNCE/predict00/save_data_AVG.mat (Time diff: 35031) Valid: False
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_17/14_09_19/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_17/20240819V1r1_13_41/DANNCE/predict00/save_data_AVG.mat (Time diff: 4) Valid: True
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_17/14_41_28/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_17/20240819V1r1_14_40/DANNCE/predict00/save_data_AVG.mat (Time diff: 12) Valid: True
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_31/11_31_56/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_31/2social_mini_20240819V1r1_single_11_29/DANNCE/predict00/save_data_AVG.mat (Time diff: 6) Valid: False
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_31/11_50_32/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_31/2social_mini_20240819V1r1_femalebleach_11_48/DANNCE/predict00/save_data_AVG.mat (Time diff: 7) Valid: False
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_11_01/14_40_33/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_11_01/2social_mini_20240819V1r1_AO_single_14_30/DANNCE/predict00/save_data_AVG.mat (Time diff: 5) Valid: False
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_11_01/14_57_45/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_11_01/20240819V1r1_AO_14_56/DANNCE/predict00/save_data_AVG.mat (Time diff: 5) Valid: True
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240910-V1-R/customEntValHere/2024_11_01/11_39_00/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_11_01/20240910V1r_BO_11_35/DANNCE/predict00/save_data_AVG.mat (Time diff: 5) Valid: False
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240910-V1-R/customEntValHere/2024_11_01/12_52_48/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_11_01/20240910V1r_AO_12_50/DANNCE/predict00/save_data_AVG.mat (Time diff: 6) Valid: True
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240910-V1-R/customEntValHere/2024_11_01/13_09_59/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_11_01/2social_mini_20240910V1r_AO_single_12_50/DANNCE/predict00/save_data_AVG.mat (Time diff: 9) Valid: True
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240910-V1-R/customEntValHere/2024_11_13/16_18_24/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_11_13/240605pmc_righthole_acrylic_test_14_55/DANNCE/predict00/save_data_AVG.mat (Time diff: 4768) Valid: False
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_04/14_49_29/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_04/20240916V1r2/DANNCE/predict00/save_data_AVG.mat (Time diff: 15418) Valid: False
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_07/14_53_59/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_07/20240916v1r1_19_18/DANNCE/predict00/save_data_AVG.mat (Time diff: 15709) Valid: False
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_07/15_07_56/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_07/20240916v1r1_19_18/DANNCE/predict00/save_data_AVG.mat (Time diff: 16546) Valid: False
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_07/15_57_40/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_07/20240916v1r1_19_18/DANNCE/predict00/save_data_AVG.mat (Time diff: 19530) Valid: False
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_07/18_00_05/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_07/20240916v1r1_19_18/DANNCE/predict00/save_data_AVG.mat (Time diff: 26875) Valid: False
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_08/14_24_58/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_08/20240916v1r1_16_22/DANNCE/predict00/save_data_AVG.mat (Time diff: 13928) Valid: False
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_08/14_41_53/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_08/20240916v1r1_16_22/DANNCE/predict00/save_data_AVG.mat (Time diff: 14943) Valid: False
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_08/15_36_19/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_08/20240916v1r1_16_22/DANNCE/predict00/save_data_AVG.mat (Time diff: 18209) Valid: False
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_08/16_06_49/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_08/20240916v1r1_16_22/DANNCE/predict00/save_data_AVG.mat (Time diff: 20039) Valid: False
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_08/16_23_13/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_08/20240916v1r1_16_22/DANNCE/predict00/save_data_AVG.mat (Time diff: 21023) Valid: False
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_14/14_54_12/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_14/20240916v1r1_14_53/DANNCE/predict00/save_data_AVG.mat (Time diff: 6) Valid: True
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_14/15_10_18/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_14/20240916v1r1_14_53/DANNCE/predict00/save_data_AVG.mat (Time diff: 972) Valid: False
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_14/16_38_19/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_14/20240916v1r1_16_37/DANNCE/predict00/save_data_AVG.mat (Time diff: 7) Valid: True
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_14/16_54_16/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_14/20240916v1r1_16_53/DANNCE/predict00/save_data_AVG.mat (Time diff: 3) Valid: True
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R2/customEntValHere/2024_10_14/14_23_28/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_14/20240916v1r2_14_30/DANNCE/predict00/save_data_AVG.mat (Time diff: 4) Valid: True
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R2/customEntValHere/2024_10_14/16_03_58/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_14/20240916v1r2_15_58/DANNCE/predict00/save_data_AVG.mat (Time diff: 7) Valid: True
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R2/customEntValHere/2024_10_25/14_31_19/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_25/20240916v1r2_14_30/DANNCE/predict00/save_data_AVG.mat (Time diff: 3) Valid: True
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240919V1L5/customEntValHere/2024_10_31/13_24_56/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_31/2social_mini_0605pmc_single_14_08/DANNCE/predict00/save_data_AVG.mat (Time diff: 2689) Valid: False
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241001-PMC-r2/customEntValHere/2024_10_24/15_27_55/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_24/20241001PMCr2_15_07/DANNCE/predict00/save_data_AVG.mat (Time diff: 7) Valid: True
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241001-PMC-r2/customEntValHere/2024_10_24/16_20_26/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_24/20241001PMCr2_16_19/DANNCE/predict00/save_data_AVG.mat (Time diff: 6) Valid: True
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241002-PMC-R1/customEntValHere/2024_10_24/13_07_09/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_24/20241002PMCr1_left1_/DANNCE/predict00/save_data_AVG.mat (Time diff: 6) Valid: True
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241002-PMC-R1/customEntValHere/2024_10_25/15_02_11/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_25/20241002PMCr1_14_54/DANNCE/predict00/save_data_AVG.mat (Time diff: 3) Valid: True
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241002-pmc-r2/customEntValHere/2024_10_25/15_50_39/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_25/20241002PMCr2_15_42/DANNCE/predict00/save_data_AVG.mat (Time diff: 3) Valid: False
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241002-pmc-r2/customEntValHere/2024_10_25/16_27_28/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_25/20241002PMCr2_16_25/DANNCE/predict00/save_data_AVG.mat (Time diff: 3) Valid: True
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241002-pmc-r2/customEntValHere/2024_10_25/17_09_14/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_25/20241002PMCr2_17_05/DANNCE/predict00/save_data_AVG.mat (Time diff: 5) Valid: False
#
# Mini: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241002-pmc-r2/customEntValHere/2024_10_25/17_24_56/My_V4_Miniscope
# Matched Rec: /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_25/20241002PMCr2_17_05/DANNCE/predict00/save_data_AVG.mat (Time diff: 947) Valid: False
#
# Duplicate resolved: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/202401015-PMC-r1/customEntValHere/2024_11_07/14_36_12/My_V4_Miniscope lost rec_path /data/big_rim/rsync_dcc_sum/Oct3V1/2024_11_07/20241015pmcr1_AO_14_52/DANNCE/predict00/save_data_AVG.mat (time_diff 1012 > 5)
# Duplicate resolved: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_09_18/13_55_04/My_V4_Miniscope lost rec_path /data/big_rim/rsync_dcc_sum/Oct3V1/2024_09_18/20240819_V1_r1_2/DANNCE/predict00/save_data_AVG.mat (time_diff 12122 > 10887)
# Duplicate resolved: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_04/20_16_14/My_V4_Miniscope lost rec_path /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_04/20240916V1r2/DANNCE/predict00/save_data_AVG.mat (time_diff 35023 > 13548)
# Duplicate resolved: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_04/21_08_15/My_V4_Miniscope lost rec_path /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_04/20240916V1r2/DANNCE/predict00/save_data_AVG.mat (time_diff 38144 > 13548)
# Duplicate resolved: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_04/21_41_08/My_V4_Miniscope lost rec_path /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_04/20240916V1r2/DANNCE/predict00/save_data_AVG.mat (time_diff 40117 > 13548)
# Duplicate resolved: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_04/14_49_29/My_V4_Miniscope lost rec_path /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_04/20240916V1r2/DANNCE/predict00/save_data_AVG.mat (time_diff 15418 > 13548)
# Duplicate resolved: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_10_08/20_16_41/My_V4_Miniscope lost rec_path /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_08/20240916v1r1_16_22/DANNCE/predict00/save_data_AVG.mat (time_diff 35031 > 13928)
# Duplicate resolved: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_08/14_41_53/My_V4_Miniscope lost rec_path /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_08/20240916v1r1_16_22/DANNCE/predict00/save_data_AVG.mat (time_diff 14943 > 13928)
# Duplicate resolved: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_08/15_36_19/My_V4_Miniscope lost rec_path /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_08/20240916v1r1_16_22/DANNCE/predict00/save_data_AVG.mat (time_diff 18209 > 13928)
# Duplicate resolved: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_08/16_06_49/My_V4_Miniscope lost rec_path /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_08/20240916v1r1_16_22/DANNCE/predict00/save_data_AVG.mat (time_diff 20039 > 13928)
# Duplicate resolved: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_08/16_23_13/My_V4_Miniscope lost rec_path /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_08/20240916v1r1_16_22/DANNCE/predict00/save_data_AVG.mat (time_diff 21023 > 13928)
# Duplicate resolved: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_07/15_07_56/My_V4_Miniscope lost rec_path /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_07/20240916v1r1_19_18/DANNCE/predict00/save_data_AVG.mat (time_diff 16546 > 15709)
# Duplicate resolved: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_07/15_57_40/My_V4_Miniscope lost rec_path /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_07/20240916v1r1_19_18/DANNCE/predict00/save_data_AVG.mat (time_diff 19530 > 15709)
# Duplicate resolved: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_07/18_00_05/My_V4_Miniscope lost rec_path /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_07/20240916v1r1_19_18/DANNCE/predict00/save_data_AVG.mat (time_diff 26875 > 15709)
# Duplicate resolved: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240916-V1-R1/customEntValHere/2024_10_14/15_10_18/My_V4_Miniscope lost rec_path /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_14/20240916v1r1_14_53/DANNCE/predict00/save_data_AVG.mat (time_diff 972 > 6)
# Duplicate resolved: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241002-pmc-r2/customEntValHere/2024_10_25/17_24_56/My_V4_Miniscope lost rec_path /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_25/20241002PMCr2_17_05/DANNCE/predict00/save_data_AVG.mat (time_diff 947 > 5)

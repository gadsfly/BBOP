# %%
#!/usr/bin/env python3
import os



# ----------------------------
# Your input list
# ----------------------------
paths = ['/data/big_rim/rsync_dcc_sum/Oct3V1/2024_11_07/#2social_mini_20241015pmcr1_single_AO_14_36_cam1dead',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2024_11_07/2social_mini_20241015pmcr2_single_AO_13_24',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_03_micecolor_test/24Anshu_f_paint_2mice_2',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_03_micecolor_test/#Anshu_f_bleach_2mice',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_03_micecolor_test/24Anshu_f_paint_2mice',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_03_micecolor_test/24Anshu_f_bleach_2mice',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2025_05_21/20241217v1l23re1_p20241217v1l23BE0',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_30/2social_mini_0605pmc_single_15_38',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_30/2social_mini_0605pmc_single_15_00',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_30/2social_mini_0605pmc_single_15_18',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_25/2male_mice_test_miniscope',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_25/2male_mice_test',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2024_12_18/20240919v1l5r2mini_p20240717PMC_social_test_13_16',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2024_12_18/20240919v1l5r2mini_p20240521b1697576_social_test_13_26',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2024_12_18/20240919v1l5r1mini_p20240717PMC_social_test_11_30',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2025_02_27/20241002PMCLE1mini_p20241001RE2_14_10',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2025_02_27/20241015PMCBE1mini_p20241015PMCRE1_12_33',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2025_03_11/20241224PMCLE1mini_p20240303PMC1_14_21',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2025_03_11/20241224PMCLE1mini_p20240303PMC2_14_44',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2025_03_11/#20241224PMCLE1mini_p20240303PMC2_14_40',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2024_12_31/#20241212v1l1r1mini_p20241111_social_11_40_cam1dead',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2024_12_31/20241212v1l1r2mini_p20241111_social_12_16',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2024_12_31/20240919v1l5r2mini_p20240717PMC_social_14_04',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2024_12_31/20240919v1l5r1mini_p20240717PMC_social_14_31',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2025_04_10/20241212V1RE1L23Fmini_p20241212V1BE1L23F',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2025_04_10/20241212V1RE1L23Fmini_p20241212V1LE1L23F',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2024_11_01/2social_mini_20240910V1r_AO_single_12_50',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2024_11_01/2social_mini_20240819V1r1_AO_single_14_30',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_31/2social_mini_20240819V1r1_single_11_29',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_31/#social_mini_20240919V1L5_single_13_20_cam1dead',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_31/2social_mini_20240819V1r1_femalebleach_11_48',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_31/2social_mini_0605pmc_single_14_08',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_31/#social_mini_0605pmc_single_14_25_cam1dead',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2024_12_11/20240919v1l5r1mini_p20240820v1r2_social_test_14_55',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2024_12_11/#20240919v1l5r1mini_pfemale_social_test_15_19_minifailed',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2024_12_11/20240919v1l5r1mini_pfemale_social_test_15_35',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2025_05_01/20250324PMCBmini_psamecageBE0_14_53',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2025_05_01/20250324PMCBmini_psamecageLE2_15_09',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2025_05_14/#20250324PMCRE1mini_p',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2025_05_14/20240324PMCBE0mini_p20250324LE1',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2025_05_14/20250324PMCBmini_p20250324LE1',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2025_05_07/20241216V1RE1Fmini_p202241216V1BE1F',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2025_05_07/#20241216V1RE1Fmini_pM_goodinteractions_cam3dead',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2025_05_16/20241216V1RE1Fmini_p20241216RE2',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2025_05_16/#20241216V1RE1Fmini_pM',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2025_05_16/#20240303PMCBE0r1coated_p',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2025_05_16/#20240303PMCBE0r1coated_pbluecap',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2025_05_16/20241216V1RE1Fmini_p20241224PMCLE1',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2025_05_16/20240303PMCBE0r1coatedmini_p20240303RE1',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2025_05_16/#20241216V1RE1Fmini_pM_',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_29/2social_mini_0605pmc_single_18_42',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_29/2social_mini_0605pmc_single_18_25',
 '/data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_29/2social_mini_0605pmc_single_18_00']
# paths = [
#     '/data/big_rim/rsync_dcc_sum/Oct3V1/2024_11_07/#2social_mini_20241015pmcr1_single_AO_14_36_cam1dead',
#     '/data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_03_micecolor_test/#Anshu_f_bleach_2mice',
#     '/data/big_rim/rsync_dcc_sum/Oct3V1/2025_03_11/#20241224PMCLE1mini_p20240303PMC2_14_40',
#     '/data/big_rim/rsync_dcc_sum/Oct3V1/2024_12_31/#20241212v1l1r1mini_p20241111_social_11_40_cam1dead',
#     '/data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_31/#social_mini_20240919V1L5_single_13_20_cam1dead',
#     '/data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_31/#social_mini_0605pmc_single_14_25_cam1dead',
#     '/data/big_rim/rsync_dcc_sum/Oct3V1/2024_12_11/#20240919v1l5r1mini_pfemale_social_test_15_19_minifailed',
#     '/data/big_rim/rsync_dcc_sum/Oct3V1/2025_05_14/#20250324PMCRE1mini_p',
#     '/data/big_rim/rsync_dcc_sum/Oct3V1/2025_05_07/#20241216V1RE1Fmini_pM_goodinteractions_cam3dead',
#     '/data/big_rim/rsync_dcc_sum/Oct3V1/2025_05_16/#20241216V1RE1Fmini_pM',
#     '/data/big_rim/rsync_dcc_sum/Oct3V1/2025_05_16/#20240303PMCBE0r1coated_p',
#     '/data/big_rim/rsync_dcc_sum/Oct3V1/2025_05_16/#20240303PMCBE0r1coated_pbluecap',
# ]

# ----------------------------
# Check for metadata.csv
# ----------------------------
target_rel_path = os.path.join("videos", "Camera1", "metadata.csv")
found = []
not_found = []

for p in paths:
    target_file = os.path.join(p, target_rel_path)
    if os.path.isfile(target_file):
        found.append(target_file)
    else:
        # print(f"Not found: {target_file}")
        not_found.append(target_file)
        

# ----------------------------
# Output
# ----------------------------

print("Found metadata.csv in:")
for f in found:
    print("  ", f)
print(f"\nTotal: {len(found)}")

# print("No metadata.csv found in any # path.")
print(f"Camer1 Not found Total: {len(not_found)}")
# Out:
# Found metadata.csv in:
#    /data/big_rim/rsync_dcc_sum/Oct3V1/2024_11_07/#2social_mini_20241015pmcr1_single_AO_14_36_cam1dead/videos/Camera1/metadata.csv
#    /data/big_rim/rsync_dcc_sum/Oct3V1/2024_11_07/2social_mini_20241015pmcr2_single_AO_13_24/videos/Camera1/metadata.csv
#    /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_03_micecolor_test/24Anshu_f_paint_2mice_2/videos/Camera1/metadata.csv
#    /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_03_micecolor_test/24Anshu_f_paint_2mice/videos/Camera1/metadata.csv
#    /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_03_micecolor_test/24Anshu_f_bleach_2mice/videos/Camera1/metadata.csv
#    /data/big_rim/rsync_dcc_sum/Oct3V1/2025_05_21/20241217v1l23re1_p20241217v1l23BE0/videos/Camera1/metadata.csv
#    /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_30/2social_mini_0605pmc_single_15_38/videos/Camera1/metadata.csv
#    /data/big_rim/rsync_dcc_sum/Oct3V1/2024_10_30/2social_mini_0605pmc_single_15_00/videos/Camera1/metadata.csv
# ...

# %%
# pip install qrcode[pil]  # run once in your env
import qrcode
url = "https://drive.google.com/drive/folders/1QBi7uWTVHklrHe5Jem2z_-Ac3tFf4fhv?usp=sharing"  # file or folder link
img = qrcode.make(url)
img.save("drive_qr_1024.png")  # drop into your poster doc
print("Saved drive_qr_1024.png")
# Out:
# Saved drive_qr_1024.png

# %%
import sys
import os
sys.path.append(os.path.abspath('../..'))
from utlis.sync_utlis.mini_dannce_sync import generate_frame_mapping
import shutil

# %%
rec_path_norm = "/data/big_rim/rsync_dcc_sum/25juneon/2025_07_08/20250519pmcl2_clearecup/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1/2025_06_17/20250407V1L23r1blkcap/"
# "/data/big_rim/rsync_dcc_sum/25juneon/2025_07_08/20250512PMCl23r1_clearscup"
# "/data/big_rim/rsync_dcc_sum/Oct3V1/2024_11_01/2social_mini_20240819V1r1_AO_single_14_30/"
# "/data/big_rim/rsync_dcc_sum/25juneon/2025_06_26/20250505v1l23r1_greencupsocial2/"
# "/data/big_rim/rsync_dcc_sum/25juneon/2025_06_26/20250505v1l23r1_ecups/"
# "/data/big_rim/rsync_dcc_sum/25juneon/2025_06_26/20250506v1l23l1_clearsocialcup/"
# "/data/big_rim/rsync_dcc_sum/25juneon/2025_06_17/20250407V1L23r1blkcap_econe/"
# "/data/big_rim/rsync_dcc_sum/25juneon/2025_06_17/20250407V1L23r1blkcap/"
# "/data/big_rim/rsync_dcc_sum/25juneon/2025_06_17/20250505V1L23R1pink_econeafterscone/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1/2025_05_16/20241216V1RE1F_15_16/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1/2025_05_16/20240303PMCBE0r1coated_14_53/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1/2025_05_16/20240303PMCBE0r1coated/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1/2024_12_31/20241212v1l1r2mini_12_04/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1/2024_11_01/2social_mini_20240819V1r1_AO_single_14_30/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1/2025_05_16/20240303PMCBE0r1coatedmini_p20240303RE1/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1/2025_05_16/20241216V1RE1Fmini_p20241224PMCLE1/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1/2024_11_01/2social_mini_20240819V1r1_AO_single_14_30/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1/2024_11_01/2social_mini_20240819V1r1_AO_single_14_30/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1/2024_12_18/20240919v1l5r1mini_11_21/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1/2025_02_13/20241225PMCLE1mini_11_06"

mini_path_norm = "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20250519-PMCL234-L2-2_cups/customEntValHere/2025_07_08/11_39_47/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20250407-V1L23-R/customEntValHere/2025_06_17/13_26_17/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20250512-PMCL23_R1-2_cups/customEntValHere/2025_07_08/15_24_44/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_11_01/14_40_33/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20250505V1L23-R1/customEntValHere/2025_06_26/15_33_15/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20250505V1L23-R1/customEntValHere/2025_06_26/14_48_33/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20250506V1L23-L1/customEntValHere/2025_06_26/16_37_57/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20250407-V1L23-R/customEntValHere/2025_06_17/13_40_49/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20250407-V1L23-R/customEntValHere/2025_06_17/13_26_17/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20250505V1L23-R1/customEntValHere/2025_06_17/15_30_26/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241216v1re1f/customEntValHere/2025_05_16/15_17_09/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240303PMCBE0coatedr1/customEntValHere/2025_05_16/14_44_34/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240303PMCBE0coatedr1/customEntValHere/2025_05_16/10_41_17/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241212v1l1r2/customEntValHere/2024_12_31/12_07_27/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_11_01/14_40_33/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240303PMCBE0coatedr1/customEntValHere/2025_05_16/14_54_15/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241216v1re1f/customEntValHere/2025_05_16/15_42_36/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_11_01/14_40_33/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_11_01/14_40_33/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240919-V1-R1/customEntValHere/2024_12_18/11_22_07/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241224PMCLE1/customEntValHere/2025_02_13/11_07_37/"

nc_key = "wnd1500_stp700_max15_diff5.0_pnr1.1"
# "wnd1500_stp700_max25_diff5.0_pnrauto"
# "wnd1000_stp700_max15_diff5.0_pnr1.1"
# "wnd1500_stp700_max25_diff5.0_pnr1.1"
# "wnd1500_stp700_max25_diff4.0_pnrauto"
# "wnd1500_stp700_max25_diff5.0_pnr1.1"
# "wnd1000_stp700_max25_diff3.5_pnrauto"
# "wnd1000_stp700_max25_diff4.0_pnrauto"
# "wnd1500_stp700_max25_diff5.0_pnrauto"
# "wnd700_stp700_max25_diff5.0_pnrauto"
# "wnd1500_stp700_max25_diff4.0_pnr1.1"
# "wnd1000_stp700_max15_diff5.0_pnr1.1"
# "wnd700_stp700_max15_diff5.0_pnr1.1"
# "wnd1000_stp700_max25_diff5.0_pnr1.1"
# "wnd1500_stp700_max25_diff5.0_pnr1.1"
# "wnd1000_stp700_max15_diff5.0_pnr1.1"
# "wnd1500_stp700_max25_diff4.0_pnr1.1"
# "wnd1500_stp700_max25_diff3.5_pnr1.1"
# "wnd1500_stp700_max15_diff3.5_pnrauto"
# "wnd700_stp700_max25_diff5.0_pnrauto"

def mirror_MIR_Aligned(rec_path, mini_path):
    src = os.path.join(rec_path, "MIR_Aligned")
    dst = os.path.join(mini_path, "MIR_Aligned")
    print(f"DEBUG: src exists? {os.path.isdir(src)} → {src}")
    if not os.path.isdir(src):
        print(f"[mirror] no MIR_Aligned at {src}")
        return
    os.makedirs(dst, exist_ok=True)
    shutil.copytree(src, dst, dirs_exist_ok=True)
    print(f"[mirror] copied MIR_Aligned → {dst}")


generate_frame_mapping(
        rec_path_norm,
        mini_path_norm,
        nc_key,
        only_com = False,#True,
        start_frame=0,
        end_frame=500,
        threshold_mini=12,
        threshold_sixcam=2
    )



mirror_MIR_Aligned(rec_path_norm, mini_path_norm)
# Out:
# Camera index with data_frame starting at 1: 0
# Saved plot to /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20250519-PMCL234-L2-2_cups/customEntValHere/2025_07_08/11_39_47/My_WebCam/sync_mini.png
# Saved plot to /data/big_rim/rsync_dcc_sum/25juneon/2025_07_08/20250519pmcl2_clearecup/sync_mini.png
# Saved plot to /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20250519-PMCL234-L2-2_cups/customEntValHere/2025_07_08/11_39_47/My_WebCam/sync_cam1.png
# Saved plot to /data/big_rim/rsync_dcc_sum/25juneon/2025_07_08/20250519pmcl2_clearecup/sync_cam1.png
# Aligned data saved to /data/big_rim/rsync_dcc_sum/25juneon/2025_07_08/20250519pmcl2_clearecup/MIR_Aligned/aligned_predictions.h5
# produced final h5 files
# Using CA file: /data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20250519-PMCL234-L2-2_cups/customEntValHere/2025_07_08/11_39_47/My_V4_Miniscope/minian_dataset_wnd1500_stp700_max15_diff5.0_pnr1.1.nc
# ...

# %%
rec_path_norm = 
# "/data/big_rim/rsync_dcc_sum/25juneon/2025_06_26/20250505v1l23r1_ecups/"
# "/data/big_rim/rsync_dcc_sum/25juneon/2025_06_26/20250506v1l23l1_clearsocialcup/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1/2025_06_17/20250407V1L23r1blkcap_econe/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1/2025_06_17/20250407V1L23r1blkcap/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1/2025_06_17/20250505V1L23R1pink_econeafterscone/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1/2025_05_16/20241216V1RE1F_15_16/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1/2025_05_16/20240303PMCBE0r1coated_14_53/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1/2025_05_16/20240303PMCBE0r1coated/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1/2024_12_31/20241212v1l1r2mini_12_04/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1/2024_11_01/2social_mini_20240819V1r1_AO_single_14_30/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1/2025_05_16/20240303PMCBE0r1coatedmini_p20240303RE1/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1/2025_05_16/20241216V1RE1Fmini_p20241224PMCLE1/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1/2024_11_01/2social_mini_20240819V1r1_AO_single_14_30/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1/2024_11_01/2social_mini_20240819V1r1_AO_single_14_30/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1/2024_12_18/20240919v1l5r1mini_11_21/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1/2025_02_13/20241225PMCLE1mini_11_06"

mini_path_norm = 
# "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20250505V1L23-R1/customEntValHere/2025_06_26/14_48_33/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20250506V1L23-L1/customEntValHere/2025_06_26/16_37_57/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20250407-V1L23-R/customEntValHere/2025_06_17/13_40_49/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20250407-V1L23-R/customEntValHere/2025_06_17/13_26_17/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20250505V1L23-R1/customEntValHere/2025_06_17/15_30_26/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241216v1re1f/customEntValHere/2025_05_16/15_17_09/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240303PMCBE0coatedr1/customEntValHere/2025_05_16/14_44_34/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240303PMCBE0coatedr1/customEntValHere/2025_05_16/10_41_17/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241212v1l1r2/customEntValHere/2024_12_31/12_07_27/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_11_01/14_40_33/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240303PMCBE0coatedr1/customEntValHere/2025_05_16/14_54_15/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241216v1re1f/customEntValHere/2025_05_16/15_42_36/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_11_01/14_40_33/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240819-V1-r1/customEntValHere/2024_11_01/14_40_33/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20240919-V1-R1/customEntValHere/2024_12_18/11_22_07/"
# "/data/big_rim/rsync_dcc_sum/Oct3V1mini_sorted/20241224PMCLE1/customEntValHere/2025_02_13/11_07_37/"

nc_key = 
# "wnd1500_stp700_max25_diff5.0_pnr1.1"
# "wnd1000_stp700_max25_diff3.5_pnrauto"
# "wnd1000_stp700_max25_diff4.0_pnrauto"
# "wnd1500_stp700_max25_diff5.0_pnrauto"
# "wnd700_stp700_max25_diff5.0_pnrauto"
# "wnd1500_stp700_max25_diff4.0_pnr1.1"
# "wnd1000_stp700_max15_diff5.0_pnr1.1"
# "wnd700_stp700_max15_diff5.0_pnr1.1"
# "wnd1000_stp700_max25_diff5.0_pnr1.1"
# "wnd1500_stp700_max25_diff5.0_pnr1.1"
# "wnd1000_stp700_max15_diff5.0_pnr1.1"
# "wnd1500_stp700_max25_diff4.0_pnr1.1"
# "wnd1500_stp700_max25_diff3.5_pnr1.1"
# "wnd1500_stp700_max15_diff3.5_pnrauto"
# "wnd700_stp700_max25_diff5.0_pnrauto"
